# %% [markdown]
# # 🔍 OSINT Incident Mapping with a Multi-Agent Pipeline (Telegram → SQLite → Maps)
#
# This notebook builds an **end-to-end, fully automated OSINT incident analysis pipeline**.
#
# The goal is simple:
#
# ➡️ **Transform raw Telegram messages into geocoded, categorized global incidents and visualize them on an interactive map.**
#
# To achieve this, I designed a **6-agent architecture**, where each agent performs one specialized task—cleaning text, filtering incident relevance, deduping repeated reports, extracting categories/locations, geocoding them, and finally plotting everything in a global interactive viewer.
#
# This project demonstrates how **agentic workflows + geospatial intelligence** can scale real-time monitoring of conflict, disasters, law enforcement activity, and emerging threats.
#
# It also shows how real OSINT pipelines operate:
# structured, modular, resilient, and explainable.
#
# This notebook includes:
#
# - 🧹 **Agent 1:** Text cleaning
# - 🗺️ **Agent 2:** Geo-significance (incident or not?)
# - 🔁 **Agent 3:** Deduplication (remove repeated reports)
# - 🏷️ **Agent 4:** Category & location extraction
# - 📌 **Agent 5:** LLM-guided geocoding
# - 🗺️ **Agent 6:** Mapping + automated natural-language summary
#
# By the end, you will see:
#
# - a fully populated **incidents.db**
# - categorized, deduplicated, and geocoded incidents
# - a **global interactive map** of all incidents
# - an LLM-generated **narrative intelligence summary**
#
# Let’s begin by setting up the environment and configuration.

# %%
import os
import sqlite3
from datetime import datetime

from dotenv import load_dotenv
from pyrogram import Client

load_dotenv()

# ---- Telegram API creds ----
TG_API_ID = int(os.getenv("TG_API_ID"))
TG_API_HASH = os.getenv("TG_API_HASH")

if not TG_API_ID or not TG_API_HASH:
    raise RuntimeError("TG_API_ID / TG_API_HASH not set in environment/.env")

from pyrogram import Client
app = Client("my_account", api_id=TG_API_ID, api_hash=TG_API_HASH)


# ---- DB path ----
DB_PATH = "incidents.db"

# ---- Channels & days ----
CHANNELS = [-1001554189930, -1001964457167, -1001150168882, -1001407087072]

DAY_1 = "2025-11-27"
DAY_2 = "2025-11-28"
DAYS = {DAY_1, DAY_2}

LIMIT_PER_CHANNEL = 2000  # enough to cover two days

SCHEMA_SQL = """
CREATE TABLE IF NOT EXISTS events (
    id INTEGER PRIMARY KEY AUTOINCREMENT,

    -- Raw Telegram metadata
    chat_id INTEGER,
    message_id INTEGER,
    chat_title TEXT,
    date TEXT,           -- ISO timestamp
    text_raw TEXT,       -- original message text

    -- Cleaner Agent output
    text_clean TEXT,

    -- Geo-significance Agent
    checked INTEGER DEFAULT 0,   -- 0 = not checked, 1 = mappable, -1 = irrelevant

    -- Contextual Deduplicator Agent
    processed INTEGER DEFAULT 0, -- 0 = pending, 1 = canonical event, -1 = duplicate, -2 = bad_geo

    -- Category + Location Extractor
    category TEXT,
    location_text TEXT,

    -- Geocoding Agent
    lat REAL,
    lon REAL,

    UNIQUE(chat_id, message_id)
);
CREATE INDEX IF NOT EXISTS idx_chat_msg ON events(chat_id, message_id);
CREATE INDEX IF NOT EXISTS idx_date ON events(date);
CREATE INDEX IF NOT EXISTS idx_checked ON events(checked);
CREATE INDEX IF NOT EXISTS idx_processed ON events(processed);
"""

def init_db(path: str = DB_PATH):
    """Create incidents.db and events table if not present."""
    created = not os.path.exists(path)
    conn = sqlite3.connect(path, timeout=30)
    cur = conn.cursor()
    cur.executescript(SCHEMA_SQL)
    conn.commit()
    return conn, created

print("Config + schema ready. DB_PATH =", DB_PATH)
# Out:
# Config + schema ready. DB_PATH = incidents.db

# %% [markdown]
# # 🗄️ Database Schema: `incidents.db`
#
# All agents write to a single SQLite file named `events.db`.
#
# The core table is:
#
# ### **`events`**
#
# This table tracks every transformation as messages flow through the pipeline.
# It contains raw fields, cleaned fields, LLM outputs, geocoding outputs, and pipeline control flags.
#
# The schema is:
#
# | Column | Type | Meaning |
# |--------|------|---------|
# | **id** | INTEGER | Primary key |
# | **chat_id** | INTEGER | Telegram channel ID |
# | **message_id** | INTEGER | Telegram message ID (prevents duplicates) |
# | **chat_title** | TEXT | Channel name |
# | **date** | TEXT | ISO timestamp |
# | **text_raw** | TEXT | Original Telegram message |
# | **text_clean** | TEXT | Cleaner Agent output |
# | **checked** | INTEGER | Agent 2 output (1 = incident, -1 = ignore) |
# | **processed** | INTEGER | Agent 3 output (1 = canonical, -1 = duplicate, -2 = ungeocodable) |
# | **category** | TEXT | Agent 4 assigned category |
# | **location_text** | TEXT | Extracted geocodable location |
# | **lat** | REAL | Final geocoded latitude |
# | **lon** | REAL | Final geocoded longitude |

# %% [markdown]
# ## Fetch data from Telegram Channels
#
# Data is being extracted using Pyrogram from the following public channels for now. Their Channel IDs have already been initialized in the previous cell
# - ElitePredators
# - War and Gore
# - OsintTv
# - Resonant News

# %%
def row_in_days(date_str: str) -> bool:
    """Check if ISO timestamp like 2025-11-27T14:22:10 is in the two days."""
    if not date_str:
        return False
    try:
        day = date_str[:10]
        return day in DAYS
    except Exception:
        return False

async def fetch_history_from_telegram_async() -> list[dict]:
    """
    Async version: use async with Client and async for history.
    Filters to the two DAYS and returns a list of dicts.
    """
    messages: list[dict] = []

    async with app:
        for ch in CHANNELS:
            print(f"\n[Pyrogram] Fetching up to {LIMIT_PER_CHANNEL} messages from channel: {ch}")
            count_for_ch = 0

            try:
                # async generator
                async for msg in app.get_chat_history(ch, limit=LIMIT_PER_CHANNEL):
                    # date → ISO string
                    try:
                        iso_ts = msg.date.isoformat()
                    except Exception:
                        iso_ts = str(msg.date)

                    # only keep our two target days
                    if not row_in_days(iso_ts):
                        continue

                    # text content
                    text = msg.text or msg.caption or ""
                    if not text.strip():
                        # skip media-only messages
                        continue

                    chat_title = msg.chat.title if msg.chat else None

                    messages.append(
                        {
                            "chat_id": ch,
                            "message_id": msg.id,
                            "chat_title": chat_title,
                            "date": iso_ts,
                            "text_raw": text.strip(),
                        }
                    )
                    count_for_ch += 1

                print(f"[Pyrogram] Kept {count_for_ch} messages for {ch} within {DAYS}")

            except Exception as e:
                print(f"[Pyrogram] ERROR fetching channel {ch}: {e}")

    print(f"\n[Pyrogram] TOTAL messages in DAYS {DAYS}: {len(messages)}")
    return messages


def insert_messages_into_db(messages: list[dict], db_path: str = DB_PATH):
    """
    Insert fetched messages into incidents.db/events
    using INSERT OR IGNORE on (chat_id, message_id).
    """
    conn, created = init_db(db_path)
    cur = conn.cursor()
    inserted = 0
    skipped = 0

    for m in messages:
        try:
            cur.execute(
                """
                INSERT OR IGNORE INTO events (
                    chat_id, message_id, chat_title, date, text_raw,
                    text_clean, checked, processed, category, location_text,
                    lat, lon
                ) VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?)
                """,
                (
                    m["chat_id"],
                    m["message_id"],
                    m["chat_title"],
                    m["date"],
                    m["text_raw"],
                    None,   # text_clean
                    0,      # checked
                    0,      # processed
                    None,   # category
                    None,   # location_text
                    None,   # lat
                    None,   # lon
                ),
            )
            if cur.rowcount > 0:
                inserted += 1
            else:
                skipped += 1
        except Exception as e:
            print("ERROR on insert:", e)
            skipped += 1

    conn.commit()

    # quick summary
    cur.execute("SELECT COUNT(1) FROM events")
    total = cur.fetchone()[0]
    conn.close()

    print(f"[DB] Inserted: {inserted}, skipped (duplicates/errors): {skipped}")
    print(f"[DB] Total rows in events: {total}")
    return inserted, skipped

print("Fetch + insert helpers ready.")
# Out:
# Fetch + insert helpers ready.

# %%
messages = await fetch_history_from_telegram_async()
inserted, skipped = insert_messages_into_db(messages)
# Out:
# [Pyrogram] Fetching up to 2000 messages from channel: -1001554189930
# [Pyrogram] Kept 22 messages for -1001554189930 within {'2025-11-27', '2025-11-28'}
#
# [Pyrogram] Fetching up to 2000 messages from channel: -1001964457167
# [Pyrogram] Kept 31 messages for -1001964457167 within {'2025-11-27', '2025-11-28'}
#
# [Pyrogram] Fetching up to 2000 messages from channel: -1001150168882
# [Pyrogram] Kept 52 messages for -1001150168882 within {'2025-11-27', '2025-11-28'}
#
# [Pyrogram] Fetching up to 2000 messages from channel: -1001407087072
# [Pyrogram] Kept 37 messages for -1001407087072 within {'2025-11-27', '2025-11-28'}
#
# [Pyrogram] TOTAL messages in DAYS {'2025-11-27', '2025-11-28'}: 142
# [DB] Inserted: 142, skipped (duplicates/errors): 0
# [DB] Total rows in events: 142

# %%
import pandas as pd
conn = sqlite3.connect(DB_PATH)
pd.read_sql_query("SELECT chat_title, COUNT(*) as n FROM events GROUP BY chat_title", conn)
# Out:
#         chat_title   n
# 0   ElitePredators  52
# 1       OsintTV 📺️  22
# 2  Resonant News 📰  37
# 3       War & Gore  31

# %% [markdown]
# ---
#
# # 🧹 Agent 1 — Text Cleaner
# ### *Normalizing Real-World OSINT Into Machine-Readable Inputs*
#
# Telegram OSINT messages are messy. They contain emojis, hashtags, random spacing, repost headers, and channel-specific noise.
# Before running any intelligence workflow, we need **clean, predictable text**.
#
# Agent 1 performs:
#
# - Emoji + symbol removal
# - Newline normalization
# - Whitespace collapsing
# - Removal of channel signatures
# - Canonicalization of message format
#
# This stage is foundational:
# **Every downstream agent depends on high-quality cleaned text to make accurate decisions.**
#
# Below is the implementation of Agent 1.

# %%
'''
Agent 1 - Text cleaner
'''

import asyncio
from google.genai import types
from google.adk.agents import LlmAgent
from google.adk.models.google_llm import Gemini
from google.adk.runners import InMemoryRunner

retry_config = types.HttpRetryOptions(
    attempts=5,
    exp_base=7,
    initial_delay=1,
    http_status_codes=[429, 500, 503, 504]
)

CLEANING_SYSTEM_INSTRUCTIONS = """
You are an OSINT text cleaning assistant.

Your job:
- Remove ALL emojis, URLs, t.me links, @usernames, noisy hashtags, random unicode junk, stickers, and decorative icons
  'Forwarded from ...' headers, channel signatures, random unicode junk 'HEADLINES' that do not add info.
- Normalize whitespace.
- Do NOT translate, summarize, or add info.
Return ONLY the cleaned text.
""".strip()

def get_connection(db_path: str = DB_PATH) -> sqlite3.Connection:
    return sqlite3.connect(db_path)

def fetch_rows_to_clean(conn: sqlite3.Connection, limit: int = 32):
    cur = conn.cursor()
    cur.execute(
        """
        SELECT id, text_raw
        FROM events
        WHERE text_raw IS NOT NULL
          AND TRIM(text_raw) <> ''
          AND (text_clean IS NULL OR TRIM(text_clean) = '')
        ORDER BY id
        LIMIT ?
        """,
        (limit,)
    )
    return cur.fetchall()

def update_clean_text(conn: sqlite3.Connection, row_id: int, text_clean: str):
    cur = conn.cursor()
    cur.execute(
        "UPDATE events SET text_clean = ? WHERE id = ?",
        (text_clean, row_id)
    )

def build_cleaning_prompt(text_raw: str) -> str:
    return f"""
Clean the following Telegram OSINT message according to the rules.

RAW MESSAGE:
{text_raw}
""".strip()

def create_cleaner_agent() -> LlmAgent:
    agent = LlmAgent(
        name="Agent1_TextCleaner",
        model=Gemini(
            model="gemini-2.5-flash-lite",
            retry_options=retry_config,
        ),
        description="Cleans Telegram OSINT messages for a geospatial OSINT pipeline.",
        instruction=CLEANING_SYSTEM_INSTRUCTIONS,
        tools=[],  # no tools needed here
    )
    return agent

class CleanerLLM:
    def __init__(self, runner: InMemoryRunner):
        self.runner = runner

    async def call(self, prompt: str) -> str:
        events = await self.runner.run_debug(prompt)
        # find last assistant-like event
        for e in reversed(events):
            if getattr(e, "author", "") == "user":
                continue
            if getattr(e, "content", None) is None:
                continue
            parts = getattr(e.content, "parts", [])
            texts = [p.text for p in parts if hasattr(p, "text") and p.text]
            if texts:
                return "\n".join(texts).strip()
        return ""

async def run_cleaner_until_done(batch_size: int = 32):
    conn = get_connection(DB_PATH)
    agent = create_cleaner_agent()
    runner = InMemoryRunner(agent=agent)
    llm = CleanerLLM(runner)

    total = 0
    try:
        while True:
            rows = fetch_rows_to_clean(conn, limit=batch_size)
            if not rows:
                break
            for row_id, text_raw in rows:
                if not text_raw or not text_raw.strip():
                    continue
                prompt = build_cleaning_prompt(text_raw)
                try:
                    cleaned = await llm.call(prompt)
                except Exception as e:
                    print(f"[Cleaner] LLM error for id={row_id}: {e}")
                    cleaned = text_raw.strip()
                if not cleaned:
                    cleaned = text_raw.strip()
                update_clean_text(conn, row_id, cleaned)
            conn.commit()
            total += len(rows)
            print(f"[Cleaner] Processed batch of {len(rows)} rows (total={total}).")
    finally:
        conn.close()

    print(f"[Cleaner] Done. Total rows cleaned: {total}")

print("Agent 1 (Cleaner) ready.")
# Out:
# Agent 1 (Cleaner) ready.

# %%
await run_cleaner_until_done()
# Out:
# App name mismatch detected. The runner is configured with app name "InMemoryRunner", but the root agent was loaded from "C:\Users\Lenovo\Desktop\AgentAICourse\agentai_venv\Lib\site-packages\google\adk\agents", which implies app name "agents".
#  ### Created new session: debug_session_id
#
# User > Clean the following Telegram OSINT message according to the rules.
#
# RAW MESSAGE:
# 'Significant outcomes' expected as Putin to visit India
#
# Russian President Vladimir Putin will make a two-day visit to India from Dec 4 to hold annual summit talks with PM Narendra Modi that is expected to produce a plethora of significant outcomes, including in the DEFENCE SPHERE.
#
# PTI Report
# Agent1_TextCleaner > 'Significant outcomes' expected as Putin to visit India
#
# Russian President Vladimir Putin will make a two-day visit to India from Dec 4 to hold annual summit talks with PM Narendra Modi that is expected to produce a plethora of significant outcomes, including in the DEFENCE SPHERE.
#
# PTI Report
#
#  ### Continue session: debug_session_id
#
# User > Clean the following Telegram OSINT message according to the rules.
#
# RAW MESSAGE:
# India continues its strong support for the Afghan people.
#
# 73 tonnes of life-saving medicines, vaccines and essential supplements have been delivered to Kabul to meet urgent medical needs.
#
# Afghan sources
# Agent1_TextCleaner > India continues its strong support for the Afghan people.
#
# 73 tonnes of life-saving medicines, vaccines and essential supplements have been delivered to Kabul to meet urgent medical needs.
#
# Afghan sources
#
#  ### Continue session: debug_session_id
#
# User > Clean the following Telegram OSINT message according to the rules.
#
# RAW MESSAGE:
# 🚨🇵🇰🗣️🇦🇫🪖 Flash News :
#
# The ceasefire between Pak and Afghanistan will end soon. : PaK F.O
#
# "The Ceasefire between Pakistan and Afghan Taliban is not holding. The ceasefire does not imply a traditional ceasefire. The ceasefire implies that there will be no terrorist attack from Afghan sponsored terrorist proxies in Pakistan. Afghan Nationals and terrorist organisation are continuing with their attacks on Pakistan" : PaK Foreign Office spox
# Tahir Andrabi
# Agent1_TextCleaner > Flash News :
#
# The ceasefire between Pak and Afghanistan will end soon. : PaK F.O
#
# "The Ceasefire between Pakistan and Afghan Taliban is not holding. The ceasefire does not imply a traditional ceasefire. The ceasefire implies that there will be no terrorist attack from Afghan sponsored terrorist proxies in Pakistan. Afghan Nationals and terrorist organisation are continuing with their attacks on Pakistan" : PaK Foreign Office spox
# Tahir Andrabi
#
#  ### Continue session: debug_session_id
#
# User > Clean the following Telegram OSINT message according to the rules.
#
# RAW MESSAGE:
# A 33 minute long documentary has been released by rebel linked media on the attackers who killed Major Adnan from the SSG and other personnel in the attack on the Bannu FC lines.
# Agent1_TextCleaner > A 33 minute long documentary has been released by rebel linked media on the attackers who killed Major Adnan from the SSG and other personnel in the attack on the Bannu FC lines.
#
#  ### Continue session: debug_session_id
#
# User > Clean the following Telegram OSINT message according to the rules.
#
# RAW MESSAGE:
# As the attacks on pakistani military intensifies around 7 pakistani soldiers have resigned from the military duties : Sources
# Agent1_TextCleaner > As the attacks on pakistani military intensifies around 7 pakistani soldiers have resigned from the military duties : Sources
#
#  ### Continue session: debug_session_id
#
# User > Clean the following Telegram OSINT message according to the rules.
#
# RAW MESSAGE:
# Some unconfirmed reports claim Maulvi Izzatullah was targeted by ISIS due to his opposition to their activities. No official confirmation yet, but sources indicate his stance against extremist elements may have made him a target.
#
# Developing story...
# Agent1_TextCleaner > Some unconfirmed reports claim Maulvi Izzatullah was targeted by ISIS due to his opposition to their activities. No official confirmation yet, but sources indicate his stance against extremist elements may have made him a target.
#
# Developing story...
#
#  ### Continue session: debug_session_id
#
# User > Clean the following Telegram OSINT message according to the rules.
#
# RAW MESSAGE:
# 🚨Just in 🇵🇰:
#
# 📍Unknown gunmen shot and killed Maulvi Izzatullah and his son in Tajabad,  Pushtakhra area, Peshawar- KP -  Pakistan.
#
# 📍Police says the killers escaped. The bodies were sent for postmortem.
#
# 📍 The motive is not clear. The eliminated Salafist Maulvi is presumed to be linked to Lashkar e Taiba.
# Agent1_TextCleaner > Just in :
#
# Unknown gunmen shot and killed Maulvi Izzatullah and his son in Tajabad, Pushtakhra area, Peshawar- KP - Pakistan.
#
# Police says the killers escaped. The bodies were sent for postmortem.
#
# The motive is not clear. The eliminated Salafist Maulvi is presumed to be linked to Lashkar e Taiba.
#
#  ### Continue session: debug_session_id
#
# User > Clean the following Telegram OSINT message according to the rules.
#
# RAW MESSAGE:
# Pakistani army general retired because there was no more space to put up medals.
#
# Belly pe medal koun lagata hei 😝
#
# Jung tho kabhi jeete nahi, aur election kabhi haare nahi
#
# #sarcasm
# Agent1_TextCleaner > Pakistani army general retired because there was no more space to put up medals.
#
# Belly pe medal koun lagata hei
#
# Jung tho kabhi jeete nahi, aur election kabhi haare nahi
#
#  ### Continue session: debug_session_id
#
# User > Clean the following Telegram OSINT message according to the rules.
#
# RAW MESSAGE:
# Here is the another post abandoned by the pakistani military in the region.
# Agent1_TextCleaner > Here is the another post abandoned by the pakistani military in the region.
#
#  ### Continue session: debug_session_id
#
# User > Clean the following Telegram OSINT message according to the rules.
#
# RAW MESSAGE:
# Mungerilal ki haseen sapne....🤣
#
# PaK politician Syed Sardar Ali Shah claims "Gujarat, Haryana, Rajasthan are ours, we will prove it...."
#
# This comes after Indian Def Min Rajnath Singh's statement on Sindh...
# Agent1_TextCleaner > Mungerilal ki haseen sapne....
#
# PaK politician Syed Sardar Ali Shah claims "Gujarat, Haryana, Rajasthan are ours, we will prove it...."
#
# This comes after Indian Def Min Rajnath Singh's statement on Sindh...
#
#  ### Continue session: debug_session_id
#
# User > Clean the following Telegram OSINT message according to the rules.
#
# RAW MESSAGE:
# Under Field Marshal Asim Munir’s , the Pakistani Taliban are now walking straight into military bases across Khyber Pakhtunkhwa like they own the place.
#
# The army isn’t fighting back. Posts are being abandoned overnight, soldiers pulling out without a shot fired, leaving basesand weapons behind. The militants move in, film videos and set up checkpoints.
# Agent1_TextCleaner > Under Field Marshal Asim Munir’s , the Pakistani Taliban are now walking straight into military bases across Khyber Pakhtunkhwa like they own the place.
#
# The army isn’t fighting back. Posts are being abandoned overnight, soldiers pulling out without a shot fired, leaving basesand weapons behind. The militants move in, film videos and set up checkpoints.
#
#  ### Continue session: debug_session_id
#
# User > Clean the following Telegram OSINT message according to the rules.
#
# RAW MESSAGE:
# 🚨 As per pro rebel sources a massive attack was launched on the Police station in Bannu, KPK resulting in death of 7 police personals.
#
# Mean while pakistani side sources reported injuries to 5 police personals
# Agent1_TextCleaner > As per pro rebel sources a massive attack was launched on the Police station in Bannu, KPK resulting in death of 7 police personals.
#
# Mean while pakistani side sources reported injuries to 5 police personals
#
#  ### Continue session: debug_session_id
#
# User > Clean the following Telegram OSINT message according to the rules.
#
# RAW MESSAGE:
# 🚨🇮🇳🪖 Itna Bam Marenge Itna Bam Marenge.... Poora Ilaaka Dhuan Dhuan Hojyaga... 💥
#
#
# Note : Strong language
# Video credit on the visual
# Agent1_TextCleaner > Itna Bam Marenge Itna Bam Marenge.... Poora Ilaaka Dhuan Dhuan Hojyaga...
#
# Note : Strong language
# Video credit on the visual
#
#  ### Continue session: debug_session_id
#
# User > Clean the following Telegram OSINT message according to the rules.
#
# RAW MESSAGE:
# 🤣
# [Cleaner] LLM error for id=14: 'NoneType' object is not iterable
#
#  ### Continue session: debug_session_id
#
# User > Clean the following Telegram OSINT message according to the rules.
#
# RAW MESSAGE:
# Damn.... PaK punjab govt hikes traffic fines to PKR 15,000 😱.
#
# Looks like Pak govt decided to pay off IMF debt by issuing traffic challans 🤣.
#
# At this rate even a wrong U-turn will fund a full IMF installment.
#
# Squeeze the awam as much as you can till every challan turns into foreign exchange 🤣
#
# https://www.samaa.tv/2087342344-punjab-raises-traffic-fines-up-to-rs15-000-under-new-law
# Agent1_TextCleaner > Damn.... PaK punjab govt hikes traffic fines to PKR 15,000 .
#
# Looks like Pak govt decided to pay off IMF debt by issuing traffic challans .
#
# At this rate even a wrong U-turn will fund a full IMF installment.
#
# Squeeze the awam as much as you can till every challan turns into foreign exchange
#
#  ### Continue session: debug_session_id
#
# User > Clean the following Telegram OSINT message according to the rules.
#
# RAW MESSAGE:
# https://x.com/i/broadcasts/1OdJrOAWDXYxX?s=20
#
#
# Live telecast
# Agent1_TextCleaner > Live telecast
#
#  ### Continue session: debug_session_id
#
# User > Clean the following Telegram OSINT message according to the rules.
#
# RAW MESSAGE:
# 🚨 Just In:
#
# Iranian Supreme Leader Ayatollah Khamenei to deliver an unscheduled address to the nation tonight: Report
# Agent1_TextCleaner > Just In:
#
# Iranian Supreme Leader Ayatollah Khamenei to deliver an unscheduled address to the nation tonight: Report
#
#  ### Continue session: debug_session_id
#
# User > Clean the following Telegram OSINT message according to the rules.
#
# RAW MESSAGE:
# 🚨🇵🇰🪖🗣️ "Pakistan’s forces must be ready for future wars, the nature of threats now ranges from hybrid confrontation to full-scale war" : outgoing PaK army Gen Sahir Shamshad
# Agent1_TextCleaner > "Pakistan’s forces must be ready for future wars, the nature of threats now ranges from hybrid confrontation to full-scale war" : outgoing PaK army Gen Sahir Shamshad
#
#  ### Continue session: debug_session_id
#
# User > Clean the following Telegram OSINT message according to the rules.
#
# RAW MESSAGE:
# 🚨 Report 🇵🇰 :
#
# According to a new IMF report corruption and weak institutions continue to drag down Pakistan’s economy.
#
# 📍 IMF warns state-capture by political and business elites has dried public resources and crippled fair competition.
# 📍 Governance issues hit tax collection, public spending and investor trust.
# 📍 Even Pak Finance Minister Aurangzeb admits they now have to address every gap identified by the IMF
#
# He said "God willing, an agreement with the IMF will be reached, loan will be approved"
#
# How long PaK govt will feed the 'LAHORI CHURAN' to it's awam
# Agent1_TextCleaner > Report :
#
# According to a new IMF report corruption and weak institutions continue to drag down Pakistan’s economy.
#
# IMF warns state-capture by political and business elites has dried public resources and crippled fair competition.
# Governance issues hit tax collection, public spending and investor trust.
# Even Pak Finance Minister Aurangzeb admits they now have to address every gap identified by the IMF
#
# He said "God willing, an agreement with the IMF will be reached, loan will be approved"
#
# How long PaK govt will feed the 'LAHORI CHURAN' to it's awam
#
#  ### Continue session: debug_session_id
#
# User > Clean the following Telegram OSINT message according to the rules.
#
# RAW MESSAGE:
# 🚨🇵🇰 🪖According to TTP sources, reportedly rebels fired a homemade rocket at the Wali Noor PaK military camp in the Janikhel area of the Baka Khel subdivision.
#
# They shared a photo and said the video will be released soon.
# Agent1_TextCleaner > According to TTP sources, reportedly rebels fired a homemade rocket at the Wali Noor PaK military camp in the Janikhel area of the Baka Khel subdivision.
#
# They shared a photo and said the video will be released soon.
#
#  ### Continue session: debug_session_id
#
# User > Clean the following Telegram OSINT message according to the rules.
#
# RAW MESSAGE:
# Yesterday, on the sad occasion of 26/11, hundreds of Lashkar-e-Taiba-linked accounts and many Pakistani users celebrated the terror attack. They treated it as entertainment, with some even sharing cake-cutting videos for 26/11 while celebrating the killing of innocent Indians.
#
# This mindset is dangerous and sick. It shows how deep radicalisation has gone.
#
# • They treat mass murder as entertainment.
# • They praise the terrorists who carried out the killings.
# • They mock the pain of Indian families.
# • They expose the depth of extremist thinking in their circles.
#
# India remembers the victims. India stands firm against terrorism.
# Agent1_TextCleaner > Yesterday, on the sad occasion of 26/11, hundreds of Lashkar-e-Taiba-linked accounts and many Pakistani users celebrated the terror attack. They treated it as entertainment, with some even sharing cake-cutting videos for 26/11 while celebrating the killing of innocent Indians.
#
# This mindset is dangerous and sick. It shows how deep radicalisation has gone.
#
# • They treat mass murder as entertainment.
# • They praise the terrorists who carried out the killings.
# • They mock the pain of Indian families.
# • They expose the depth of extremist thinking in their circles.
#
# India remembers the victims. India stands firm against terrorism.
#
#  ### Continue session: debug_session_id
#
# User > Clean the following Telegram OSINT message according to the rules.
#
# RAW MESSAGE:
# BLA says Four Pakistani Army Personnel Eliminated in Panjgur Attack .
# Agent1_TextCleaner > BLA says Four Pakistani Army Personnel Eliminated in Panjgur Attack .
#
#  ### Continue session: debug_session_id
#
# User > Clean the following Telegram OSINT message according to the rules.
#
# RAW MESSAGE:
# National Defence Academy during Monsoon
# Agent1_TextCleaner > National Defence Academy during Monsoon
#
#  ### Continue session: debug_session_id
#
# User > Clean the following Telegram OSINT message according to the rules.
#
# RAW MESSAGE:
# This is the 4th attempt by PLA in the same area in the last few years. The last 3 attempts were thwarted.
# Agent1_TextCleaner > This is the 4th attempt by PLA in the same area in the last few years. The last 3 attempts were thwarted.
#
#  ### Continue session: debug_session_id
#
# User > Clean the following Telegram OSINT message according to the rules.
#
# RAW MESSAGE:
# Correction-
#
# This attack is done by People's liberation Army (PLA) insurgent group. PLA is valley based insurgent group(VBIG)- Meitei.
# Agent1_TextCleaner > Correction-
#
# This attack is done by People's liberation Army (PLA) insurgent group. PLA is valley based insurgent group(VBIG)- Meitei.
#
#  ### Continue session: debug_session_id
#
# User > Clean the following Telegram OSINT message according to the rules.
#
# RAW MESSAGE:
# Hong Kong Fire incident:
#
# Death toll reaches 128.
# Agent1_TextCleaner > Hong Kong Fire incident:
#
# Death toll reaches 128.
#
#  ### Continue session: debug_session_id
#
# User > Clean the following Telegram OSINT message according to the rules.
#
# RAW MESSAGE:
# Statement from officials -A patrolling party of Assam Rifles was fired upon by terrorists in Tengnoupal district of Manipur, along the India-Myanmar Border in the early morning hours today. Operations are currently underway, with additional troops being deployed into the area.
# Agent1_TextCleaner > Statement from officials -A patrolling party of Assam Rifles was fired upon by terrorists in Tengnoupal district of Manipur, along the India-Myanmar Border in the early morning hours today. Operations are currently underway, with additional troops being deployed into the area.
#
#  ### Continue session: debug_session_id
#
# User > Clean the following Telegram OSINT message according to the rules.
#
# RAW MESSAGE:
# The trio reportedly took food from a local in Chilla Balotha village.
# Agent1_TextCleaner > The trio reportedly took food from a local in Chilla Balotha village.
#
#  ### Continue session: debug_session_id
#
# User > Clean the following Telegram OSINT message according to the rules.
#
# RAW MESSAGE:
# Udhampur:Security forces have launched a major search operation in Basantgarh after movement of three suspected terrorists.
# Agent1_TextCleaner > Udhampur:Security forces have launched a major search operation in Basantgarh after movement of three suspected terrorists.
#
#  ### Continue session: debug_session_id
#
# User > Clean the following Telegram OSINT message according to the rules.
#
# RAW MESSAGE:
# Manipur: Reportedly PLA Terrorists attacked post BP-87
# in Tengnoupal (Manipur) around 4:30 am. 4 jawans are said to be injured.
# Agent1_TextCleaner > Manipur: Reportedly PLA Terrorists attacked post BP-87
# in Tengnoupal (Manipur) around 4:30 am. 4 jawans are said to be injured.
#
#  ### Continue session: debug_session_id
#
# User > Clean the following Telegram OSINT message according to the rules.
#
# RAW MESSAGE:
# Kremlin:
#
# On December 4–5, Vladimir Putin will make a state visit to India at the invitation of Indian Prime Minister Narendra Modi
# Agent1_TextCleaner > Kremlin:
#
# On December 4–5, Vladimir Putin will make a state visit to India at the invitation of Indian Prime Minister Narendra Modi
#
#  ### Continue session: debug_session_id
#
# User > Clean the following Telegram OSINT message according to the rules.
#
# RAW MESSAGE:
# UN urges Pakistan to 'fully uphold' Imran Khan's rights amid growing concern over jailed ex-PM's welfare
# Agent1_TextCleaner > UN urges Pakistan to 'fully uphold' Imran Khan's rights amid growing concern over jailed ex-PM's welfare
# [Cleaner] Processed batch of 32 rows (total=32).
#
#  ### Continue session: debug_session_id
#
# User > Clean the following Telegram OSINT message according to the rules.
#
# RAW MESSAGE:
# NOTAM range extended to 3,485-km
# Agent1_TextCleaner > NOTAM range extended to 3,485-km
#
#  ### Continue session: debug_session_id
#
# User > Clean the following Telegram OSINT message according to the rules.
#
# RAW MESSAGE:
# Reportedly RPG attack on a FC post
# Agent1_TextCleaner > Reportedly RPG attack on a FC post
#
#  ### Continue session: debug_session_id
#
# User > Clean the following Telegram OSINT message according to the rules.
#
# RAW MESSAGE:
# Massive explosion in Wana South Waziristan
# Agent1_TextCleaner > Massive explosion in Wana South Waziristan
#
#  ### Continue session: debug_session_id
#
# User > Clean the following Telegram OSINT message according to the rules.
#
# RAW MESSAGE:
# Australia's Foreign Minister Penny Wong today announced that the Islamic Revolutionary Guard Corps (IRGC) has been officially designated as a state sponsor of terrorism by the Australian government. The listing, under Australia's counter-terrorism framework, means the IRGC is formally recognized as supporting terrorist activity, triggering stricter legal and financial measures against it.
# Agent1_TextCleaner > Australia's Foreign Minister Penny Wong today announced that the Islamic Revolutionary Guard Corps (IRGC) has been officially designated as a state sponsor of terrorism by the Australian government. The listing, under Australia's counter-terrorism framework, means the IRGC is formally recognized as supporting terrorist activity, triggering stricter legal and financial measures against it.
#
#  ### Continue session: debug_session_id
#
# User > Clean the following Telegram OSINT message according to the rules.
#
# RAW MESSAGE:
# A quadcopter drone attack on a police post in Bannu district, Khyber Pakhtunkhwa province has injured two policemen: Police
# Agent1_TextCleaner > A quadcopter drone attack on a police post in Bannu district, Khyber Pakhtunkhwa province has injured two policemen: Police
#
#  ### Continue session: debug_session_id
#
# User > Clean the following Telegram OSINT message according to the rules.
#
# RAW MESSAGE:
# :)
# [Cleaner] LLM error for id=38: 'NoneType' object is not iterable
#
#  ### Continue session: debug_session_id
#
# User > Clean the following Telegram OSINT message according to the rules.
#
# RAW MESSAGE:
# TOI:India's plan to acquire another five squad-rons of the S-400 Triumf air defence systems as well as a large number of its surface-to-air missiles for already in-ducted systems, which per-formed exceedingly well during Operation Sindoor, are likely to figure in discus-sions during the Modi-Putin summit here on Dec 5.
# Agent1_TextCleaner > TOI:India's plan to acquire another five squad-rons of the S-400 Triumf air defence systems as well as a large number of its surface-to-air missiles for already in-ducted systems, which per-formed exceedingly well during Operation Sindoor, are likely to figure in discus-sions during the Modi-Putin summit here on Dec 5.
#
#  ### Continue session: debug_session_id
#
# User > Clean the following Telegram OSINT message according to the rules.
#
# RAW MESSAGE:
# American strategist Bruce Reidel had pointed out years ago that there was a third party behind the 26/11 attacks besides Pakistan’s ISI and Lashkar-e-Taiba (LeT). Reidel said that it was al-Qaeda, which had its own reasons for supporting that attack. He had argued that al-Qaeda deliberately kept a low profile and allowed LeT to select the Mumbai targets, making it appear that it was purely an Indo-Pak issue.
#
# Reidel also added that LeT had planned a big attack on New Delhi during the 2010 Commonwealth Games, which “was thwarted by prompt intelligence from the British services.”
# Agent1_TextCleaner > American strategist Bruce Reidel had pointed out years ago that there was a third party behind the 26/11 attacks besides Pakistan’s ISI and Lashkar-e-Taiba (LeT). Reidel said that it was al-Qaeda, which had its own reasons for supporting that attack. He had argued that al-Qaeda deliberately kept a low profile and allowed LeT to select the Mumbai targets, making it appear that it was purely an Indo-Pak issue.
#
# Reidel also added that LeT had planned a big attack on New Delhi during the 2010 Commonwealth Games, which “was thwarted by prompt intelligence from the British services.”
#
#  ### Continue session: debug_session_id
#
# User > Clean the following Telegram OSINT message according to the rules.
#
# RAW MESSAGE:
# WSJ: After a tense call with China’s leader Xi Jinping, President Trump phoned Japanese Prime Minister Sanae Takaichi and urged her to soften her tone on Taiwan.
# Agent1_TextCleaner > WSJ: After a tense call with China’s leader Xi Jinping, President Trump phoned Japanese Prime Minister Sanae Takaichi and urged her to soften her tone on Taiwan.
#
#  ### Continue session: debug_session_id
#
# User > Clean the following Telegram OSINT message according to the rules.
#
# RAW MESSAGE:
# You'll reap what you sow
#
# He was working with CIA in Afghanistan.
# Agent1_TextCleaner > You'll reap what you sow
#
# He was working with CIA in Afghanistan.
#
#  ### Continue session: debug_session_id
#
# User > Clean the following Telegram OSINT message according to the rules.
#
# RAW MESSAGE:
# He was part of The Zero One unit that was formed by American intelligence in Afghanistan.
# Name- Rahmanullah Laknwal
# Agent1_TextCleaner > He was part of The Zero One unit that was formed by American intelligence in Afghanistan.
# Name- Rahmanullah Laknwal
#
#  ### Continue session: debug_session_id
#
# User > Clean the following Telegram OSINT message according to the rules.
#
# RAW MESSAGE:
# When USA left Afghanistan, that so called Afghan army led by President Ashraf Ghani & fully funded by US and supported by Paijaan army 🇵🇰, collapsed within hours & Taliban took over Afghanistan.
# Agent1_TextCleaner > When USA left Afghanistan, that so called Afghan army led by President Ashraf Ghani & fully funded by US and supported by Paijaan army collapsed within hours & Taliban took over Afghanistan.
#
#  ### Continue session: debug_session_id
#
# User > Clean the following Telegram OSINT message according to the rules.
#
# RAW MESSAGE:
# Interestingly that specific Afghan national has fought war against Taliban along with US Special forces. He was reportedly part of Afghan army that was working with Pak army & American Army.
# Agent1_TextCleaner > Interestingly that specific Afghan national has fought war against Taliban along with US Special forces. He was reportedly part of Afghan army that was working with Pak army & American Army.
#
#  ### Continue session: debug_session_id
#
# User > Clean the following Telegram OSINT message according to the rules.
#
# RAW MESSAGE:
# Yesterday two national guards 🇺🇸were shot dead by an Afghan national near White house.
# Agent1_TextCleaner > Yesterday two national guards were shot dead by an Afghan national near White house.
#
#  ### Continue session: debug_session_id
#
# User > Clean the following Telegram OSINT message according to the rules.
#
# RAW MESSAGE:
# 24 years old Pakistani intruder arrested from Barmer Rajasthan.
# Agent1_TextCleaner > 24 years old Pakistani intruder arrested from Barmer Rajasthan.
#
#  ### Continue session: debug_session_id
#
# User > Clean the following Telegram OSINT message according to the rules.
#
# RAW MESSAGE:
# "Pakiatan's arms shopping post Operation Sindoor matter of concern" - Commanding-in-Chief Western Naval command Vice Admiral K Swaminathan.
# Agent1_TextCleaner > "Pakiatan's arms shopping post Operation Sindoor matter of concern" - Commanding-in-Chief Western Naval command Vice Admiral K Swaminathan.
#
#  ### Continue session: debug_session_id
#
# User > Clean the following Telegram OSINT message according to the rules.
#
# RAW MESSAGE:
# 11 killed as train hits railway workers in southwest China.
# Agent1_TextCleaner > 11 killed as train hits railway workers in southwest China.
#
#  ### Continue session: debug_session_id
#
# User > Clean the following Telegram OSINT message according to the rules.
#
# RAW MESSAGE:
# Hong Kong Fire incident:
#
# 42 people died & 280+ are said to be Injured/missing.
# Agent1_TextCleaner > Hong Kong Fire incident:
#
# 42 people died & 280+ are said to be Injured/missing.
#
#  ### Continue session: debug_session_id
#
# User > Clean the following Telegram OSINT message according to the rules.
#
# RAW MESSAGE:
# Afghanistan has given Indian firms a 5-year tax break for investing in gold mining. Due to trade issues with Pakistan, Indian investors get a chance with low competition and only 1% duty on investments, says Minister Nooruddin.
# Agent1_TextCleaner > Afghanistan has given Indian firms a 5-year tax break for investing in gold mining. Due to trade issues with Pakistan, Indian investors get a chance with low competition and only 1% duty on investments, says Minister Nooruddin.
#
#  ### Continue session: debug_session_id
#
# User > Clean the following Telegram OSINT message according to the rules.
#
# RAW MESSAGE:
# PAF jet activities over Peshawar ✈️
# Agent1_TextCleaner > PAF jet activities over Peshawar
#
#  ### Continue session: debug_session_id
#
# User > Clean the following Telegram OSINT message according to the rules.
#
# RAW MESSAGE:
# Looks like Afghanistan has conducted drone strikes in Pakistan.
# Agent1_TextCleaner > Looks like Afghanistan has conducted drone strikes in Pakistan.
#
#  ### Continue session: debug_session_id
#
# User > Clean the following Telegram OSINT message according to the rules.
#
# RAW MESSAGE:
# Maoists responsible for the IED blast in Jharkhand.
# Agent1_TextCleaner > Maoists responsible for the IED blast in Jharkhand.
#
#  ### Continue session: debug_session_id
#
# User > Clean the following Telegram OSINT message according to the rules.
#
# RAW MESSAGE:
# Paxtan will burn... Damn
# Agent1_TextCleaner > Paxtan will burn... Damn
#
#  ### Continue session: debug_session_id
#
# User > Clean the following Telegram OSINT message according to the rules.
#
# RAW MESSAGE:
# Chief Economic Adviser, V Anantha Nageswaran :
# GDP growth may surpass 7 pc to cross USD 4 tn in FY26.
# Agent1_TextCleaner > Chief Economic Adviser, V Anantha Nageswaran :
# GDP growth may surpass 7 pc to cross USD 4 tn in FY26.
#
#  ### Continue session: debug_session_id
#
# User > Clean the following Telegram OSINT message according to the rules.
#
# RAW MESSAGE:
# Woman killed, two others injured in IED blast in Jharkhand''s Chaibasa: Police
#
# ~PTI
# Agent1_TextCleaner > Woman killed, two others injured in IED blast in Jharkhand''s Chaibasa: Police
#
# ~ PTI
#
#  ### Continue session: debug_session_id
#
# User > Clean the following Telegram OSINT message according to the rules.
#
# RAW MESSAGE:
# India's GDP grew by 8.2% in the 2nd Quarter of this financial year.
#
# This growth is despite tarrifs by Trump, and the fact that GST cut was available only for a week in this quarter (September end)
# Golden days ahead 💫
# Agent1_TextCleaner > India's GDP grew by 8.2% in the 2nd Quarter of this financial year.
#
# This growth is despite tarrifs by Trump, and the fact that GST cut was available only for a week in this quarter (September end)
# Golden days ahead
#
#  ### Continue session: debug_session_id
#
# User > Clean the following Telegram OSINT message according to the rules.
#
# RAW MESSAGE:
# National Defence Academy
# Agent1_TextCleaner > National Defence Academy
#
#  ### Continue session: debug_session_id
#
# User > Clean the following Telegram OSINT message according to the rules.
#
# RAW MESSAGE:
# Pakistan: Maulana Qari Izzatullah was shot dead near University Town a short while ago, according to local sources.
#
# The attackers have not yet been identified, and police have launched an investigation into the incident.
# Agent1_TextCleaner > Pakistan: Maulana Qari Izzatullah was shot dead near University Town a short while ago, according to local sources.
#
# The attackers have not yet been identified, and police have launched an investigation into the incident.
#
#  ### Continue session: debug_session_id
#
# User > Clean the following Telegram OSINT message according to the rules.
#
# RAW MESSAGE:
# 1. Cyclone Ditwah has hit Sri Lanka, causing major loss of life and destruction.
#
# 2. India launched Operation Sagar Bandhu to provide urgent HADR support to its closest maritime neighbour.
#
# 3. INS Vikrant and INS Udaigiri delivered the first relief supplies to Colombo.
#
# 4. The mission reflects India’s Neighbourhood First and SAGAR vision, with PM Modi and EAM Dr. S. Jaishankar assuring full support to Sri Lanka.
# Agent1_TextCleaner > 1. Cyclone Ditwah has hit Sri Lanka, causing major loss of life and destruction.
#
# 2. India launched Operation Sagar Bandhu to provide urgent HADR support to its closest maritime neighbour.
#
# 3. INS Vikrant and INS Udaigiri delivered the first relief supplies to Colombo.
#
# 4. The mission reflects India’s Neighbourhood First and SAGAR vision, with PM Modi and EAM Dr. S. Jaishankar assuring full support to Sri Lanka.
#
#  ### Continue session: debug_session_id
#
# User > Clean the following Telegram OSINT message according to the rules.
#
# RAW MESSAGE:
# Khyber PakhtunKhwa
#
#
# The injured soldier of Frontier constabulary succumbed to his injuries in hospital.
# Agent1_TextCleaner > Khyber PakhtunKhwa
#
# The injured soldier of Frontier constabulary succumbed to his injuries in hospital.
#
#  ### Continue session: debug_session_id
#
# User > Clean the following Telegram OSINT message according to the rules.
#
# RAW MESSAGE:
# Nepal Reignites the Border dispute with Bharat:
#
# Nepal’s central bank unveiled new Rs 100 currency notes featuring a revised national map that includes the disputed Kalapani, Lipulekh, and Limpiyadhura regions, territories India has long maintained are its own.
#
# The redesigned currency incorporates the updated national map adopted during the K P Sharma Oli–led government, to include Kalapani, Lipulekh, and Limpiyadhura.
# Agent1_TextCleaner > Nepal Reignites the Border dispute with Bharat:
#
# Nepal’s central bank unveiled new Rs 100 currency notes featuring a revised national map that includes the disputed Kalapani, Lipulekh, and Limpiyadhura regions, territories India has long maintained are its own.
#
# The redesigned currency incorporates the updated national map adopted during the K P Sharma Oli–led government, to include Kalapani, Lipulekh, and Limpiyadhura.
#
#  ### Continue session: debug_session_id
#
# User > Clean the following Telegram OSINT message according to the rules.
#
# RAW MESSAGE:
# 𝗜𝘀𝗿𝗮𝗲𝗹𝗶 𝗳𝗼𝗿𝗰𝗲𝘀 carried out an incursion into the Syrian town of Beit Jinn in 𝗿𝘂𝗿𝗮𝗹 𝗗𝗮𝗺𝗮𝘀𝗰𝘂𝘀.
#
# Clashes reported between 𝗹𝗼𝗰𝗮𝗹 𝗿𝗲𝘀𝗶𝗱𝗲𝗻𝘁𝘀 and the troops, wherein IDF reportedly used artilleries and drones.
# Agent1_TextCleaner > Israeli forces carried out an incursion into the Syrian town of Beit Jinn in rural Damascus.
#
# Clashes reported between local residents and the troops, wherein IDF reportedly used artilleries and drones.
# [Cleaner] Processed batch of 32 rows (total=64).
#
#  ### Continue session: debug_session_id
#
# User > Clean the following Telegram OSINT message according to the rules.
#
# RAW MESSAGE:
# The NOTAM for a likely missile test over the Bay of Bengal, scheduled from December 6 to 8, has been cancelled.
# Agent1_TextCleaner > The NOTAM for a likely missile test over the Bay of Bengal, scheduled from December 6 to 8, has been cancelled.
#
#  ### Continue session: debug_session_id
#
# User > Clean the following Telegram OSINT message according to the rules.
#
# RAW MESSAGE:
# MEA Press Release
# Agent1_TextCleaner > MEA Press Release
#
#  ### Continue session: debug_session_id
#
# User > Clean the following Telegram OSINT message according to the rules.
#
# RAW MESSAGE:
# Bannu Police station attack responsibility
# Agent1_TextCleaner > Bannu Police station attack responsibility
#
#  ### Continue session: debug_session_id
#
# User > Clean the following Telegram OSINT message according to the rules.
#
# RAW MESSAGE:
# On Friday, November 28, at midnight, the Mujahideen of the Pakistan Revolution Movement and the Burr and Jamaat jointly launched a counterattack on the Domail Ahmadzai police station. With the grace of Allah, the Mujahideen displayed great courage and captured the police station. During this time, more police and army troops also arrived from Bannu, with whom a fierce battle ensued. Alhamdulillah, according to reliable reports, several anti-Sharia police officers were killed and injured in this battle.
#
# Maulvi Ismail Khan, spokesman for the Pakistan Revolution
# Agent1_TextCleaner > On Friday, November 28, at midnight, the Mujahideen of the Pakistan Revolution Movement and the Burr and Jamaat jointly launched a counterattack on the Domail Ahmadzai police station. With the grace of Allah, the Mujahideen displayed great courage and captured the police station. During this time, more police and army troops also arrived from Bannu, with whom a fierce battle ensued. Alhamdulillah, according to reliable reports, several anti-Sharia police officers were killed and injured in this battle.
#
# Maulvi Ismail Khan, spokesman for the Pakistan Revolution
#
#  ### Continue session: debug_session_id
#
# User > Clean the following Telegram OSINT message according to the rules.
#
# RAW MESSAGE:
# The distance for the NOTAM has been extended further to approximately 3485 km (1882 NM).
# Agent1_TextCleaner > The distance for the NOTAM has been extended further to approximately 3485 km (1882 NM).
#
#  ### Continue session: debug_session_id
#
# User > Clean the following Telegram OSINT message according to the rules.
#
# RAW MESSAGE:
# She absolutely cooked him.
# Correction: Obliterated him.
#
# Credits: China Insider with David Zhang
# Agent1_TextCleaner > She absolutely cooked him.
# Correction: Obliterated him.
#
# Credits: China Insider with David Zhang
#
#  ### Continue session: debug_session_id
#
# User > Clean the following Telegram OSINT message according to the rules.
#
# RAW MESSAGE:
# Zydus Life signed a MoU worth $100 million with Kabul-based Raoufi Group
# Agent1_TextCleaner > Zydus Life signed a MoU worth $100 million with Kabul-based Raoufi Group
#
#  ### Continue session: debug_session_id
#
# User > Clean the following Telegram OSINT message according to the rules.
#
# RAW MESSAGE:
# Good morning
#
#
# https://indianexpress.com/article/india/days-after-hidmas-death-84-maoists-with-a-bounty-of-rs-2-56-crore-surrender-10389143/
# Agent1_TextCleaner > Good morning
#
#  ### Continue session: debug_session_id
#
# User > Clean the following Telegram OSINT message according to the rules.
#
# RAW MESSAGE:
# Tajikistan MFA: "Three Chinese workers were killed in a drone strike from Afghanistan."
# Agent1_TextCleaner > Tajikistan MFA: "Three Chinese workers were killed in a drone strike from Afghanistan."
#
#  ### Continue session: debug_session_id
#
# User > Clean the following Telegram OSINT message according to the rules.
#
# RAW MESSAGE:
# A Pakistani spy identified as Farman son of Shah Jan, resident of Mohabbat Khel, who was involved in the killing of several rebels was executed by TTP rebels after he confessed to the crime.
# Agent1_TextCleaner > A Pakistani spy identified as Farman son of Shah Jan, resident of Mohabbat Khel, who was involved in the killing of several rebels was executed by TTP rebels after he confessed to the crime.
#
#  ### Continue session: debug_session_id
#
# User > Clean the following Telegram OSINT message according to the rules.
#
# RAW MESSAGE:
# A loud explosion has been heard in Wana, South Waziristan
# Agent1_TextCleaner > A loud explosion has been heard in Wana, South Waziristan
#
#  ### Continue session: debug_session_id
#
# User > Clean the following Telegram OSINT message according to the rules.
#
# RAW MESSAGE:
# Multiple dm in such a short time🙂
#
#
# Look like we need a special team for this
# Agent1_TextCleaner > Multiple dm in such a short time
#
# Look like we need a special team for this
#
#  ### Continue session: debug_session_id
#
# User > Clean the following Telegram OSINT message according to the rules.
#
# RAW MESSAGE:
# If you come across any online terror suspicious activity, extremist content, recruitment attempts online and you’re unsure about approaching the authorities directly you can confidentially forward the details to the Elitepredators admin.
#
#
# Your identity will always remain private. Even a small tip can prevent a larger threat.
#
#
#
# Report & don’t ignore.
#
#
#
# Contact us: @Contact_ep
# Agent1_TextCleaner > If you come across any online terror suspicious activity, extremist content, recruitment attempts online and you’re unsure about approaching the authorities directly you can confidentially forward the details to the Elitepredators admin.
#
# Your identity will always remain private. Even a small tip can prevent a larger threat.
#
# Report & don’t ignore.
#
# Contact us: @Contact_ep
#
#  ### Continue session: debug_session_id
#
# User > Clean the following Telegram OSINT message according to the rules.
#
# RAW MESSAGE:
# India plans to acquire 5 more S-400 Triumf air defence squadrons and additional surface to air missiles for existing systems. These topics are expected at the Modi-Putin summit on Dec 5.
#
# The PM-led CCS will also approve a ₹63,000 crore upgrade for 84 Sukhoi-30MKI fighters, enhancing radars, avionics, and weapons to extend their combat life by 30 years. The upgrade will be mostly indigenous, with some Russian involvement.
# Agent1_TextCleaner > India plans to acquire 5 more S-400 Triumf air defence squadrons and additional surface to air missiles for existing systems. These topics are expected at the Modi-Putin summit on Dec 5.
#
# The PM-led CCS will also approve a ₹63,000 crore upgrade for 84 Sukhoi-30MKI fighters, enhancing radars, avionics, and weapons to extend their combat life by 30 years. The upgrade will be mostly indigenous, with some Russian involvement.
#
#  ### Continue session: debug_session_id
#
# User > Clean the following Telegram OSINT message according to the rules.
#
# RAW MESSAGE:
# Trump told Japan's PM to lower the volume on Taiwan.
#
# Trump spoke with Takaichi after Xi Jinping called the U.S. president and spoke about China's historic claim to the democratic self-governing island as well as Washington and Beijing’s joint responsibility to manage the world order.
# Agent1_TextCleaner > Trump told Japan's PM to lower the volume on Taiwan.
#
# Trump spoke with Takaichi after Xi Jinping called the U.S. president and spoke about China's historic claim to the democratic self-governing island as well as Washington and Beijing’s joint responsibility to manage the world order.
#
#  ### Continue session: debug_session_id
#
# User > Clean the following Telegram OSINT message according to the rules.
#
# RAW MESSAGE:
# The NOTAM near the Andaman & Nicobar Islands for a likely missile test has been rescheduled to December 1–3.
# Agent1_TextCleaner > The NOTAM near the Andaman & Nicobar Islands for a likely missile test has been rescheduled to December 1–3.
#
#  ### Continue session: debug_session_id
#
# User > Clean the following Telegram OSINT message according to the rules.
#
# RAW MESSAGE:
# Peene ke liye paani nahi, khaane ke liye aata nahi hai...
#
# Par bhikh se aayaa paisa bohot hai...
# Agent1_TextCleaner > Peene ke liye paani nahi, khaane ke liye aata nahi hai...
#
# Par bhikh se aayaa paisa bohot hai...
#
#  ### Continue session: debug_session_id
#
# User > Clean the following Telegram OSINT message according to the rules.
#
# RAW MESSAGE:
# India has issued a NOTAM for Indian Air Force exercises near the western border in Rajasthan.
#
# IAF Exercises [ Dec 3 - Dec 6]
# Agent1_TextCleaner > India has issued a NOTAM for Indian Air Force exercises near the western border in Rajasthan.
#
# IAF Exercises [ Dec 3 - Dec 6]
#
#  ### Continue session: debug_session_id
#
# User > Clean the following Telegram OSINT message according to the rules.
#
# RAW MESSAGE:
# The Biggest Attack Planned in India Averted!
#
# https://youtube.com/shorts/T_PHrDHyBFk
# Agent1_TextCleaner > The Biggest Attack Planned in India Averted!
#
#  ### Continue session: debug_session_id
#
# User > Clean the following Telegram OSINT message according to the rules.
#
# RAW MESSAGE:
# Safran and DRDO to develop a new engine together in India.
# Agent1_TextCleaner > Safran and DRDO to develop a new engine together in India.
#
#  ### Continue session: debug_session_id
#
# User > Clean the following Telegram OSINT message according to the rules.
#
# RAW MESSAGE:
# Jammu Police arrested a 19-year-old Reasi native living in Bathindi, a key suspect in FIR 331/2025 u/s 113(3) BNS at PS Bahu Fort. He was allegedly radicalised online and in contact with foreign numbers. His digital devices were seized, and investigation continues.
# Agent1_TextCleaner > Jammu Police arrested a 19-year-old Reasi native living in Bathindi, a key suspect in FIR 331/2025 u/s 113(3) BNS at PS Bahu Fort. He was allegedly radicalised online and in contact with foreign numbers. His digital devices were seized, and investigation continues.
#
#  ### Continue session: debug_session_id
#
# User > Clean the following Telegram OSINT message according to the rules.
#
# RAW MESSAGE:
# Back to work
#
# Now regular posting on EP Insight
# Agent1_TextCleaner > Back to work
#
# Now regular posting on EP Insight
#
#  ### Continue session: debug_session_id
#
# User > Clean the following Telegram OSINT message according to the rules.
#
# RAW MESSAGE:
# https://x.com/EPINSIGHTS/status/1993940649109016602
# [Cleaner] LLM error for id=87: 'NoneType' object is not iterable
#
#  ### Continue session: debug_session_id
#
# User > Clean the following Telegram OSINT message according to the rules.
#
# RAW MESSAGE:
# The Family man Season 3
#
# Full time waste💔
# Agent1_TextCleaner > The Family man Season 3
#
# Full time waste
#
#  ### Continue session: debug_session_id
#
# User > Clean the following Telegram OSINT message according to the rules.
#
# RAW MESSAGE:
# India is now projected to become a $5 trillion economy only in FY29, a year later than previously estimated, according to the IMF's latest staff consultation report released on November 26.
# Agent1_TextCleaner > India is now projected to become a $5 trillion economy only in FY29, a year later than previously estimated, according to the IMF's latest staff consultation report released on November 26.
#
#  ### Continue session: debug_session_id
#
# User > Clean the following Telegram OSINT message according to the rules.
#
# RAW MESSAGE:
# Dominican Republic has authorized the US to use its air bases.
# Agent1_TextCleaner > Dominican Republic has authorized the US to use its air bases.
#
#  ### Continue session: debug_session_id
#
# User > Clean the following Telegram OSINT message according to the rules.
#
# RAW MESSAGE:
# US Special Forces launched a ground operation against the Islamic State of the Somalia Province (ISSP), in the Baalade Valley, Puntland, Somalia.
#
# Violent clashes erupted between the US troops and ISSP in the Cal-Miskaad mountain range.
#
# At least 100 US SF personnel were carrying out the ground operation.
# Agent1_TextCleaner > US Special Forces launched a ground operation against the Islamic State of the Somalia Province (ISSP), in the Baalade Valley, Puntland, Somalia.
#
# Violent clashes erupted between the US troops and ISSP in the Cal-Miskaad mountain range.
#
# At least 100 US SF personnel were carrying out the ground operation.
#
#  ### Continue session: debug_session_id
#
# User > Clean the following Telegram OSINT message according to the rules.
#
# RAW MESSAGE:
# Two US National Guard members were shot near the White House in an apparent ambush.
# Agent1_TextCleaner > Two US National Guard members were shot near the White House in an apparent ambush.
#
#  ### Continue session: debug_session_id
#
# User > Clean the following Telegram OSINT message according to the rules.
#
# RAW MESSAGE:
# Well, don't come here illegally and don't film sensitive areas.
#
# https://t.me/elitepredatorsss/26572
#
# Spectacular timing. The Old Man ain't holding back...
# Agent1_TextCleaner > Well, don't come here illegally and don't film sensitive areas.
#
# Spectacular timing. The Old Man ain't holding back...
#
#  ### Continue session: debug_session_id
#
# User > Clean the following Telegram OSINT message according to the rules.
#
# RAW MESSAGE:
# 44 dead and 300+ missing after massive fire engulfed several high rise residential towers in Hong Kong!!
#
# Three senior staff from construction company have been arrested on suspicion of manslaughter
# Agent1_TextCleaner > 44 dead and 300+ missing after massive fire engulfed several high rise residential towers in Hong Kong!!
#
# Three senior staff from construction company have been arrested on suspicion of manslaughter
#
#  ### Continue session: debug_session_id
#
# User > Clean the following Telegram OSINT message according to the rules.
#
# RAW MESSAGE:
# Afghanistan 🌚?
# Agent1_TextCleaner > Afghanistan
#
#  ### Continue session: debug_session_id
#
# User > Clean the following Telegram OSINT message according to the rules.
#
# RAW MESSAGE:
# Unknown drones reportedly carried out strikes on ISIS-linked locations in the Jabar Mela area of Khyber District, Khyber Pakhtunkhwa, according to Al-Mersad.
# The area hosts key ISIS-K figures, including Gul Nazim, Sadiqyar, and Hudhaifa. Nazim, who leads ISIS-K’s eastern zone, has been active in Jabar Mela since 2024.
# Agent1_TextCleaner > Unknown drones reportedly carried out strikes on ISIS-linked locations in the Jabar Mela area of Khyber District, Khyber Pakhtunkhwa, according to Al-Mersad.
# The area hosts key ISIS-K figures, including Gul Nazim, Sadiqyar, and Hudhaifa. Nazim, who leads ISIS-K’s eastern zone, has been active in Jabar Mela since 2024.
# [Cleaner] Processed batch of 32 rows (total=96).
#
#  ### Continue session: debug_session_id
#
# User > Clean the following Telegram OSINT message according to the rules.
#
# RAW MESSAGE:
# EP×Exclusive: A propaganda poster linked to the banned terror group Jaish-e-Mohammad is circulating online, advertising a digital package of religious and jihadi lectures and publications for Rs 1000. The material includes hundreds of audio files, sermons, and tafseer recordings on USB and memory cards, along with a contact number for buyers.
#
# The poster shows the group’s continued efforts to spread its ideology through digital distribution.
#
#
# Details blurred due to security reasons.
# Agent1_TextCleaner > EP×Exclusive: A propaganda poster linked to the banned terror group Jaish-e-Mohammad is circulating online, advertising a digital package of religious and jihadi lectures and publications for Rs 1000. The material includes hundreds of audio files, sermons, and tafseer recordings on USB and memory cards, along with a contact number for buyers.
#
# The poster shows the group’s continued efforts to spread its ideology through digital distribution.
#
# Details blurred due to security reasons.
#
# ...
#
#
# https://youtube.com/shorts/RYnioaOBQr0?si=MYs1L8Kab9stk2cV
# Agent1_TextCleaner > WARNING WARNING WARNINGSaudi authorities crack a whip on Pakistani drug network in Medinah
#
# Few Pakistani men involved in ice (meth) trade arrested in a massive op by Saudi authorities. 👇👇👇
#
# https://youtube.com/shorts/RYnioaOBQr0?si=MYs1L8Kab9stk2cV
#
#  ### Continue session: debug_session_id
#
# User > Clean the following Telegram OSINT message according to the rules.
#
# RAW MESSAGE:
# LeT-JeM Terror Nexus Exposed: Key Operatives Link Bangladesh Routes to Pahalgam Attack
#
# Recent intelligence has fully unraveled the deepening ties between Lashkar-e-Taiba (LeT) and Jaish-e-Mohammed (JeM), with a high-level meeting between LeT's Bahawalpur head Saifullah Saif and PoK deputy Rizwan Hanif confirming their joint operational coordination.
#
#  This duo has been pivotal in orchestrating cross-group activities, raising alarms over escalating threats to India's security landscape.
#
# Follow Kashmir Disinfo Lab
# Agent1_TextCleaner > LeT-JeM Terror Nexus Exposed: Key Operatives Link Bangladesh Routes to Pahalgam Attack
#
# Recent intelligence has fully unraveled the deepening ties between Lashkar-e-Taiba (LeT) and Jaish-e-Mohammed (JeM), with a high-level meeting between LeT's Bahawalpur head Saifullah Saif and PoK deputy Rizwan Hanif confirming their joint operational coordination.
#
# This duo has been pivotal in orchestrating cross-group activities, raising alarms over escalating threats to India's security landscape.
#
# Follow Kashmir Disinfo Lab
# [Cleaner] Processed batch of 32 rows (total=128).
#
#  ### Continue session: debug_session_id
#
# User > Clean the following Telegram OSINT message according to the rules.
#
# RAW MESSAGE:
# Kulgam Police Launch Major Raids on Banned JeI Network
#
# Kulgam Police executed swift, coordinated raids across the district targeting the banned Jamaat-e-Islami (JeI), recovering electronic gadgets and incriminating documents.
#
# This operation underscores ongoing efforts to dismantle terror-linked networks in Jammu & Kashmir.
#
# No arrests reported yet, but investigations continue.
#
#  #KulgamRaids #JeI #JammuKashmirSecurity #IndiaSecurity
#
# Join Kashmir conflict stories
# Agent1_TextCleaner > Kulgam Police Launch Major Raids on Banned JeI Network
#
# Kulgam Police executed swift, coordinated raids across the district targeting the banned Jamaat-e-Islami (JeI), recovering electronic gadgets and incriminating documents.
#
# This operation underscores ongoing efforts to dismantle terror-linked networks in Jammu & Kashmir.
#
# No arrests reported yet, but investigations continue.
#
# #KulgamRaids #JeI #JammuKashmirSecurity #IndiaSecurity
#
# Join Kashmir conflict stories
#
#  ### Continue session: debug_session_id
#
# User > Clean the following Telegram OSINT message according to the rules.
#
# RAW MESSAGE:
# 🚨🚨🚨Declassified: Indian Army's MOST BRUTAL revenge attack.
#
# Not for the WEAK hearted ‼️
#
#
# 📹Complete video: https://youtu.be/JE6ucjl2wTw
# Agent1_TextCleaner > WARNING WARNING WARNINGDeclassified: Indian Army's MOST BRUTAL revenge attack.
#
# Not for the WEAK hearted ‼️
#
# Complete video: https://youtu.be/JE6ucjl2wTw
#
#  ### Continue session: debug_session_id
#
# User > Clean the following Telegram OSINT message according to the rules.
#
# RAW MESSAGE:
# 🚨 𝗕𝗥𝗘𝗔𝗞𝗜𝗡𝗚: 𝟯𝟯𝟰 𝘁𝗿𝗼𝗼𝗽𝘀 𝗳𝗿𝗼𝗺 𝗲𝗮𝗰𝗵 𝗻𝗮𝘁𝗶𝗼𝗻 𝘂𝗻𝗶𝘁𝗲 𝗳𝗼𝗿 𝗵𝗶𝗴𝗵-𝗮𝗹𝘁𝗶𝘁𝘂𝗱𝗲 𝗰𝗼𝘂𝗻𝘁𝗲𝗿-𝘁𝗲𝗿𝗿𝗼𝗿 𝗮𝗻𝗱 𝗱𝗶𝘀𝗮𝘀𝘁𝗲𝗿 𝗿𝗲𝗹𝗶𝗲𝗳 𝗱𝗿𝗶𝗹𝗹𝘀 𝗶𝗻 𝗛𝗶𝗺𝗮𝗹𝗮𝘆𝗮𝘀
#
# 🇮🇳🇳🇵 || The 19th edition of Exercise Suryakiran kicked off in Uttarakhand’s Pithoragarh district, bringing together 334 soldiers each from the Indian Army’s Assam Regiment and the Nepal Army’s Devi Dutta Regiment for intensive training in mountain warfare, counter-terror operations, and humanitarian response.
#
# 🔥 This two-week exercise will enhance interoperability and deepen military ties, focusing on modern tactics and tech-enabled operations to bolster security cooperation in the Himalayan region.
#
# #Suryakiran #IndiaNepal #MilitaryExercise #Uttarakhand #CounterTerror #DefenceCooperation #Himalayas #IndianArmy #NepalArmy
#
# 📍 @ResonantNews
# Agent1_TextCleaner > BREAKING: 334 TROOPS FROM EACH NATION UNITE FOR HIGH-ALTITUDE COUNTER-TERROR AND DISASTER RELIEF DRILLS IN HIMALAYAS
#
# The 19th edition of Exercise Suryakiran kicked off in Uttarakhand’s Pithoragarh district, bringing together 334 soldiers each from the Indian Army’s Assam Regiment and the Nepal Army’s Devi Dutta Regiment for intensive training in mountain warfare, counter-terror operations, and humanitarian response.
#
# This two-week exercise will enhance interoperability and deepen military ties, focusing on modern tactics and tech-enabled operations to bolster security cooperation in the Himalayan region.
#
# #Suryakiran #IndiaNepal #MilitaryExercise #Uttarakhand #CounterTerror #DefenceCooperation #Himalayas #IndianArmy #NepalArmy
#
# 📍 @ResonantNews
#
#  ### Continue session: debug_session_id
#
# User > Clean the following Telegram OSINT message according to the rules.
#
# RAW MESSAGE:
# 🚨 𝗕𝗥𝗘𝗔𝗞𝗜𝗡𝗚: 𝗕𝗹𝗮𝘇𝗲 𝗱𝗲𝘃𝗮𝘀𝘁𝗮𝘁𝗲𝘀 𝗼𝘃𝗲𝗿 𝟭,𝟱𝟬𝟬 𝗞𝗼𝗿𝗮𝗶𝗹 𝘀𝗵𝗮𝗻𝘁𝗶𝗲𝘀, 𝗳𝗮𝗺𝗶𝗹𝗶𝗲𝘀 𝗳𝗹𝗲𝗲 𝗗𝗵𝗮𝗸𝗮 𝘀𝗲𝘁𝘁𝗹𝗲𝗺𝗲𝗻𝘁 𝗼𝘃𝗲𝗿𝗻𝗶𝗴𝗵𝘁
#
# 🇧🇩 || A massive fire ripped through Dhaka’s crowded Korail slum, destroying more than 1,500 makeshift homes and leaving thousands of people with nowhere to sleep but the open streets.
#
# 💥 Rescue workers scrambled to assist and government officials are assessing damage as one of the worst urban blazes in years exposes harsh realities for Bangladesh’s poorest residents.
#
# #DhakaFire #Bangladesh #SlumFire #Korail #Disaster #UrbanPoverty #BreakingNews
#
# 📍 @ResonantNews
# Agent1_TextCleaner > BREAKING: BLAZE DEVASTATES OVER 1,500 KORAIL SHANTIES, FAMILIES FLEE DHAKA SETTLEMENT OVERNIGHT
#
# A massive fire ripped through Dhaka’s crowded Korail slum, destroying more than 1,500 makeshift homes and leaving thousands of people with nowhere to sleep but the open streets.
#
# Rescue workers scrambled to assist and government officials are assessing damage as one of the worst urban blazes in years exposes harsh realities for Bangladesh’s poorest residents.
#
# #DhakaFire #Bangladesh #SlumFire #Korail #Disaster #UrbanPoverty #BreakingNews
#
# 📍 @ResonantNews
#
#  ### Continue session: debug_session_id
#
# User > Clean the following Telegram OSINT message according to the rules.
#
# RAW MESSAGE:
# 🚨 𝗕𝗥𝗘𝗔𝗞𝗜𝗡𝗚: 𝗟𝗮𝗶 𝗖𝗵𝗶𝗻𝗴-𝘁𝗲’𝘀 𝗽𝗹𝗮𝗻 𝗯𝗼𝗼𝘀𝘁𝘀 𝗺𝗶𝘀𝘀𝗶𝗹𝗲𝘀, 𝗱𝗿𝗼𝗻𝗲𝘀, 𝗮𝗶𝗿 𝗱𝗲𝗳𝗲𝗻𝗰𝗲 𝘁𝗼 𝗰𝗼𝘂𝗻𝘁𝗲𝗿 𝗣𝗟𝗔 𝘁𝗵𝗿𝗲𝗮𝘁𝘀
#
# 🇹🇼🇨🇳 || President Lai’s government announced a massive $40 billion multi-year defence package, aiming to reinforce missile shields, anti-ship systems, drone fleets and reserve forces to deter increasing Chinese military activity.
#
# ⚡ The landmark decision puts defence at 5% of GDP and seeks deeper arms accords with the US.
#
# #Taiwan #DefenceBudget #ChinaThreat #MissileShield #Taipei #Security
#
# 📍 @ResonantNews
# Agent1_TextCleaner > BREAKING: LAI CHING-TE’S PLAN BOOSTS MISSILES, DRONES, AIR DEFENCE TO COUNTER PLA THREATS
#
# President Lai’s government announced a massive $40 billion multi-year defence package, aiming to reinforce missile shields, anti-ship systems, drone fleets and reserve forces to deter increasing Chinese military activity.
#
# The landmark decision puts defence at 5% of GDP and seeks deeper arms accords with the US.
#
# #Taiwan #DefenceBudget #ChinaThreat #MissileShield #Taipei #Security
#
# 📍 @ResonantNews
#
#  ### Continue session: debug_session_id
#
# User > Clean the following Telegram OSINT message according to the rules.
#
# RAW MESSAGE:
# 🚨 𝗕𝗥𝗘𝗔𝗞𝗜𝗡𝗚: 𝗗𝗖 𝗮𝘁𝘁𝗮𝗰𝗸 𝘀𝘂𝘀𝗽𝗲𝗰𝘁 𝗲𝗻𝘁𝗲𝗿𝗲𝗱 𝗨𝗦 𝗮𝘀 𝗮 𝗺𝗶𝗴𝗿𝗮𝗻𝘁 𝗶𝗻 𝟮𝟬𝟮𝟭, 𝗙𝗕𝗜 𝗽𝗿𝗼𝗯𝗲𝘀 𝘁𝗲𝗿𝗿𝗼𝗿 𝗮𝗻𝗴𝗹𝗲
#
# 🇺🇸🇦🇫 || Authorities identified 29-year-old Rahmanullah Lakanwal, an Afghan national, as the gunman who shot two National Guard soldiers near the White House.
#
# 💥 The FBI and local security agencies have launched terrorism investigations, while the US government reviews Afghan migration records amid fresh security concerns.
#
# #DCshooting #NationalGuard #AfghanSuspect #Security #Breaking #USA
#
# 📍 @ResonantNews
# Agent1_TextCleaner > BREAKING: DC ATTACK SUSPECT ENTERED US AS A MIGRANT IN 2021, FBI PROBES TERROR ANGLE
#
# Authorities identified 29-year-old Rahmanullah Lakanwal, an Afghan national, as the gunman who shot two National Guard soldiers near the White House.
#
# The FBI and local security agencies have launched terrorism investigations, while the US government reviews Afghan migration records amid fresh security concerns.
#
# #DCshooting #NationalGuard #AfghanSuspect #Security #Breaking #USA
#
# 📍 @ResonantNews
#
#  ### Continue session: debug_session_id
#
# User > Clean the following Telegram OSINT message according to the rules.
#
# RAW MESSAGE:
# 🚨 𝗕𝗥𝗘𝗔𝗞𝗜𝗡𝗚: 𝗟𝗮𝗻𝗱𝗺𝗮𝗿𝗸 𝗟𝗮𝘄 𝗙𝗮𝗰𝗲𝘀 𝗖𝗼𝘂𝗿𝘁 𝗖𝗵𝗮𝗹𝗹𝗲𝗻𝗴𝗲, 𝗦𝗽𝗮𝗿𝗸𝘀 𝗢𝗻𝗹𝗶𝗻𝗲 𝗦𝗮𝗳𝗲𝘁𝘆 𝗗𝗲𝗯𝗮𝘁𝗲
#
# 🇦🇺 || Australia’s government will implement a nationwide ban on social media use for children under 16 despite pending court cases, citing rising concerns over youth mental health and cyberbullying.
#
# 🔥 Supporters hail the move as proactive, while critics argue it restricts digital freedom and parental rights.
#
# #Australia #SocialMediaBan #ChildSafety #OnlineSafety #YouthPolicy #LegalDebate
#
# 📍 @ResonantNews
# Agent1_TextCleaner > BREAKING: LANDMARK LAW FACES COURT CHALLENGE, SPARKS ONLINE SAFETY DEBATE
#
# Australia’s government will implement a nationwide ban on social media use for children under 16 despite pending court cases, citing rising concerns over youth mental health and cyberbullying.
#
# Supporters hail the move as proactive, while critics argue it restricts digital freedom and parental rights.
#
# #Australia #SocialMediaBan #ChildSafety #OnlineSafety #YouthPolicy #LegalDebate
#
# 📍 @ResonantNews
#
#  ### Continue session: debug_session_id
#
# User > Clean the following Telegram OSINT message according to the rules.
#
# RAW MESSAGE:
# ⚡️⚡️⚡️Bangladesh’s 🇧🇩 BGB rehearses “ how to tackle election day crowd”  😄👆👆👆
#
# In preparation for upcoming 13th National Parliamentary Election, Border Guard Bangladesh (BGB) conducted an election training drill.
#
#
# @ResonantNews
# Agent1_TextCleaner > BANGLADESH’S BGB REHEARSES “HOW TO TACKLE ELECTION DAY CROWD”
#
# In preparation for upcoming 13th National Parliamentary Election, Border Guard Bangladesh (BGB) conducted an election training drill.
#
# @ResonantNews
#
#  ### Continue session: debug_session_id
#
# User > Clean the following Telegram OSINT message according to the rules.
#
# RAW MESSAGE:
# 🚨 𝗕𝗥𝗘𝗔𝗞𝗜𝗡𝗚: 𝗚𝗹𝗼𝗯𝗮𝗹 𝗦𝗽𝗼𝗿𝘁𝗶𝗻𝗴 𝗘𝘃𝗲𝗻𝘁 𝗥𝗲𝘁𝘂𝗿𝗻𝘀 𝘁𝗼 𝗜𝗻𝗱𝗶𝗮𝗻 𝗦𝗼𝗶𝗹 𝗔𝗳𝘁𝗲𝗿 𝗗𝗲𝗰𝗮𝗱𝗲𝘀
#
# 🇮🇳 || Amdavad (Ahmedabad) is named host for the prestigious 2030 Centenary Games, with massive infrastructural and sporting preparations underway to welcome global athletes.
#
# 🔥 India’s selection highlights renewed ambitions for global sporting reputation and inclusive celebration.
#
# #CentenaryGames #Amdavad2030 #IndiaSport #GlobalEvent #Ahmedabad
#
# 📍 @ResonantNews
# Agent1_TextCleaner > BREAKING: GLOBAL SPORTING EVENT RETURNS TO INDIAN SOIL AFTER DECADES
#
# Amdavad (Ahmedabad) is named host for the prestigious 2030 Centenary Games, with massive infrastructural and sporting preparations underway to welcome global athletes.
#
# India’s selection highlights renewed ambitions for global sporting reputation and inclusive celebration.
#
# #CentenaryGames #Amdavad2030 #IndiaSport #GlobalEvent #Ahmedabad
#
# 📍 @ResonantNews
#
#  ### Continue session: debug_session_id
#
# User > Clean the following Telegram OSINT message according to the rules.
#
# RAW MESSAGE:
# 🚨Death toll in Hong Kong fire rises to 44 with 279 still missing
#
# 🔶At least 44 people have been killed in a major fire engulfing public housing apartments in Hong Kong's Tai Po district - more than 270 people are still not accounted for
#
# 🔶Three construction company executives have been arrested on suspicion of manslaughter connected to flammable materials that may have allowed the fire to spread quickly
#
# 🔶After 18 hours, officials said the fire was under control - it has been classified a level five blaze, the most serious level in Hong Kong
#
#
# @ResonantNews
# Agent1_TextCleaner > Death toll in Hong Kong fire rises to 44 with 279 still missing
#
# At least 44 people have been killed in a major fire engulfing public housing apartments in Hong Kong's Tai Po district - more than 270 people are still not accounted for
#
# Three construction company executives have been arrested on suspicion of manslaughter connected to flammable materials that may have allowed the fire to spread quickly
#
# After 18 hours, officials said the fire was under control - it has been classified a level five blaze, the most serious level in Hong Kong
#
# @ResonantNews
#
#  ### Continue session: debug_session_id
#
# User > Clean the following Telegram OSINT message according to the rules.
#
# RAW MESSAGE:
# 🚨 𝗕𝗥𝗘𝗔𝗞𝗜𝗡𝗚: 𝗚𝗿𝗼𝘄𝘁𝗵 𝗦𝗲𝘁𝗯𝗮𝗰𝗸 𝗣𝘂𝘀𝗵𝗲𝘀 𝗔𝗺𝗯𝗶𝘁𝗶𝗼𝗻 𝘁𝗼 𝗟𝗮𝘁𝗲 𝟮𝟬𝟮𝟴, 𝗗𝗮𝘁𝗮 𝗦𝗵𝗼𝘄𝘀
#
# 🇮🇳 || The IMF confirmed India will reach the $5 trillion GDP milestone a year later than expected, reflecting slowed recovery post-pandemic and global headwinds.
#
# ⚡ Policy reforms and investments remain vital as the country strives to regain growth momentum and leadership in the global economy.
#
# #IndiaEconomy #IMF #GrowthDelay #GDP #GlobalFinance #5TrillionGoal
#
#
# 📍 @ResonantNews
# Agent1_TextCleaner > BREAKING: GROWTH SETBACK PUSHES AMBITION TO LATE 2028, DATA SHOWS
#
# The IMF confirmed India will reach the $5 trillion GDP milestone a year later than expected, reflecting slowed recovery post-pandemic and global headwinds.
#
# Policy reforms and investments remain vital as the country strives to regain growth momentum and leadership in the global economy.
#
# #IndiaEconomy #IMF #GrowthDelay #GDP #GlobalFinance #5TrillionGoal
#
# 📍 @ResonantNews
#
#  ### Continue session: debug_session_id
#
# User > Clean the following Telegram OSINT message according to the rules.
#
# RAW MESSAGE:
# 🚨 𝗕𝗥𝗘𝗔𝗞𝗜𝗡𝗚: 𝗔𝗹𝗹𝗲𝗴𝗮𝘁𝗶𝗼𝗻𝘀 𝗮𝗻𝗱 𝗥𝗲𝗹𝗶𝗴𝗶𝗼𝘂𝘀 𝗧𝗲𝗻𝘀𝗶𝗼𝗻𝘀
#
# 🇮🇳🇵🇰 || India sharply criticized Pakistan’s comments on Ayodhya, calling it a “country with a stained record of bigotry” and rejecting religious interference in internal matters.
#
# 💥 The exchange deepened diplomatic tensions, fueled by historical disputes and both sides trading accusations of intolerance.
#
# #IndiaPakistan #Ayodhya #Bigotry #DiplomaticRow #SouthAsia
#
# 📍 @ResonantNews
# Agent1_TextCleaner > BREAKING: ALLEGATIONS AND RELIGIOUS TENSIONS
#
# India sharply criticized Pakistan’s comments on Ayodhya, calling it a “country with a stained record of bigotry” and rejecting religious interference in internal matters.
#
# The exchange deepened diplomatic tensions, fueled by historical disputes and both sides trading accusations of intolerance.
#
# #IndiaPakistan #Ayodhya #Bigotry #DiplomaticRow #SouthAsia
#
# 📍 @ResonantNews
#
#  ### Continue session: debug_session_id
#
# User > Clean the following Telegram OSINT message according to the rules.
#
# RAW MESSAGE:
# ⚡️⚡️⚡️France's 🇫🇷 SAFRAN is heavily investing in India 🇮🇳
#
# 🔶Safran's MRO center for CFM Int'l LEAP engine in Hyderabad.
#
# 🔶Another MRO shop for M88 engine used by #Rafale
#
# 🔶Safran's joint venture with BEL to produce #Hammer (can be integrated on #TEJAS) 👍👍👍
#
# @BEL_CorpCom
#
# @SAFRAN
#
#
# Indian airforce will benefit from this.
#
#
# ▶️You can read the details here (subscribers)
# https://resonantnews.com/2025/11/27/safran-strengthens-its-footprint-in-india-indian-airforce-to-benefit-from-it/
#
#
# @ResonantNews
# Agent1_TextCleaner > BANGLADESH’S BGB REHEARSES “HOW TO TACKLE ELECTION DAY CROWD”
#
# In preparation for upcoming 13th National Parliamentary Election, Border Guard Bangladesh (BGB) conducted an election training drill.
#
# @ResonantNews
#
#  ### Continue session: debug_session_id
#
# User > Clean the following Telegram OSINT message according to the rules.
#
# RAW MESSAGE:
# 🌞 MORNING SHLOK 🌞
#
# कराग्रे वसते लक्ष्मीः करमध्यं सरस्वती ।
# करमूले तु गोविन्दः प्रभाते करदर्शनम् ॥
#
# On the tips of the fingers resides Lakshmi, in the palm's center Saraswati, at the base Govinda; behold your hands at dawn
# Agent1_TextCleaner > MORNING SHLOK
#
# कराग्रे वसते लक्ष्मीः करमध्यं सरस्वती ।
# करमूले तु गोविन्दः प्रभाते करदर्शनम् ॥
#
# On the tips of the fingers resides Lakshmi, in the palm's center Saraswati, at the base Govinda; behold your hands at dawn
# [Cleaner] Processed batch of 14 rows (total=142).
# [Cleaner] Done. Total rows cleaned: 142

# %%
conn = sqlite3.connect("events.db")
df = pd.read_sql_query("SELECT id, text_raw, text_clean FROM events;", conn)
df.head()
# Out:
#    id                                           text_raw  \
# 0   1  'Significant outcomes' expected as Putin to vi...
# 1   2
# 2   3  India continues its strong support for the Afg...
# 3   4  🚨🇵🇰🗣️🇦🇫🪖 Flash News :\n\nThe ceasefire between...
# 4   5  A 33 minute long documentary has been released...
#
#                                           text_clean
# 0  'Significant outcomes' expected as Putin to vi...
# 1                                               None
# 2  India continues its strong support for the Afg...
# 3  Flash News : The ceasefire between Pak and Afg...
# 4  A 33 minute long documentary has been released...

# %% [markdown]
# ---
#
# # 🗺️ Agent 2 — Geo-Significance Classifier
# ### *Filtering which messages represent real, mappable incidents*
#
# Not every OSINT message describes a localized event.
# Some are commentary, propaganda, or broad political statements.
#
# Agent 2 uses an LLM to distinguish real incidents and update the 'checked' column of the database:
#
# - **checked=1** A concrete event in time & location
# - **checked=-1** Non-actionable contextual noise
#
# This step dramatically reduces false positives and ensures that only **spatially meaningful events** continue through the pipeline.
#
# Below is the implementation of Agent 2.

# %%
"""
Agent 2 — Geo-Significance Checker 

Definition of "incident" (map-worthy):
- Specific event in time and space
- That can be reasonably plotted on a map
"""

import sqlite3
from typing import List, Tuple

from google.genai import types
from google.adk.agents import LlmAgent
from google.adk.models import Gemini
from google.adk.runners import InMemoryRunner

DB_PATH = "incidents.db"
BATCH_SIZE = 32  # number of rows to classify per batch

retry_config = types.HttpRetryOptions(
    attempts=5,
    exp_base=7,
    initial_delay=1,
    http_status_codes=[429, 500, 503, 504],
)

GEO_SYSTEM_INSTRUCTIONS = """
You are an OSINT incident filter assistant for a geospatial mapping pipeline.

Your job:
- Read a cleaned Telegram OSINT message.
- Decide if it describes a CONCRETE, LOCALIZED INCIDENT that can be placed on a map.

DEFINITION OF INCIDENT (MAP-WORTHY):
- A specific event that happened (or is happening) at a particular place.
- Examples:
  - Attack, skirmish, firefight, encounter, ambush, bombing, shelling,
    missile strike, drone strike, IED blast, sniper incident.
  - Security/military operations tied to a locality: raid, search operation,
    cordon, troop movement, convoy movement, checkpoint clash, border
    infiltration attempt, drone spotting near a town.
  - Crime/policing: arrest, detention, seizure of weapons or contraband,
    kidnapping, smuggling interdiction, violent riot at a specific location.
  - Disaster/emergency: fire, building collapse, accident, bus/train crash,
    flood/landslide in a named area.
  - Infrastructure incidents: damage to bridges, roads, power stations,
    pipelines, airports, if localized.

NOT INCIDENT (NOT MAP-WORTHY):
- Pure political or diplomatic statements, border claims, map changes,
  without a concrete violent/security event.
- General tension or fear: "situation is tense in the region", "people
  are worried everywhere".
- Whole-country or broad-region statements with no specific locality:
  "Russia attacks Ukraine's anti-drone nets" (no specific city/site).
- Historical summaries or hypotheticals.
- Generic commentary, propaganda, analysis.

RULE:
- If the message clearly describes a concrete event at a city/area/facility
  that could be plotted on a map, label it as INCIDENT.
- If not, label it as NOT INCIDENT.

OUTPUT FORMAT:
- If INCIDENT (mappable)     → output: 1
- If NOT INCIDENT (not used) → output: -1

Return ONLY 1 or -1 as plain text, nothing else.
""".strip()


# ----------------- DB HELPERS -----------------

def get_connection(db_path: str = DB_PATH) -> sqlite3.Connection:
    """Return a sqlite3 connection to the DB file."""
    return sqlite3.connect(db_path)


def fetch_rows_to_check(
    conn: sqlite3.Connection,
    limit: int = BATCH_SIZE
) -> List[Tuple[int, str]]:
    """
    Fetch a batch of rows that still need geo-significance checking.

    Conditions:
    - text_clean is not NULL/empty
    - checked = 0 (default, not yet classified)
    """
    cur = conn.cursor()
    cur.execute(
        """
        SELECT id, text_clean
        FROM events
        WHERE text_clean IS NOT NULL
          AND TRIM(text_clean) <> ''
          AND checked = 0
        ORDER BY id
        LIMIT ?
        """,
        (limit,),
    )
    return cur.fetchall()


def update_checked(
    conn: sqlite3.Connection,
    row_id: int,
    checked_value: int
) -> None:
    """Update the checked field (1 or -1) for a single row."""
    cur = conn.cursor()
    cur.execute(
        """
        UPDATE events
        SET checked = ?
        WHERE id = ?
        """,
        (checked_value, row_id),
    )


# ----------------- PROMPT BUILDER -----------------

def build_geo_prompt(text_clean: str) -> str:
    """
    Build the user prompt that will be sent to the geo-significance agent.
    """
    user_prompt = f"""
Using your incident definition and rules, decide if the following OSINT message
is an INCIDENT or NOT INCIDENT, and return ONLY 1 or -1.

MESSAGE:
{text_clean}
""".strip()
    return user_prompt


# ----------------- ADK AGENT SETUP -----------------

def create_geo_agent() -> LlmAgent:
    """
    Create and return the ADK Agent dedicated to geo-significance checking.
    """
    agent = LlmAgent(
        name="Agent2_GeoChecker",
        model=Gemini(
            model="gemini-2.5-flash-lite",
            retry_options=retry_config,
        ),
        description="Decides if a cleaned OSINT message is a localized, map-worthy incident.",
        instruction=GEO_SYSTEM_INSTRUCTIONS,
        tools=[],  # no tools needed
    )
    return agent


# ----------------- LLM CALL WRAPPER -----------------

class GeoCheckerLLM:
    """
    Wrapper around an InMemoryRunner for the geo-significance agent.

    Provides an async call(prompt: str) -> int that returns 1 or -1.
    """

    def __init__(self, runner: InMemoryRunner):
        self.runner = runner

    async def call(self, prompt: str) -> int:
        events = await self.runner.run_debug(prompt)

        # Find the last non-user event with content
        assistant_event = None
        for e in reversed(events):
            if getattr(e, "author", "") == "user":
                continue
            if getattr(e, "content", None) is None:
                continue
            assistant_event = e
            break

        if assistant_event is None:
            # Fallback: default to NOT INCIDENT
            return -1

        # Extract text parts
        parts = getattr(assistant_event.content, "parts", [])
        texts = []
        for p in parts:
            if hasattr(p, "text") and p.text:
                texts.append(p.text)

        raw_text = "\n".join(texts).strip()
        cleaned = raw_text.strip()

        # Direct parse attempt
        try:
            val = int(cleaned)
            if val in (1, -1):
                return val
        except ValueError:
            pass

        # Fallback: scan for first occurrence of "-1" or "1"
        if "-1" in cleaned:
            return -1
        if "1" in cleaned:
            return 1

        # If nothing sensible found, default to NOT INCIDENT
        return -1


# ----------------- BATCH LOGIC (ASYNC) -----------------

async def run_geo_batch(
    llm: GeoCheckerLLM,
    db_path: str = DB_PATH,
    batch_size: int = BATCH_SIZE,
) -> int:
    """
    Process a single batch of rows that need geo-significance checking.

    Returns:
        Number of rows updated in this batch.
    """
    conn = get_connection(db_path)
    try:
        rows = fetch_rows_to_check(conn, limit=batch_size)
        if not rows:
            return 0

        for row_id, text_clean in rows:
            if not text_clean or not text_clean.strip():
                update_checked(conn, row_id, -1)
                continue

            prompt = build_geo_prompt(text_clean)

            try:
                checked_val = await llm.call(prompt)
            except Exception as e:
                print(f"[GeoChecker] LLM error for id={row_id}: {e}")
                checked_val = -1  # Fail-safe: NOT INCIDENT

            if checked_val not in (1, -1):
                checked_val = -1

            update_checked(conn, row_id, checked_val)

        conn.commit()
        return len(rows)
    finally:
        conn.close()


async def run_geo_until_done(
    llm: GeoCheckerLLM,
    db_path: str = DB_PATH,
    batch_size: int = BATCH_SIZE,
) -> None:
    """
    Keep running batches until there are no more rows with checked = 0.
    """
    total = 0
    while True:
        processed = await run_geo_batch(
            llm=llm,
            db_path=db_path,
            batch_size=batch_size,
        )
        if processed == 0:
            break
        total += processed
        print(f"[GeoChecker] Processed batch of {processed} rows (total={total}).")

    print(f"[GeoChecker] Done. Total rows labeled: {total}")


# ----------------- NOTEBOOK ENTRYPOINT -----------------

async def run_agent2_geo_checker(batch_size: int = BATCH_SIZE):

    geo_agent = create_geo_agent()
    print("[GeoChecker] Agent created.")

    geo_runner = InMemoryRunner(agent=geo_agent)
    print("[GeoChecker] Runner created.")

    llm = GeoCheckerLLM(runner=geo_runner)
    await run_geo_until_done(llm=llm, db_path=DB_PATH, batch_size=batch_size)

    print("[GeoChecker] Completed.")

# %%
await run_agent2_geo_checker()
# Out:
# App name mismatch detected. The runner is configured with app name "InMemoryRunner", but the root agent was loaded from "C:\Users\Lenovo\Desktop\AgentAICourse\agentai_venv\Lib\site-packages\google\adk\agents", which implies app name "agents".
# [GeoChecker] Agent created.
# [GeoChecker] Runner created.
#
#  ### Created new session: debug_session_id
#
# User > Using your incident definition and rules, decide if the following OSINT message
# is an INCIDENT or NOT INCIDENT, and return ONLY 1 or -1.
#
# MESSAGE:
# 'Significant outcomes' expected as Putin to visit India
#
# Russian President Vladimir Putin will make a two-day visit to India from Dec 4 to hold annual summit talks with PM Narendra Modi that is expected to produce a plethora of significant outcomes, including in the DEFENCE SPHERE.
#
# PTI Report
# Agent2_GeoChecker > -1
#
#  ### Continue session: debug_session_id
#
# User > Using your incident definition and rules, decide if the following OSINT message
# is an INCIDENT or NOT INCIDENT, and return ONLY 1 or -1.
#
# MESSAGE:
# India continues its strong support for the Afghan people.
#
# 73 tonnes of life-saving medicines, vaccines and essential supplements have been delivered to Kabul to meet urgent medical needs.
#
# Afghan sources
# Agent2_GeoChecker > -1
#
#  ### Continue session: debug_session_id
#
# User > Using your incident definition and rules, decide if the following OSINT message
# is an INCIDENT or NOT INCIDENT, and return ONLY 1 or -1.
#
# MESSAGE:
# Flash News :
#
# The ceasefire between Pak and Afghanistan will end soon. : PaK F.O
#
# "The Ceasefire between Pakistan and Afghan Taliban is not holding. The ceasefire does not imply a traditional ceasefire. The ceasefire implies that there will be no terrorist attack from Afghan sponsored terrorist proxies in Pakistan. Afghan Nationals and terrorist organisation are continuing with their attacks on Pakistan" : PaK Foreign Office spox
# Tahir Andrabi
# Agent2_GeoChecker > -1
#
#  ### Continue session: debug_session_id
#
# User > Using your incident definition and rules, decide if the following OSINT message
# is an INCIDENT or NOT INCIDENT, and return ONLY 1 or -1.
#
# MESSAGE:
# A 33 minute long documentary has been released by rebel linked media on the attackers who killed Major Adnan from the SSG and other personnel in the attack on the Bannu FC lines.
# Agent2_GeoChecker > 1
#
#  ### Continue session: debug_session_id
#
# User > Using your incident definition and rules, decide if the following OSINT message
# is an INCIDENT or NOT INCIDENT, and return ONLY 1 or -1.
#
# MESSAGE:
# As the attacks on pakistani military intensifies around 7 pakistani soldiers have resigned from the military duties : Sources
# Agent2_GeoChecker > -1
#
#  ### Continue session: debug_session_id
#
# User > Using your incident definition and rules, decide if the following OSINT message
# is an INCIDENT or NOT INCIDENT, and return ONLY 1 or -1.
#
# MESSAGE:
# Some unconfirmed reports claim Maulvi Izzatullah was targeted by ISIS due to his opposition to their activities. No official confirmation yet, but sources indicate his stance against extremist elements may have made him a target.
#
# Developing story...
# Agent2_GeoChecker > -1
#
#  ### Continue session: debug_session_id
#
# User > Using your incident definition and rules, decide if the following OSINT message
# is an INCIDENT or NOT INCIDENT, and return ONLY 1 or -1.
#
# MESSAGE:
# Just in :
#
# Unknown gunmen shot and killed Maulvi Izzatullah and his son in Tajabad, Pushtakhra area, Peshawar- KP - Pakistan.
#
# Police says the killers escaped. The bodies were sent for postmortem.
#
# The motive is not clear. The eliminated Salafist Maulvi is presumed to be linked to Lashkar e Taiba.
# Agent2_GeoChecker > 1
#
#  ### Continue session: debug_session_id
#
# User > Using your incident definition and rules, decide if the following OSINT message
# is an INCIDENT or NOT INCIDENT, and return ONLY 1 or -1.
#
# MESSAGE:
# Pakistani army general retired because there was no more space to put up medals.
#
# Belly pe medal koun lagata hei
#
# Jung tho kabhi jeete nahi, aur election kabhi haare nahi
# Agent2_GeoChecker > -1
#
#  ### Continue session: debug_session_id
#
# User > Using your incident definition and rules, decide if the following OSINT message
# is an INCIDENT or NOT INCIDENT, and return ONLY 1 or -1.
#
# MESSAGE:
# Here is the another post abandoned by the pakistani military in the region.
# Agent2_GeoChecker > -1
#
#  ### Continue session: debug_session_id
#
# User > Using your incident definition and rules, decide if the following OSINT message
# is an INCIDENT or NOT INCIDENT, and return ONLY 1 or -1.
#
# MESSAGE:
# Mungerilal ki haseen sapne....
#
# PaK politician Syed Sardar Ali Shah claims "Gujarat, Haryana, Rajasthan are ours, we will prove it...."
#
# This comes after Indian Def Min Rajnath Singh's statement on Sindh...
# Agent2_GeoChecker > -1
#
#  ### Continue session: debug_session_id
#
# User > Using your incident definition and rules, decide if the following OSINT message
# is an INCIDENT or NOT INCIDENT, and return ONLY 1 or -1.
#
# MESSAGE:
# Under Field Marshal Asim Munir’s , the Pakistani Taliban are now walking straight into military bases across Khyber Pakhtunkhwa like they own the place.
#
# The army isn’t fighting back. Posts are being abandoned overnight, soldiers pulling out without a shot fired, leaving basesand weapons behind. The militants move in, film videos and set up checkpoints.
# Agent2_GeoChecker > 1
#
#  ### Continue session: debug_session_id
#
# User > Using your incident definition and rules, decide if the following OSINT message
# is an INCIDENT or NOT INCIDENT, and return ONLY 1 or -1.
#
# MESSAGE:
# As per pro rebel sources a massive attack was launched on the Police station in Bannu, KPK resulting in death of 7 police personals.
#
# Mean while pakistani side sources reported injuries to 5 police personals
# Agent2_GeoChecker > 1
#
#  ### Continue session: debug_session_id
#
# User > Using your incident definition and rules, decide if the following OSINT message
# is an INCIDENT or NOT INCIDENT, and return ONLY 1 or -1.
#
# MESSAGE:
# Itna Bam Marenge Itna Bam Marenge.... Poora Ilaaka Dhuan Dhuan Hojyaga...
#
# Note : Strong language
# Video credit on the visual
# Agent2_GeoChecker > -1
#
#  ### Continue session: debug_session_id
#
# User > Using your incident definition and rules, decide if the following OSINT message
# is an INCIDENT or NOT INCIDENT, and return ONLY 1 or -1.
#
# MESSAGE:
# 🤣
# Agent2_GeoChecker > -1
#
#  ### Continue session: debug_session_id
#
# User > Using your incident definition and rules, decide if the following OSINT message
# is an INCIDENT or NOT INCIDENT, and return ONLY 1 or -1.
#
# MESSAGE:
# Damn.... PaK punjab govt hikes traffic fines to PKR 15,000 .
#
# Looks like Pak govt decided to pay off IMF debt by issuing traffic challans .
#
# At this rate even a wrong U-turn will fund a full IMF installment.
#
# Squeeze the awam as much as you can till every challan turns into foreign exchange
# Agent2_GeoChecker > -1
#
#  ### Continue session: debug_session_id
#
# User > Using your incident definition and rules, decide if the following OSINT message
# is an INCIDENT or NOT INCIDENT, and return ONLY 1 or -1.
#
# MESSAGE:
# Live telecast
# Agent2_GeoChecker > -1
#
#  ### Continue session: debug_session_id
#
# User > Using your incident definition and rules, decide if the following OSINT message
# is an INCIDENT or NOT INCIDENT, and return ONLY 1 or -1.
#
# MESSAGE:
# Just In:
#
# Iranian Supreme Leader Ayatollah Khamenei to deliver an unscheduled address to the nation tonight: Report
# Agent2_GeoChecker > -1
#
#  ### Continue session: debug_session_id
#
# User > Using your incident definition and rules, decide if the following OSINT message
# is an INCIDENT or NOT INCIDENT, and return ONLY 1 or -1.
#
# MESSAGE:
# "Pakistan’s forces must be ready for future wars, the nature of threats now ranges from hybrid confrontation to full-scale war" : outgoing PaK army Gen Sahir Shamshad
# Agent2_GeoChecker > -1
#
#  ### Continue session: debug_session_id
#
# User > Using your incident definition and rules, decide if the following OSINT message
# is an INCIDENT or NOT INCIDENT, and return ONLY 1 or -1.
#
# MESSAGE:
# Report :
#
# According to a new IMF report corruption and weak institutions continue to drag down Pakistan’s economy.
#
# IMF warns state-capture by political and business elites has dried public resources and crippled fair competition.
# Governance issues hit tax collection, public spending and investor trust.
# Even Pak Finance Minister Aurangzeb admits they now have to address every gap identified by the IMF
#
# He said "God willing, an agreement with the IMF will be reached, loan will be approved"
#
# How long PaK govt will feed the 'LAHORI CHURAN' to it's awam
# Agent2_GeoChecker > -1
#
#  ### Continue session: debug_session_id
#
# User > Using your incident definition and rules, decide if the following OSINT message
# is an INCIDENT or NOT INCIDENT, and return ONLY 1 or -1.
#
# MESSAGE:
# According to TTP sources, reportedly rebels fired a homemade rocket at the Wali Noor PaK military camp in the Janikhel area of the Baka Khel subdivision.
#
# They shared a photo and said the video will be released soon.
# Agent2_GeoChecker > 1
#
#  ### Continue session: debug_session_id
#
# User > Using your incident definition and rules, decide if the following OSINT message
# is an INCIDENT or NOT INCIDENT, and return ONLY 1 or -1.
#
# MESSAGE:
# Yesterday, on the sad occasion of 26/11, hundreds of Lashkar-e-Taiba-linked accounts and many Pakistani users celebrated the terror attack. They treated it as entertainment, with some even sharing cake-cutting videos for 26/11 while celebrating the killing of innocent Indians.
#
# This mindset is dangerous and sick. It shows how deep radicalisation has gone.
#
# • They treat mass murder as entertainment.
# • They praise the terrorists who carried out the killings.
# • They mock the pain of Indian families.
# • They expose the depth of extremist thinking in their circles.
#
# India remembers the victims. India stands firm against terrorism.
# Agent2_GeoChecker > -1
#
#  ### Continue session: debug_session_id
#
# User > Using your incident definition and rules, decide if the following OSINT message
# is an INCIDENT or NOT INCIDENT, and return ONLY 1 or -1.
#
# MESSAGE:
# BLA says Four Pakistani Army Personnel Eliminated in Panjgur Attack .
# Agent2_GeoChecker > 1
#
#  ### Continue session: debug_session_id
#
# User > Using your incident definition and rules, decide if the following OSINT message
# is an INCIDENT or NOT INCIDENT, and return ONLY 1 or -1.
#
# MESSAGE:
# National Defence Academy during Monsoon
# Agent2_GeoChecker > -1
#
#  ### Continue session: debug_session_id
#
# User > Using your incident definition and rules, decide if the following OSINT message
# is an INCIDENT or NOT INCIDENT, and return ONLY 1 or -1.
#
# MESSAGE:
# This is the 4th attempt by PLA in the same area in the last few years. The last 3 attempts were thwarted.
# Agent2_GeoChecker > -1
#
#  ### Continue session: debug_session_id
#
# User > Using your incident definition and rules, decide if the following OSINT message
# is an INCIDENT or NOT INCIDENT, and return ONLY 1 or -1.
#
# MESSAGE:
# Correction-
#
# This attack is done by People's liberation Army (PLA) insurgent group. PLA is valley based insurgent group(VBIG)- Meitei.
# Agent2_GeoChecker > -1
#
#  ### Continue session: debug_session_id
#
# User > Using your incident definition and rules, decide if the following OSINT message
# is an INCIDENT or NOT INCIDENT, and return ONLY 1 or -1.
#
# MESSAGE:
# Hong Kong Fire incident:
#
# Death toll reaches 128.
# Agent2_GeoChecker > 1
#
#  ### Continue session: debug_session_id
#
# User > Using your incident definition and rules, decide if the following OSINT message
# is an INCIDENT or NOT INCIDENT, and return ONLY 1 or -1.
#
# MESSAGE:
# Statement from officials -A patrolling party of Assam Rifles was fired upon by terrorists in Tengnoupal district of Manipur, along the India-Myanmar Border in the early morning hours today. Operations are currently underway, with additional troops being deployed into the area.
# Agent2_GeoChecker > 1
#
#  ### Continue session: debug_session_id
#
# User > Using your incident definition and rules, decide if the following OSINT message
# is an INCIDENT or NOT INCIDENT, and return ONLY 1 or -1.
#
# MESSAGE:
# The trio reportedly took food from a local in Chilla Balotha village.
# Agent2_GeoChecker > -1
#
#  ### Continue session: debug_session_id
#
# User > Using your incident definition and rules, decide if the following OSINT message
# is an INCIDENT or NOT INCIDENT, and return ONLY 1 or -1.
#
# MESSAGE:
# Udhampur:Security forces have launched a major search operation in Basantgarh after movement of three suspected terrorists.
# Agent2_GeoChecker > 1
#
#  ### Continue session: debug_session_id
#
# User > Using your incident definition and rules, decide if the following OSINT message
# is an INCIDENT or NOT INCIDENT, and return ONLY 1 or -1.
#
# MESSAGE:
# Manipur: Reportedly PLA Terrorists attacked post BP-87
# in Tengnoupal (Manipur) around 4:30 am. 4 jawans are said to be injured.
# Agent2_GeoChecker > 1
#
#  ### Continue session: debug_session_id
#
# User > Using your incident definition and rules, decide if the following OSINT message
# is an INCIDENT or NOT INCIDENT, and return ONLY 1 or -1.
#
# MESSAGE:
# Kremlin:
#
# On December 4–5, Vladimir Putin will make a state visit to India at the invitation of Indian Prime Minister Narendra Modi
# Agent2_GeoChecker > -1
#
#  ### Continue session: debug_session_id
#
# User > Using your incident definition and rules, decide if the following OSINT message
# is an INCIDENT or NOT INCIDENT, and return ONLY 1 or -1.
#
# MESSAGE:
# UN urges Pakistan to 'fully uphold' Imran Khan's rights amid growing concern over jailed ex-PM's welfare
# Agent2_GeoChecker > -1
# [GeoChecker] Processed batch of 32 rows (total=32).
#
#  ### Continue session: debug_session_id
#
# User > Using your incident definition and rules, decide if the following OSINT message
# is an INCIDENT or NOT INCIDENT, and return ONLY 1 or -1.
#
# MESSAGE:
# NOTAM range extended to 3,485-km
# Agent2_GeoChecker > -1
#
#  ### Continue session: debug_session_id
#
# User > Using your incident definition and rules, decide if the following OSINT message
# is an INCIDENT or NOT INCIDENT, and return ONLY 1 or -1.
#
# MESSAGE:
# Reportedly RPG attack on a FC post
# Agent2_GeoChecker > 1
#
#  ### Continue session: debug_session_id
#
# User > Using your incident definition and rules, decide if the following OSINT message
# is an INCIDENT or NOT INCIDENT, and return ONLY 1 or -1.
#
# MESSAGE:
# Massive explosion in Wana South Waziristan
# Agent2_GeoChecker > 1
#
#  ### Continue session: debug_session_id
#
# User > Using your incident definition and rules, decide if the following OSINT message
# is an INCIDENT or NOT INCIDENT, and return ONLY 1 or -1.
#
# MESSAGE:
# Australia's Foreign Minister Penny Wong today announced that the Islamic Revolutionary Guard Corps (IRGC) has been officially designated as a state sponsor of terrorism by the Australian government. The listing, under Australia's counter-terrorism framework, means the IRGC is formally recognized as supporting terrorist activity, triggering stricter legal and financial measures against it.
# Agent2_GeoChecker > -1
#
#  ### Continue session: debug_session_id
#
# User > Using your incident definition and rules, decide if the following OSINT message
# is an INCIDENT or NOT INCIDENT, and return ONLY 1 or -1.
#
# MESSAGE:
# A quadcopter drone attack on a police post in Bannu district, Khyber Pakhtunkhwa province has injured two policemen: Police
# Agent2_GeoChecker > 1
#
#  ### Continue session: debug_session_id
#
# User > Using your incident definition and rules, decide if the following OSINT message
# is an INCIDENT or NOT INCIDENT, and return ONLY 1 or -1.
#
# MESSAGE:
# :)
# Agent2_GeoChecker > -1
#
#  ### Continue session: debug_session_id
#
# User > Using your incident definition and rules, decide if the following OSINT message
# is an INCIDENT or NOT INCIDENT, and return ONLY 1 or -1.
#
# MESSAGE:
# TOI:India's plan to acquire another five squad-rons of the S-400 Triumf air defence systems as well as a large number of its surface-to-air missiles for already in-ducted systems, which per-formed exceedingly well during Operation Sindoor, are likely to figure in discus-sions during the Modi-Putin summit here on Dec 5.
# Agent2_GeoChecker > -1
#
#  ### Continue session: debug_session_id
#
# User > Using your incident definition and rules, decide if the following OSINT message
# is an INCIDENT or NOT INCIDENT, and return ONLY 1 or -1.
#
# MESSAGE:
# American strategist Bruce Reidel had pointed out years ago that there was a third party behind the 26/11 attacks besides Pakistan’s ISI and Lashkar-e-Taiba (LeT). Reidel said that it was al-Qaeda, which had its own reasons for supporting that attack. He had argued that al-Qaeda deliberately kept a low profile and allowed LeT to select the Mumbai targets, making it appear that it was purely an Indo-Pak issue.
#
# Reidel also added that LeT had planned a big attack on New Delhi during the 2010 Commonwealth Games, which “was thwarted by prompt intelligence from the British services.”
# Agent2_GeoChecker > -1
#
#  ### Continue session: debug_session_id
#
# User > Using your incident definition and rules, decide if the following OSINT message
# is an INCIDENT or NOT INCIDENT, and return ONLY 1 or -1.
#
# MESSAGE:
# WSJ: After a tense call with China’s leader Xi Jinping, President Trump phoned Japanese Prime Minister Sanae Takaichi and urged her to soften her tone on Taiwan.
# Agent2_GeoChecker > -1
#
#  ### Continue session: debug_session_id
#
# User > Using your incident definition and rules, decide if the following OSINT message
# is an INCIDENT or NOT INCIDENT, and return ONLY 1 or -1.
#
# MESSAGE:
# You'll reap what you sow
#
# He was working with CIA in Afghanistan.
# Agent2_GeoChecker > -1
#
#  ### Continue session: debug_session_id
#
# User > Using your incident definition and rules, decide if the following OSINT message
# is an INCIDENT or NOT INCIDENT, and return ONLY 1 or -1.
#
# MESSAGE:
# He was part of The Zero One unit that was formed by American intelligence in Afghanistan.
# Name- Rahmanullah Laknwal
# Agent2_GeoChecker > -1
#
#  ### Continue session: debug_session_id
#
# User > Using your incident definition and rules, decide if the following OSINT message
# is an INCIDENT or NOT INCIDENT, and return ONLY 1 or -1.
#
# MESSAGE:
# When USA left Afghanistan, that so called Afghan army led by President Ashraf Ghani & fully funded by US and supported by Paijaan army collapsed within hours & Taliban took over Afghanistan.
# Agent2_GeoChecker > -1
#
#  ### Continue session: debug_session_id
#
# User > Using your incident definition and rules, decide if the following OSINT message
# is an INCIDENT or NOT INCIDENT, and return ONLY 1 or -1.
#
# MESSAGE:
# Interestingly that specific Afghan national has fought war against Taliban along with US Special forces. He was reportedly part of Afghan army that was working with Pak army & American Army.
# Agent2_GeoChecker > -1
#
#  ### Continue session: debug_session_id
#
# User > Using your incident definition and rules, decide if the following OSINT message
# is an INCIDENT or NOT INCIDENT, and return ONLY 1 or -1.
#
# MESSAGE:
# Yesterday two national guards were shot dead by an Afghan national near White house.
# Agent2_GeoChecker > 1
#
#  ### Continue session: debug_session_id
#
# User > Using your incident definition and rules, decide if the following OSINT message
# is an INCIDENT or NOT INCIDENT, and return ONLY 1 or -1.
#
# MESSAGE:
# 24 years old Pakistani intruder arrested from Barmer Rajasthan.
# Agent2_GeoChecker > 1
#
#  ### Continue session: debug_session_id
#
# User > Using your incident definition and rules, decide if the following OSINT message
# is an INCIDENT or NOT INCIDENT, and return ONLY 1 or -1.
#
# MESSAGE:
# "Pakiatan's arms shopping post Operation Sindoor matter of concern" - Commanding-in-Chief Western Naval command Vice Admiral K Swaminathan.
# Agent2_GeoChecker > -1
#
#  ### Continue session: debug_session_id
#
# User > Using your incident definition and rules, decide if the following OSINT message
# is an INCIDENT or NOT INCIDENT, and return ONLY 1 or -1.
#
# MESSAGE:
# 11 killed as train hits railway workers in southwest China.
# Agent2_GeoChecker > 1
#
#  ### Continue session: debug_session_id
#
# User > Using your incident definition and rules, decide if the following OSINT message
# is an INCIDENT or NOT INCIDENT, and return ONLY 1 or -1.
#
# MESSAGE:
# Hong Kong Fire incident:
#
# 42 people died & 280+ are said to be Injured/missing.
# Agent2_GeoChecker > 1
#
#  ### Continue session: debug_session_id
#
# User > Using your incident definition and rules, decide if the following OSINT message
# is an INCIDENT or NOT INCIDENT, and return ONLY 1 or -1.
#
# MESSAGE:
# Afghanistan has given Indian firms a 5-year tax break for investing in gold mining. Due to trade issues with Pakistan, Indian investors get a chance with low competition and only 1% duty on investments, says Minister Nooruddin.
# Agent2_GeoChecker > -1
#
#  ### Continue session: debug_session_id
#
# User > Using your incident definition and rules, decide if the following OSINT message
# is an INCIDENT or NOT INCIDENT, and return ONLY 1 or -1.
#
# MESSAGE:
# PAF jet activities over Peshawar
# Agent2_GeoChecker > -1
#
#  ### Continue session: debug_session_id
#
# User > Using your incident definition and rules, decide if the following OSINT message
# is an INCIDENT or NOT INCIDENT, and return ONLY 1 or -1.
#
# MESSAGE:
# Looks like Afghanistan has conducted drone strikes in Pakistan.
# Agent2_GeoChecker > -1
#
#  ### Continue session: debug_session_id
#
# User > Using your incident definition and rules, decide if the following OSINT message
# is an INCIDENT or NOT INCIDENT, and return ONLY 1 or -1.
#
# MESSAGE:
# Maoists responsible for the IED blast in Jharkhand.
# Agent2_GeoChecker > 1
#
#  ### Continue session: debug_session_id
#
# User > Using your incident definition and rules, decide if the following OSINT message
# is an INCIDENT or NOT INCIDENT, and return ONLY 1 or -1.
#
# MESSAGE:
# Paxtan will burn... Damn
# Agent2_GeoChecker > -1
#
#  ### Continue session: debug_session_id
#
# User > Using your incident definition and rules, decide if the following OSINT message
# is an INCIDENT or NOT INCIDENT, and return ONLY 1 or -1.
#
# MESSAGE:
# Chief Economic Adviser, V Anantha Nageswaran :
# GDP growth may surpass 7 pc to cross USD 4 tn in FY26.
# Agent2_GeoChecker > -1
#
#  ### Continue session: debug_session_id
#
# User > Using your incident definition and rules, decide if the following OSINT message
# is an INCIDENT or NOT INCIDENT, and return ONLY 1 or -1.
#
# MESSAGE:
# Woman killed, two others injured in IED blast in Jharkhand''s Chaibasa: Police
#
# ~ PTI
# Agent2_GeoChecker > 1
#
#  ### Continue session: debug_session_id
#
# User > Using your incident definition and rules, decide if the following OSINT message
# is an INCIDENT or NOT INCIDENT, and return ONLY 1 or -1.
#
# MESSAGE:
# India's GDP grew by 8.2% in the 2nd Quarter of this financial year.
#
# This growth is despite tarrifs by Trump, and the fact that GST cut was available only for a week in this quarter (September end)
# Golden days ahead
# Agent2_GeoChecker > -1
#
#  ### Continue session: debug_session_id
#
# User > Using your incident definition and rules, decide if the following OSINT message
# is an INCIDENT or NOT INCIDENT, and return ONLY 1 or -1.
#
# MESSAGE:
# National Defence Academy
# Agent2_GeoChecker > -1
#
#  ### Continue session: debug_session_id
#
# User > Using your incident definition and rules, decide if the following OSINT message
# is an INCIDENT or NOT INCIDENT, and return ONLY 1 or -1.
#
# MESSAGE:
# Pakistan: Maulana Qari Izzatullah was shot dead near University Town a short while ago, according to local sources.
#
# The attackers have not yet been identified, and police have launched an investigation into the incident.
# Agent2_GeoChecker > 1
#
#  ### Continue session: debug_session_id
#
# User > Using your incident definition and rules, decide if the following OSINT message
# is an INCIDENT or NOT INCIDENT, and return ONLY 1 or -1.
#
# MESSAGE:
# 1. Cyclone Ditwah has hit Sri Lanka, causing major loss of life and destruction.
#
# 2. India launched Operation Sagar Bandhu to provide urgent HADR support to its closest maritime neighbour.
#
# 3. INS Vikrant and INS Udaigiri delivered the first relief supplies to Colombo.
#
# 4. The mission reflects India’s Neighbourhood First and SAGAR vision, with PM Modi and EAM Dr. S. Jaishankar assuring full support to Sri Lanka.
# Agent2_GeoChecker > 1
#
#  ### Continue session: debug_session_id
#
# User > Using your incident definition and rules, decide if the following OSINT message
# is an INCIDENT or NOT INCIDENT, and return ONLY 1 or -1.
#
# MESSAGE:
# Khyber PakhtunKhwa
#
# The injured soldier of Frontier constabulary succumbed to his injuries in hospital.
# Agent2_GeoChecker > 1
#
#  ### Continue session: debug_session_id
#
# User > Using your incident definition and rules, decide if the following OSINT message
# is an INCIDENT or NOT INCIDENT, and return ONLY 1 or -1.
#
# MESSAGE:
# Nepal Reignites the Border dispute with Bharat:
#
# Nepal’s central bank unveiled new Rs 100 currency notes featuring a revised national map that includes the disputed Kalapani, Lipulekh, and Limpiyadhura regions, territories India has long maintained are its own.
#
# The redesigned currency incorporates the updated national map adopted during the K P Sharma Oli–led government, to include Kalapani, Lipulekh, and Limpiyadhura.
# Agent2_GeoChecker > -1
#
#  ### Continue session: debug_session_id
#
# User > Using your incident definition and rules, decide if the following OSINT message
# is an INCIDENT or NOT INCIDENT, and return ONLY 1 or -1.
#
# MESSAGE:
# Israeli forces carried out an incursion into the Syrian town of Beit Jinn in rural Damascus.
#
# Clashes reported between local residents and the troops, wherein IDF reportedly used artilleries and drones.
# Agent2_GeoChecker > 1
# [GeoChecker] Processed batch of 32 rows (total=64).
#
#  ### Continue session: debug_session_id
#
# User > Using your incident definition and rules, decide if the following OSINT message
# is an INCIDENT or NOT INCIDENT, and return ONLY 1 or -1.
#
# MESSAGE:
# The NOTAM for a likely missile test over the Bay of Bengal, scheduled from December 6 to 8, has been cancelled.
# Agent2_GeoChecker > -1
#
#  ### Continue session: debug_session_id
#
# User > Using your incident definition and rules, decide if the following OSINT message
# is an INCIDENT or NOT INCIDENT, and return ONLY 1 or -1.
#
# MESSAGE:
# MEA Press Release
# Agent2_GeoChecker > -1
#
#  ### Continue session: debug_session_id
#
# User > Using your incident definition and rules, decide if the following OSINT message
# is an INCIDENT or NOT INCIDENT, and return ONLY 1 or -1.
#
# MESSAGE:
# Bannu Police station attack responsibility
# Agent2_GeoChecker > -1
#
#  ### Continue session: debug_session_id
#
# User > Using your incident definition and rules, decide if the following OSINT message
# is an INCIDENT or NOT INCIDENT, and return ONLY 1 or -1.
#
# MESSAGE:
# On Friday, November 28, at midnight, the Mujahideen of the Pakistan Revolution Movement and the Burr and Jamaat jointly launched a counterattack on the Domail Ahmadzai police station. With the grace of Allah, the Mujahideen displayed great courage and captured the police station. During this time, more police and army troops also arrived from Bannu, with whom a fierce battle ensued. Alhamdulillah, according to reliable reports, several anti-Sharia police officers were killed and injured in this battle.
#
# Maulvi Ismail Khan, spokesman for the Pakistan Revolution
# Agent2_GeoChecker > 1
#
#  ### Continue session: debug_session_id
#
# User > Using your incident definition and rules, decide if the following OSINT message
# is an INCIDENT or NOT INCIDENT, and return ONLY 1 or -1.
#
# MESSAGE:
# The distance for the NOTAM has been extended further to approximately 3485 km (1882 NM).
# Agent2_GeoChecker > -1
#
#  ### Continue session: debug_session_id
#
# User > Using your incident definition and rules, decide if the following OSINT message
# is an INCIDENT or NOT INCIDENT, and return ONLY 1 or -1.
#
# MESSAGE:
# She absolutely cooked him.
# Correction: Obliterated him.
#
# Credits: China Insider with David Zhang
# Agent2_GeoChecker > -1
#
#  ### Continue session: debug_session_id
#
# User > Using your incident definition and rules, decide if the following OSINT message
# is an INCIDENT or NOT INCIDENT, and return ONLY 1 or -1.
#
# MESSAGE:
# Zydus Life signed a MoU worth $100 million with Kabul-based Raoufi Group
# Agent2_GeoChecker > -1
#
#  ### Continue session: debug_session_id
#
# User > Using your incident definition and rules, decide if the following OSINT message
# is an INCIDENT or NOT INCIDENT, and return ONLY 1 or -1.
#
# MESSAGE:
# Good morning
# Agent2_GeoChecker > -1
#
#  ### Continue session: debug_session_id
#
# User > Using your incident definition and rules, decide if the following OSINT message
# is an INCIDENT or NOT INCIDENT, and return ONLY 1 or -1.
#
# MESSAGE:
# Tajikistan MFA: "Three Chinese workers were killed in a drone strike from Afghanistan."
# Agent2_GeoChecker > 1
#
#  ### Continue session: debug_session_id
#
# User > Using your incident definition and rules, decide if the following OSINT message
# is an INCIDENT or NOT INCIDENT, and return ONLY 1 or -1.
#
# MESSAGE:
# A Pakistani spy identified as Farman son of Shah Jan, resident of Mohabbat Khel, who was involved in the killing of several rebels was executed by TTP rebels after he confessed to the crime.
# Agent2_GeoChecker > 1
#
#  ### Continue session: debug_session_id
#
# User > Using your incident definition and rules, decide if the following OSINT message
# is an INCIDENT or NOT INCIDENT, and return ONLY 1 or -1.
#
# MESSAGE:
# A loud explosion has been heard in Wana, South Waziristan
# Agent2_GeoChecker > 1
#
#  ### Continue session: debug_session_id
#
# User > Using your incident definition and rules, decide if the following OSINT message
# is an INCIDENT or NOT INCIDENT, and return ONLY 1 or -1.
#
# MESSAGE:
# Multiple dm in such a short time
#
# Look like we need a special team for this
# Agent2_GeoChecker > -1
#
#  ### Continue session: debug_session_id
#
# User > Using your incident definition and rules, decide if the following OSINT message
# is an INCIDENT or NOT INCIDENT, and return ONLY 1 or -1.
#
# MESSAGE:
# If you come across any online terror suspicious activity, extremist content, recruitment attempts online and you’re unsure about approaching the authorities directly you can confidentially forward the details to the Elitepredators admin.
#
# Your identity will always remain private. Even a small tip can prevent a larger threat.
#
# Report & don’t ignore.
#
# Contact us: @Contact_ep
# Agent2_GeoChecker > -1
#
#  ### Continue session: debug_session_id
#
# User > Using your incident definition and rules, decide if the following OSINT message
# is an INCIDENT or NOT INCIDENT, and return ONLY 1 or -1.
#
# MESSAGE:
# India plans to acquire 5 more S-400 Triumf air defence squadrons and additional surface to air missiles for existing systems. These topics are expected at the Modi-Putin summit on Dec 5.
#
# The PM-led CCS will also approve a ₹63,000 crore upgrade for 84 Sukhoi-30MKI fighters, enhancing radars, avionics, and weapons to extend their combat life by 30 years. The upgrade will be mostly indigenous, with some Russian involvement.
# Agent2_GeoChecker > -1
#
#  ### Continue session: debug_session_id
#
# User > Using your incident definition and rules, decide if the following OSINT message
# is an INCIDENT or NOT INCIDENT, and return ONLY 1 or -1.
#
# MESSAGE:
# Trump told Japan's PM to lower the volume on Taiwan.
#
# Trump spoke with Takaichi after Xi Jinping called the U.S. president and spoke about China's historic claim to the democratic self-governing island as well as Washington and Beijing’s joint responsibility to manage the world order.
# Agent2_GeoChecker > -1
#
#  ### Continue session: debug_session_id
#
# User > Using your incident definition and rules, decide if the following OSINT message
# is an INCIDENT or NOT INCIDENT, and return ONLY 1 or -1.
#
# MESSAGE:
# The NOTAM near the Andaman & Nicobar Islands for a likely missile test has been rescheduled to December 1–3.
# Agent2_GeoChecker > -1
#
#  ### Continue session: debug_session_id
#
# User > Using your incident definition and rules, decide if the following OSINT message
# is an INCIDENT or NOT INCIDENT, and return ONLY 1 or -1.
#
# MESSAGE:
# Peene ke liye paani nahi, khaane ke liye aata nahi hai...
#
# Par bhikh se aayaa paisa bohot hai...
# Agent2_GeoChecker > -1
#
#  ### Continue session: debug_session_id
#
# User > Using your incident definition and rules, decide if the following OSINT message
# is an INCIDENT or NOT INCIDENT, and return ONLY 1 or -1.
#
# MESSAGE:
# India has issued a NOTAM for Indian Air Force exercises near the western border in Rajasthan.
#
# IAF Exercises [ Dec 3 - Dec 6]
# Agent2_GeoChecker > -1
#
#  ### Continue session: debug_session_id
#
# User > Using your incident definition and rules, decide if the following OSINT message
# is an INCIDENT or NOT INCIDENT, and return ONLY 1 or -1.
#
# MESSAGE:
# The Biggest Attack Planned in India Averted!
# Agent2_GeoChecker > -1
#
#  ### Continue session: debug_session_id
#
# User > Using your incident definition and rules, decide if the following OSINT message
# is an INCIDENT or NOT INCIDENT, and return ONLY 1 or -1.
#
# MESSAGE:
# Safran and DRDO to develop a new engine together in India.
# Agent2_GeoChecker > -1
#
#  ### Continue session: debug_session_id
#
# User > Using your incident definition and rules, decide if the following OSINT message
# is an INCIDENT or NOT INCIDENT, and return ONLY 1 or -1.
#
# MESSAGE:
# Jammu Police arrested a 19-year-old Reasi native living in Bathindi, a key suspect in FIR 331/2025 u/s 113(3) BNS at PS Bahu Fort. He was allegedly radicalised online and in contact with foreign numbers. His digital devices were seized, and investigation continues.
# Agent2_GeoChecker > 1
#
#  ### Continue session: debug_session_id
#
# User > Using your incident definition and rules, decide if the following OSINT message
# is an INCIDENT or NOT INCIDENT, and return ONLY 1 or -1.
#
# MESSAGE:
# Back to work
#
# Now regular posting on EP Insight
# Agent2_GeoChecker > -1
#
#  ### Continue session: debug_session_id
#
# User > Using your incident definition and rules, decide if the following OSINT message
# is an INCIDENT or NOT INCIDENT, and return ONLY 1 or -1.
#
# MESSAGE:
# https://x.com/EPINSIGHTS/status/1993940649109016602
# Agent2_GeoChecker > -1
#
#  ### Continue session: debug_session_id
#
# User > Using your incident definition and rules, decide if the following OSINT message
# is an INCIDENT or NOT INCIDENT, and return ONLY 1 or -1.
#
# MESSAGE:
# The Family man Season 3
#
# Full time waste
# Agent2_GeoChecker > -1
#
#  ### Continue session: debug_session_id
#
# User > Using your incident definition and rules, decide if the following OSINT message
# is an INCIDENT or NOT INCIDENT, and return ONLY 1 or -1.
#
# MESSAGE:
# India is now projected to become a $5 trillion economy only in FY29, a year later than previously estimated, according to the IMF's latest staff consultation report released on November 26.
# Agent2_GeoChecker > -1
#
#  ### Continue session: debug_session_id
#
# User > Using your incident definition and rules, decide if the following OSINT message
# is an INCIDENT or NOT INCIDENT, and return ONLY 1 or -1.
#
# MESSAGE:
# Dominican Republic has authorized the US to use its air bases.
# Agent2_GeoChecker > -1
#
#  ### Continue session: debug_session_id
#
# User > Using your incident definition and rules, decide if the following OSINT message
# is an INCIDENT or NOT INCIDENT, and return ONLY 1 or -1.
#
# MESSAGE:
# US Special Forces launched a ground operation against the Islamic State of the Somalia Province (ISSP), in the Baalade Valley, Puntland, Somalia.
#
# Violent clashes erupted between the US troops and ISSP in the Cal-Miskaad mountain range.
#
# At least 100 US SF personnel were carrying out the ground operation.
# Agent2_GeoChecker > 1
#
#  ### Continue session: debug_session_id
#
# User > Using your incident definition and rules, decide if the following OSINT message
# is an INCIDENT or NOT INCIDENT, and return ONLY 1 or -1.
#
# MESSAGE:
# Two US National Guard members were shot near the White House in an apparent ambush.
# Agent2_GeoChecker > 1
#
#  ### Continue session: debug_session_id
#
# User > Using your incident definition and rules, decide if the following OSINT message
# is an INCIDENT or NOT INCIDENT, and return ONLY 1 or -1.
#
# MESSAGE:
# Well, don't come here illegally and don't film sensitive areas.
#
# Spectacular timing. The Old Man ain't holding back...
# Agent2_GeoChecker > -1
#
#  ### Continue session: debug_session_id
#
# User > Using your incident definition and rules, decide if the following OSINT message
# is an INCIDENT or NOT INCIDENT, and return ONLY 1 or -1.
#
# MESSAGE:
# 44 dead and 300+ missing after massive fire engulfed several high rise residential towers in Hong Kong!!
#
# Three senior staff from construction company have been arrested on suspicion of manslaughter
# Agent2_GeoChecker > 1
#
#  ### Continue session: debug_session_id
#
# User > Using your incident definition and rules, decide if the following OSINT message
# is an INCIDENT or NOT INCIDENT, and return ONLY 1 or -1.
#
# MESSAGE:
# Afghanistan
# Agent2_GeoChecker > -1
#
#  ### Continue session: debug_session_id
#
# User > Using your incident definition and rules, decide if the following OSINT message
# is an INCIDENT or NOT INCIDENT, and return ONLY 1 or -1.
#
# MESSAGE:
# Unknown drones reportedly carried out strikes on ISIS-linked locations in the Jabar Mela area of Khyber District, Khyber Pakhtunkhwa, according to Al-Mersad.
# The area hosts key ISIS-K figures, including Gul Nazim, Sadiqyar, and Hudhaifa. Nazim, who leads ISIS-K’s eastern zone, has been active in Jabar Mela since 2024.
# Agent2_GeoChecker > 1
# [GeoChecker] Processed batch of 32 rows (total=96).
#
#  ### Continue session: debug_session_id
#
# User > Using your incident definition and rules, decide if the following OSINT message
# is an INCIDENT or NOT INCIDENT, and return ONLY 1 or -1.
#
# MESSAGE:
# EP×Exclusive: A propaganda poster linked to the banned terror group Jaish-e-Mohammad is circulating online, advertising a digital package of religious and jihadi lectures and publications for Rs 1000. The material includes hundreds of audio files, sermons, and tafseer recordings on USB and memory cards, along with a contact number for buyers.
#
# The poster shows the group’s continued efforts to spread its ideology through digital distribution.
#
# Details blurred due to security reasons.
# Agent2_GeoChecker > -1
#
#  ### Continue session: debug_session_id
#
# User > Using your incident definition and rules, decide if the following OSINT message
# is an INCIDENT or NOT INCIDENT, and return ONLY 1 or -1.
#
# MESSAGE:
# The suspect in the DC National Guard shooting has been identified as 29-year-old Afghan National Rahmanullah Lakanwal.
# Agent2_GeoChecker > 1
#
#  ### Continue session: debug_session_id
#
# User > Using your incident definition and rules, decide if the following OSINT message
# is an INCIDENT or NOT INCIDENT, and return ONLY 1 or -1.
#
# MESSAGE:
# INS Vikrant in Sri Lanka for an International Fleet Review to mark the 75th Anniversary of Sri Lankan Navy.
# Agent2_GeoChecker > -1
#
#  ### Continue session: debug_session_id
#
# User > Using your incident definition and rules, decide if the following OSINT message
# is an INCIDENT or NOT INCIDENT, and return ONLY 1 or -1.
#
# MESSAGE:
# Kash Patel, FBI Director:
#
# Guardsmen are alive but critical. They have been taken for treatment.
#
# The suspect was taken into custody.
#
# Investigation and interrogation to follow.
#
# DC Mayor and Metro PD chief were among the other top officials present there.
# Agent2_GeoChecker > 1
#
#  ### Continue session: debug_session_id
#
# User > Using your incident definition and rules, decide if the following OSINT message
# is an INCIDENT or NOT INCIDENT, and return ONLY 1 or -1.
#
# MESSAGE:
# Washington, DC:
#
# An unidentified individual, shot two US Army National Guards near the WH.
#
# Guardsmen are critically wounded and being treated.
#
# Suspect in custody.
#
# FBI, Metro PD, etc were rushed to the spot.
# Agent2_GeoChecker > 1
#
#  ### Continue session: debug_session_id
#
# User > Using your incident definition and rules, decide if the following OSINT message
# is an INCIDENT or NOT INCIDENT, and return ONLY 1 or -1.
#
# MESSAGE:
# Surrender army surrenders again to TTP protesters
# Imran Khan's sister Aleema Khan was allowed to meet him in Adiala Jail.
# Agent2_GeoChecker > -1
#
#  ### Continue session: debug_session_id
#
# User > Using your incident definition and rules, decide if the following OSINT message
# is an INCIDENT or NOT INCIDENT, and return ONLY 1 or -1.
#
# MESSAGE:
# Nigeria declares Nationwide State of Emergency amid escalating insurgency And kidnapping crisis.
# Agent2_GeoChecker > 1
#
#  ### Continue session: debug_session_id
#
# User > Using your incident definition and rules, decide if the following OSINT message
# is an INCIDENT or NOT INCIDENT, and return ONLY 1 or -1.
#
# MESSAGE:
# Well well well.
#
# Waiting for the WH to rename it as NBC Fake News.
# Agent2_GeoChecker > -1
#
#  ### Continue session: debug_session_id
#
# User > Using your incident definition and rules, decide if the following OSINT message
# is an INCIDENT or NOT INCIDENT, and return ONLY 1 or -1.
#
# MESSAGE:
# Two lawyers from Nuh, Haryana were arrested for spying for ISI.
#
# -- Rizwan Khan and his associate Musharraf aka Parvez.
# Agent2_GeoChecker > 1
#
#  ### Continue session: debug_session_id
#
# User > Using your incident definition and rules, decide if the following OSINT message
# is an INCIDENT or NOT INCIDENT, and return ONLY 1 or -1.
#
# MESSAGE:
# India's most successful counterinsurgency operation in #kashmir | Indian Army
# | Assam Rifles
#
# — when 72 terrorists were KILLED in one day🇮🇳🇮🇳🇮🇳
# Agent2_GeoChecker > 1
#
#  ### Continue session: debug_session_id
#
# User > Using your incident definition and rules, decide if the following OSINT message
# is an INCIDENT or NOT INCIDENT, and return ONLY 1 or -1.
#
# MESSAGE:
# Assam rifles/AR patrolling party ambushed in Saibol (Manipur);
# 4 soldiers injured
#
# Today, four Assam Rifles soldiers were injured when terrorists opened fire on their patrol in Manipur’s Tengnoupal district near the India 🇮🇳Myanmar🇲🇲- border.
#
# The incident took place close to border pillar No. 87 near Saibol village.
#
# In an official statement, the Defence Ministry confirmed that terrorists along the India-Myanmar border targeted the Assam Rifles patrol this morning. The troops responded with controlled and cautious retaliation to ensure civilian safety.
#
# The attack occurred in a porous border area of Tengnoupal district known for frequent militant activity.
#
# As of now, no insurgent group has claimed responsibility for the ambush.
#
# @ResonantNews
# Agent2_GeoChecker > 1
#
#  ### Continue session: debug_session_id
#
# User > Using your incident definition and rules, decide if the following OSINT message
# is an INCIDENT or NOT INCIDENT, and return ONLY 1 or -1.
#
# MESSAGE:
# Part-1️⃣🚨BIG!
#
# 👉Awantipora Police, along with 42 #RashtriyaRifles and 180 Battalion #CRPF, busted a Jaish-e-Mohammad (JeM)-linked hideout in south #Kashmir.
#
# 👉Operation was launched on Friday based on specific intelligence about terrorist presence in Naner Midoora area of Tral.
# A joint cordon-and-search operation was conducted in the area.
# 👉Forces apprehended a key terror associate identified as Nazir Ahmed Ganai, son of Abdul Aziz Ganai, resident of Ganai Mohalla Nanar.
#
# The arrested individual has known links with proscribed terrorist outfit Jaish-e-Mohammad (JeM).
# During sustained questioning, Nazir Ahmed Ganai disclosed the location of a concealed hideout in his own orchards.
# 👉Security forces unearthed the hideout and recovered:Two hand grenades
# One detonator
# Explosive-like material
#
# Join Kashmir Conflict stories
# Agent2_GeoChecker > 1
#
#  ### Continue session: debug_session_id
#
# User > Using your incident definition and rules, decide if the following OSINT message
# is an INCIDENT or NOT INCIDENT, and return ONLY 1 or -1.
#
# MESSAGE:
# BREAKING: KABUL SEEKS IMPARTIAL PROBE AS AFGHAN LINK TO US NATIONAL GUARD ATTACK SPARKS TENSION
#
# Taliban spokesperson Suhail Shaheen has alleged that Pakistan’s ISI may be trying to damage Afghanistan’s reputation by linking it to the recent shooting of US National Guard soldiers near the White House, insisting Kabul does not allow its soil to be used for foreign attacks.
#
# Calling for a professional, unbiased investigation, the Taliban said all “possibilities” must be examined, including external intelligence networks, as Washington tightens Afghan immigration checks after the incident.
#
# #Afghanistan #ISI #DCshooting #Taliban #Pakistan #USSecurity
#
# 📍 @ResonantNews
# Agent2_GeoChecker > 1
#
#  ### Continue session: debug_session_id
#
# User > Using your incident definition and rules, decide if the following OSINT message
# is an INCIDENT or NOT INCIDENT, and return ONLY 1 or -1.
#
# MESSAGE:
# BREAKING: STATE’S REFUSAL TO IMPLEMENT NEW LABOUR REFORMS RISKS CONFUSION, STALLED PROTECTIONS FOR GIG AND INFORMAL WORKERS
#
# Kerala Labour Minister V Sivankutty has bluntly declared that the state will not implement the Centre’s four new Labour Codes, even as most other states move ahead with the reforms.
#
# The decision means workers in Kerala may miss out on key benefits like universal social security for gig workers, mandatory appointment letters, statutory minimum wages and stricter rules on timely payment that the central codes promise.
#
# Critics warn that keeping the old patchwork of laws while the rest of India transitions to a new framework could create legal uncertainty, deter investment and leave many vulnerable workers stuck in limbo as the government sits on draft regulations it prepared back in 2021 without acting for three years.
#
# #Kerala #LabourCodes #WorkersRights #GigWorkers #TradeUnions #LabourReform #IndiaNews
#
# 📍 @ResonantNews
# Agent2_GeoChecker > -1
#
#  ### Continue session: debug_session_id
#
# User > Using your incident definition and rules, decide if the following OSINT message
# is an INCIDENT or NOT INCIDENT, and return ONLY 1 or -1.
#
# MESSAGE:
# BREAKING: MACRON’S 10-MONTH PROGRAMME AIMED AT BUILDING RESERVES AMID RUSSIA THREAT
#
# Nearly three decades after ending conscription, President Emmanuel Macron has unveiled a 10-month voluntary military service for mainly 18–19 year olds, citing the deteriorating security environment and Russia’s war in Ukraine.
#
# The scheme, to start next summer, will keep volunteers within French and overseas territories, bolster reserves, and form a “hybrid army model” combining active troops, reservists and trained youth.
#
# #France #MilitaryService #Macron #UkraineWar #NATO #Defence
#
# 📍 @ResonantNews
# Agent2_GeoChecker > -1
#
#  ### Continue session: debug_session_id
#
# User > Using your incident definition and rules, decide if the following OSINT message
# is an INCIDENT or NOT INCIDENT, and return ONLY 1 or -1.
#
# MESSAGE:
# WATCH
#
# 3 Chinese men killed in a drone strike from Afghanistan inside Tajikistan
#
# 2nd such incident in last one year‼️
#
# The Chinese and Pakistanis are slowly losing hope of dominating in CENTRAL ASIA.
#
# You can also read about BOTH the incidents on ResonantNews website
# Agent2_GeoChecker > 1
#
#  ### Continue session: debug_session_id
#
# User > Using your incident definition and rules, decide if the following OSINT message
# is an INCIDENT or NOT INCIDENT, and return ONLY 1 or -1.
#
# MESSAGE:
# BREAKING: MIGRANT ACCUSED OF DC ATTACK WAS PREVIOUSLY EVACUATED AFTER AIDING AMERICAN MISSIONS IN KABUL
#
# The Afghan migrant charged with shooting two National Guard soldiers near the White House had worked with the US military, CIA and special forces before being evacuated in 2021 as the Taliban took over Afghanistan.
#
# US media reports highlight the challenges of refugee vetting after his arrival on emergency flights, adding new focus to crime and security debates around former foreign partners.
#
# #NationalGuard #DCshooting #AfghanRefugee #USMilitary #Security #BreakingNews
#
# 📍 @ResonantNews
# Agent2_GeoChecker > 1
#
#  ### Continue session: debug_session_id
#
# User > Using your incident definition and rules, decide if the following OSINT message
# is an INCIDENT or NOT INCIDENT, and return ONLY 1 or -1.
#
# MESSAGE:
# BREAKING: BANGLADESH’S OPPOSITION ESCALATES “RESISTANCE MARCHES,” CALLS FOR INTERIM GOVERNMENT RESIGNATION
#
# Bangladesh’s Awami League has announced sweeping district-level protests and marches in response to the “illegal” death sentence imposed on ousted PM Sheikh Hasina.
#
# The party accuses the Nobel Laureate Muhammad Yunus-led government of political conspiracy to block Hasina’s return ahead of February’s polls, vowing to resist “any attempt to exclude pro-liberation forces.”
#
# ...
#
# #WestBengal #SIR2025 #VoterList #ElectionCommission #BLO #Democracy
#
# 📍 @ResonantNews
# Agent2_GeoChecker > -1
#
#  ### Continue session: debug_session_id
#
# User > Using your incident definition and rules, decide if the following OSINT message
# is an INCIDENT or NOT INCIDENT, and return ONLY 1 or -1.
#
# MESSAGE:
# 🔴Afghans remind retiring Pakistani General of the wars Pakistan has lost
#
# General (Gen) Sahir Shamshad Mirza has recently retired as Pakistan's Chairman of the Joint Chiefs of Staff Committee (CJCSC) on November 27, 2025.
#
# Pakistan is in the process of effectively abolishing the permanent post of the Chairman Joint Chiefs of Staff Committee (CJCSC).
#
# @ResonantNews
# Agent2_GeoChecker > -1
#
#  ### Continue session: debug_session_id
#
# User > Using your incident definition and rules, decide if the following OSINT message
# is an INCIDENT or NOT INCIDENT, and return ONLY 1 or -1.
#
# MESSAGE:
# HEADLINE
#
# 27/28 - NOVEMBER - 2025
#
# 📍India Rebukes Pakistan Over Ayodhya Remarks
# Diplomatic S**t Heats Up Amid Bigotry
# Read more....
#
# 📍India’s $5 Trillion Economy Goal Delayed by IMF Projections
# Read more....
#
# 📍Amdavad, India Confirmed as Host of 2030 Centenary Games
# Read more....
#
# 📍Australia to Enforce Social Media Ban for Children Under 16
# Read more....
#
# 📍US National Guard Shooting: Afghan Suspect Identified
# Read more....
#
# 📍Taiwan Unveils $40 Billion Defence Budget to Deter China
# Read more....
#
# 📍Bangladesh Slum Fire Leaves Thousands Homeless
# Read more....
#
# 📍India–Nepal Joint Military Exercise ‘Suryakiran-XIX’ Begins in Uttarakhand
# Read more....
#
# 🎥 7 Pakistani Soldiers Killed In 2 Different Attacks
# Video.....
#
# 📍Guinea-Bissau Army Chief Takes Transitional Presidency Amid Coup
# Read more....
#
# 🎥 Pakistan backed JeM Terrorist In Syria
# Video.....
#
# RESONANT NEWS
# Agent2_GeoChecker > 1
#
#  ### Continue session: debug_session_id
#
# User > Using your incident definition and rules, decide if the following OSINT message
# is an INCIDENT or NOT INCIDENT, and return ONLY 1 or -1.
#
# MESSAGE:
# MORNING SHLOK
#
# वक्रतुण्ड महाकाय सूर्यकोटि समप्रभः ।
# निर्विघ्नं कुरु मे देव सर्वकार्येषु सर्वदा ॥
#
# O Ganesha with curved trunk and vast form, shining like a crore of suns, make all my tasks obstacle-free forever
# Agent2_GeoChecker > -1
#
#  ### Continue session: debug_session_id
#
# User > Using your incident definition and rules, decide if the following OSINT message
# is an INCIDENT or NOT INCIDENT, and return ONLY 1 or -1.
#
# MESSAGE:
# WARNING WARNING WARNING
# Pakistan backed JeM Terrorist in Syria ‼️
#
# He statement and description of the incident confirms HTS grp (which is ruling Syria right now) is collaborating with JeM.
#
# So how do we know Syria's HTS and Pakistan's JeM are collaborating?
#
# The location and incident he mentioned took place when HTS took over the oldest mosque in Syria.
#
# You can read about it here https://resonantnews.com/2025/11/27/pakistan-backed-jem-in-syria-is-syrian-hts-collaborating-with-pakistans-jem-terror-group/
#
# Earlier in Aug we had posted that Syrian HTS men had visited #ISI HQ in Pakistan
#
# @ResonantNews
# Agent2_GeoChecker > 1
#
#  ### Continue session: debug_session_id
#
# User > Using your incident definition and rules, decide if the following OSINT message
# is an INCIDENT or NOT INCIDENT, and return ONLY 1 or -1.
#
# MESSAGE:
# BREAKING: MILITARY SUSPENDS INSTITUTIONS, REOPENS BORDERS AFTER ELECTION TURMOIL
#
# General Horta Nta Na Man has assumed the role of "transitional president" after the High Military Command staged a coup in Guinea-Bissau, citing election instability and a plot by “drug lords” to alter the constitutional order.
#
# The military dissolved state institutions, shut media, closed borders (later reopened), and imposed a curfew in Bissau following disputed election results where both incumbent President Umaro Sissoco Embaló and challenger Fernando Dias claimed victory.
#
# International observers, the African Union, and ECOWAS have called for the return of constitutional governance as the West African nation faces yet another episode of political unrest and transitions led by its armed forces.
#
# #GuineaBissau #Coup #TransitionalPresident #MilitaryTakeover #PoliticalCrisis #AfricaNews #Democracy #BreakingNews
#
# 📍 @ResonantNews
# Agent2_GeoChecker > 1
#
#  ### Continue session: debug_session_id
#
# User > Using your incident definition and rules, decide if the following OSINT message
# is an INCIDENT or NOT INCIDENT, and return ONLY 1 or -1.
#
# MESSAGE:
# https://youtu.be/JE6ucjl2wTw
# Agent2_GeoChecker > -1
#
#  ### Continue session: debug_session_id
#
# User > Using your incident definition and rules, decide if the following OSINT message
# is an INCIDENT or NOT INCIDENT, and return ONLY 1 or -1.
#
# MESSAGE:
# WARNING WARNING WARNING
# Pakistan backed JeM Terrorist in Syria ‼️
#
# He statement and description of the incident confirms HTS grp (which is ruling Syria right now) is collaborating with JeM.
#
# So how do we know Syria's HTS and Pakistan's JeM are collaborating?
#
# The location and incident he mentioned took place when HTS took over the oldest mosque in Syria.
#
# You can read about it here https://resonantnews.com/2025/11/27/pakistan-backed-jem-in-syria-is-syrian-hts-collaborating-with-pakistans-jem-terror-group/
#
# Earlier in Aug we had posted that Syrian HTS men had visited #ISI HQ in Pakistan
#
# @ResonantNews
# Agent2_GeoChecker > 1
#
#  ### Continue session: debug_session_id
#
# User > Using your incident definition and rules, decide if the following OSINT message
# is an INCIDENT or NOT INCIDENT, and return ONLY 1 or -1.
#
# MESSAGE:
# 7 Pakistani soldiers killed in 2 diff attacks by BLA
#
# After reducing intensity of attacks in November, Baloch group BLA hits Pakistani forces again.
#
# Loc: Panjgur and Mastung (map)
#
# @ResonantNews
# Agent2_GeoChecker > 1
#
#  ### Continue session: debug_session_id
#
# User > Using your incident definition and rules, decide if the following OSINT message
# is an INCIDENT or NOT INCIDENT, and return ONLY 1 or -1.
#
# MESSAGE:
# WARNING WARNING WARNINGSaudi authorities crack a whip on Pakistani drug network in Medinah
#
# Few Pakistani men involved in ice (meth) trade arrested in a massive op by Saudi authorities. 👇👇👇
#
# https://youtube.com/shorts/RYnioaOBQr0?si=MYs1L8Kab9stk2cV
# Agent2_GeoChecker > 1
#
#  ### Continue session: debug_session_id
#
# User > Using your incident definition and rules, decide if the following OSINT message
# is an INCIDENT or NOT INCIDENT, and return ONLY 1 or -1.
#
# MESSAGE:
# LeT-JeM Terror Nexus Exposed: Key Operatives Link Bangladesh Routes to Pahalgam Attack
#
# Recent intelligence has fully unraveled the deepening ties between Lashkar-e-Taiba (LeT) and Jaish-e-Mohammed (JeM), with a high-level meeting between LeT's Bahawalpur head Saifullah Saif and PoK deputy Rizwan Hanif confirming their joint operational coordination.
#
# This duo has been pivotal in orchestrating cross-group activities, raising alarms over escalating threats to India's security landscape.
#
# Follow Kashmir Disinfo Lab
# Agent2_GeoChecker > -1
# [GeoChecker] Processed batch of 32 rows (total=128).
#
#  ### Continue session: debug_session_id
#
# User > Using your incident definition and rules, decide if the following OSINT message
# is an INCIDENT or NOT INCIDENT, and return ONLY 1 or -1.
#
# MESSAGE:
# Kulgam Police Launch Major Raids on Banned JeI Network
#
# Kulgam Police executed swift, coordinated raids across the district targeting the banned Jamaat-e-Islami (JeI), recovering electronic gadgets and incriminating documents.
#
# This operation underscores ongoing efforts to dismantle terror-linked networks in Jammu & Kashmir.
#
# No arrests reported yet, but investigations continue.
#
# #KulgamRaids #JeI #JammuKashmirSecurity #IndiaSecurity
#
# Join Kashmir conflict stories
# Agent2_GeoChecker > 1
#
#  ### Continue session: debug_session_id
#
# User > Using your incident definition and rules, decide if the following OSINT message
# is an INCIDENT or NOT INCIDENT, and return ONLY 1 or -1.
#
# MESSAGE:
# WARNING WARNING WARNINGDeclassified: Indian Army's MOST BRUTAL revenge attack.
#
# Not for the WEAK hearted ‼️
#
# Complete video: https://youtu.be/JE6ucjl2wTw
# Agent2_GeoChecker > -1
#
#  ### Continue session: debug_session_id
#
# User > Using your incident definition and rules, decide if the following OSINT message
# is an INCIDENT or NOT INCIDENT, and return ONLY 1 or -1.
#
# MESSAGE:
# BREAKING: 334 TROOPS FROM EACH NATION UNITE FOR HIGH-ALTITUDE COUNTER-TERROR AND DISASTER RELIEF DRILLS IN HIMALAYAS
#
# The 19th edition of Exercise Suryakiran kicked off in Uttarakhand’s Pithoragarh district, bringing together 334 soldiers each from the Indian Army’s Assam Regiment and the Nepal Army’s Devi Dutta Regiment for intensive training in mountain warfare, counter-terror operations, and humanitarian response.
#
# This two-week exercise will enhance interoperability and deepen military ties, focusing on modern tactics and tech-enabled operations to bolster security cooperation in the Himalayan region.
#
# #Suryakiran #IndiaNepal #MilitaryExercise #Uttarakhand #CounterTerror #DefenceCooperation #Himalayas #IndianArmy #NepalArmy
#
# 📍 @ResonantNews
# Agent2_GeoChecker > -1
#
#  ### Continue session: debug_session_id
#
# User > Using your incident definition and rules, decide if the following OSINT message
# is an INCIDENT or NOT INCIDENT, and return ONLY 1 or -1.
#
# MESSAGE:
# BREAKING: BLAZE DEVASTATES OVER 1,500 KORAIL SHANTIES, FAMILIES FLEE DHAKA SETTLEMENT OVERNIGHT
#
# A massive fire ripped through Dhaka’s crowded Korail slum, destroying more than 1,500 makeshift homes and leaving thousands of people with nowhere to sleep but the open streets.
#
# Rescue workers scrambled to assist and government officials are assessing damage as one of the worst urban blazes in years exposes harsh realities for Bangladesh’s poorest residents.
#
# #DhakaFire #Bangladesh #SlumFire #Korail #Disaster #UrbanPoverty #BreakingNews
#
# 📍 @ResonantNews
# Agent2_GeoChecker > 1
#
#  ### Continue session: debug_session_id
#
# User > Using your incident definition and rules, decide if the following OSINT message
# is an INCIDENT or NOT INCIDENT, and return ONLY 1 or -1.
#
# MESSAGE:
# BREAKING: LAI CHING-TE’S PLAN BOOSTS MISSILES, DRONES, AIR DEFENCE TO COUNTER PLA THREATS
#
# President Lai’s government announced a massive $40 billion multi-year defence package, aiming to reinforce missile shields, anti-ship systems, drone fleets and reserve forces to deter increasing Chinese military activity.
#
# The landmark decision puts defence at 5% of GDP and seeks deeper arms accords with the US.
#
# #Taiwan #DefenceBudget #ChinaThreat #MissileShield #Taipei #Security
#
# 📍 @ResonantNews
# Agent2_GeoChecker > -1
#
#  ### Continue session: debug_session_id
#
# User > Using your incident definition and rules, decide if the following OSINT message
# is an INCIDENT or NOT INCIDENT, and return ONLY 1 or -1.
#
# MESSAGE:
# BREAKING: DC ATTACK SUSPECT ENTERED US AS A MIGRANT IN 2021, FBI PROBES TERROR ANGLE
#
# Authorities identified 29-year-old Rahmanullah Lakanwal, an Afghan national, as the gunman who shot two National Guard soldiers near the White House.
#
# The FBI and local security agencies have launched terrorism investigations, while the US government reviews Afghan migration records amid fresh security concerns.
#
# #DCshooting #NationalGuard #AfghanSuspect #Security #Breaking #USA
#
# 📍 @ResonantNews
# Agent2_GeoChecker > 1
#
#  ### Continue session: debug_session_id
#
# User > Using your incident definition and rules, decide if the following OSINT message
# is an INCIDENT or NOT INCIDENT, and return ONLY 1 or -1.
#
# MESSAGE:
# BREAKING: LANDMARK LAW FACES COURT CHALLENGE, SPARKS ONLINE SAFETY DEBATE
#
# Australia’s government will implement a nationwide ban on social media use for children under 16 despite pending court cases, citing rising concerns over youth mental health and cyberbullying.
#
# Supporters hail the move as proactive, while critics argue it restricts digital freedom and parental rights.
#
# #Australia #SocialMediaBan #ChildSafety #OnlineSafety #YouthPolicy #LegalDebate
#
# 📍 @ResonantNews
# Agent2_GeoChecker > -1
#
#  ### Continue session: debug_session_id
#
# User > Using your incident definition and rules, decide if the following OSINT message
# is an INCIDENT or NOT INCIDENT, and return ONLY 1 or -1.
#
# MESSAGE:
# BANGLADESH’S BGB REHEARSES “HOW TO TACKLE ELECTION DAY CROWD”
#
# In preparation for upcoming 13th National Parliamentary Election, Border Guard Bangladesh (BGB) conducted an election training drill.
#
# @ResonantNews
# Agent2_GeoChecker > -1
#
#  ### Continue session: debug_session_id
#
# User > Using your incident definition and rules, decide if the following OSINT message
# is an INCIDENT or NOT INCIDENT, and return ONLY 1 or -1.
#
# MESSAGE:
# BREAKING: GLOBAL SPORTING EVENT RETURNS TO INDIAN SOIL AFTER DECADES
#
# Amdavad (Ahmedabad) is named host for the prestigious 2030 Centenary Games, with massive infrastructural and sporting preparations underway to welcome global athletes.
#
# India’s selection highlights renewed ambitions for global sporting reputation and inclusive celebration.
#
# #CentenaryGames #Amdavad2030 #IndiaSport #GlobalEvent #Ahmedabad
#
# 📍 @ResonantNews
# Agent2_GeoChecker > -1
#
#  ### Continue session: debug_session_id
#
# User > Using your incident definition and rules, decide if the following OSINT message
# is an INCIDENT or NOT INCIDENT, and return ONLY 1 or -1.
#
# MESSAGE:
# Death toll in Hong Kong fire rises to 44 with 279 still missing
#
# At least 44 people have been killed in a major fire engulfing public housing apartments in Hong Kong's Tai Po district - more than 270 people are still not accounted for
#
# Three construction company executives have been arrested on suspicion of manslaughter connected to flammable materials that may have allowed the fire to spread quickly
#
# After 18 hours, officials said the fire was under control - it has been classified a level five blaze, the most serious level in Hong Kong
#
# @ResonantNews
# Agent2_GeoChecker > 1
#
#  ### Continue session: debug_session_id
#
# User > Using your incident definition and rules, decide if the following OSINT message
# is an INCIDENT or NOT INCIDENT, and return ONLY 1 or -1.
#
# MESSAGE:
# BREAKING: GROWTH SETBACK PUSHES AMBITION TO LATE 2028, DATA SHOWS
#
# The IMF confirmed India will reach the $5 trillion GDP milestone a year later than expected, reflecting slowed recovery post-pandemic and global headwinds.
#
# Policy reforms and investments remain vital as the country strives to regain growth momentum and leadership in the global economy.
#
# #IndiaEconomy #IMF #GrowthDelay #GDP #GlobalFinance #5TrillionGoal
#
# 📍 @ResonantNews
# Agent2_GeoChecker > -1
#
#  ### Continue session: debug_session_id
#
# User > Using your incident definition and rules, decide if the following OSINT message
# is an INCIDENT or NOT INCIDENT, and return ONLY 1 or -1.
#
# MESSAGE:
# BREAKING: ALLEGATIONS AND RELIGIOUS TENSIONS
#
# India sharply criticized Pakistan’s comments on Ayodhya, calling it a “country with a stained record of bigotry” and rejecting religious interference in internal matters.
#
# The exchange deepened diplomatic tensions, fueled by historical disputes and both sides trading accusations of intolerance.
#
# #IndiaPakistan #Ayodhya #Bigotry #DiplomaticRow #SouthAsia
#
# 📍 @ResonantNews
# Agent2_GeoChecker > -1
#
#  ### Continue session: debug_session_id
#
# User > Using your incident definition and rules, decide if the following OSINT message
# is an INCIDENT or NOT INCIDENT, and return ONLY 1 or -1.
#
# MESSAGE:
# BANGLADESH’S BGB REHEARSES “HOW TO TACKLE ELECTION DAY CROWD”
#
# In preparation for upcoming 13th National Parliamentary Election, Border Guard Bangladesh (BGB) conducted an election training drill.
#
# @ResonantNews
# Agent2_GeoChecker > -1
#
#  ### Continue session: debug_session_id
#
# User > Using your incident definition and rules, decide if the following OSINT message
# is an INCIDENT or NOT INCIDENT, and return ONLY 1 or -1.
#
# MESSAGE:
# MORNING SHLOK
#
# कराग्रे वसते लक्ष्मीः करमध्यं सरस्वती ।
# करमूले तु गोविन्दः प्रभाते करदर्शनम् ॥
#
# On the tips of the fingers resides Lakshmi, in the palm's center Saraswati, at the base Govinda; behold your hands at dawn
# Agent2_GeoChecker > -1
# [GeoChecker] Processed batch of 14 rows (total=142).
# [GeoChecker] Done. Total rows labeled: 142
# [GeoChecker] Completed.

# %%
conn = sqlite3.connect("incidents.db")
pd.read_sql_query(
    "SELECT checked, COUNT(*) as n FROM events GROUP BY checked",
    conn
)
# Out:
#    checked   n
# 0       -1  88
# 1        1  54

# %% [markdown]
# 54 text pieces contain a geographic element

# %% [markdown]
# ---
#
# # 🔁 Agent 3 — Contextual Deduplication
# ### *Ensuring each real-world incident appears only once*
#
# The same incident may be reported by:
#
# - multiple channels
# - multiple message styles
# - multiple updates
#
# To prevent overcounting, Agent 3 compares **same-day** incident candidates and determines whether two messages describe:
#
# - **SAME incident** → Keep one canonical record
#     Each row gets updated as processed=-1
# - **DIFFERENT incidents** → Preserve both
#     Each row gets updated as processed=1
#
# Time-based context and general heuristics I developed using iterative analysis are laid down as ground rules for deduplication.
#
# This stage is crucial for creating a **trustworthy event dataset** and producing accurate maps.
#
#
# Below is the implementation of Agent 3.

# %%
"""
Agent 3 — Contextual Deduplicator 

Role in pipeline:
- Input: rows in `events` table where:
    checked = 1        (incident-like, from Agent 2)
    processed = 0      (not yet deduplicated)
- Work per CALENDAR DAY (YYYY-MM-DD).
- Within each day, group messages that describe the SAME real-world incident.
- For each group:
    - One canonical row gets: processed = 1
    - All other rows in that group get: processed = -1
"""

import sqlite3
import re
from datetime import datetime
from typing import List, Tuple, Dict, Any, Optional

from google.genai import types
from google.adk.agents import LlmAgent
from google.adk.models import Gemini
from google.adk.runners import InMemoryRunner

# Use the same DB as the rest of the notebook
DB_PATH = "incidents.db"

# Heuristic thresholds
TIME_WINDOW_HOURS = 4.0      # only compare events within ±4 hours
LEN_RATIO_MAX = 2.0          # ignore pairs where length ratio > 2x
MAX_CANDIDATES_PER_MSG = 3   # limit LLM comparisons per message
LOCATION_MIN_COMMON = 1      # need at least 1 shared "location-like" token

retry_config = types.HttpRetryOptions(
    attempts=5,
    exp_base=7,
    initial_delay=1,
    http_status_codes=[429, 500, 503, 504],
)

DEDUP_SYSTEM_INSTRUCTIONS = """
You are an OSINT incident deduplication assistant.

Your job:
Given TWO cleaned OSINT messages from the SAME calendar day, decide whether they
describe the SAME real-world incident, or TWO DISTINCT incidents.

DEFINITION OF "SAME INCIDENT":
- One single event in time and place, described by different channels or wording.
- Examples:
  - "RPG attack on FC post in Khyber" vs
    "Militants attacked FC checkpoint with RPG in Khyber".
  - "IED blast in Pulwama town" vs
    "Explosion reported in Pulwama today".

DEFINITION OF "DIFFERENT INCIDENTS":
- Different locations, even if the event type is similar.
- Different targets (e.g., attack on police vs attack on civilians).
- Clearly separate times (e.g., morning vs late night, or hours apart)
  indicating different attacks or explosions.
- Follow-up consequences (e.g., later death of injured soldier, funerals,
  remembrance posts, documentaries about an attack) are NOT the same incident
  as the original attack.
- General commentary on a past incident is NOT the same as the incident report.

You are given:
- CLEANED_MESSAGE_A
- TIMESTAMP_A (ISO format)
- CLEANED_MESSAGE_B
- TIMESTAMP_B (ISO format)
All from the SAME calendar day.

CRITICAL RULES:
- If one message is clearly a follow-up, consequence, or commentary
  about an earlier event (e.g., "injured soldier succumbed", "documentary released",
  "funeral held", "statement about the attack"), treat it as a DIFFERENT incident.
- If there is any reasonable doubt whether they are the same event, choose DIFFERENT.
- Do NOT merge two incidents just because they share the same district or region name.
- Only treat them as SAME if they are clearly the same moment/event being described.

OUTPUT FORMAT (IMPORTANT):
- If they describe the SAME incident, return exactly: SAME
- If they describe DIFFERENT incidents, return exactly: DIFFERENT

Return ONLY one word: SAME or DIFFERENT.
""".strip()


# ----------------- DB HELPERS -----------------

def get_connection(db_path: str = DB_PATH) -> sqlite3.Connection:
    """Return a sqlite3 connection to the DB file."""
    return sqlite3.connect(db_path)


def get_distinct_calendar_days_with_incidents(conn: sqlite3.Connection) -> List[str]:
    """
    Get distinct calendar days (YYYY-MM-DD) which have checked=1 and processed=0.
    Deduplication will be done per day.

    Assumes date is an ISO timestamp string like '2025-11-27T14:22:10'.
    """
    cur = conn.cursor()
    cur.execute(
        """
        SELECT DISTINCT SUBSTR(date, 1, 10) AS day
        FROM events
        WHERE checked = 1
          AND processed = 0
          AND date IS NOT NULL
        ORDER BY day
        """
    )
    rows = cur.fetchall()
    return [r[0] for r in rows]


def fetch_incident_rows_for_day(
    conn: sqlite3.Connection,
    day_str: str,
) -> List[Tuple[int, str, str, int, int, str]]:
    """
    Fetch incident-like rows for a given calendar day (YYYY-MM-DD)
    that have not yet been deduplicated.

    Returns:
        List of tuples:
            (id, text_clean, date_iso, chat_id, message_id, chat_title)
    """
    cur = conn.cursor()
    cur.execute(
        """
        SELECT id, text_clean, date, chat_id, message_id, chat_title
        FROM events
        WHERE date LIKE ?
          AND checked = 1
          AND processed = 0
        ORDER BY date, chat_id, message_id, id
        """,
        (f"{day_str}%",),
    )
    return cur.fetchall()


def update_processed(conn: sqlite3.Connection, row_id: int, value: int) -> None:
    """
    Update the processed field for a single row.

    Values:
      1  -> canonical incident
     -1  -> duplicate of another incident
    """
    cur = conn.cursor()
    cur.execute(
        """
        UPDATE events
        SET processed = ?
        WHERE id = ?
        """,
        (value, row_id),
    )


# ----------------- HEURISTICS -----------------

WORD_RE = re.compile(r"[A-Za-z][A-Za-z\-]+")

GENERIC_WORDS = {
    # very generic words we don't want as "location-like"
    "attack", "attacks", "ambush", "blast", "blasts", "explosion", "explosions",
    "bomb", "bombing", "raid", "raids", "search", "operation", "operations",
    "forces", "security", "police", "army", "militants", "terrorists",
    "soldier", "soldiers", "troops", "people", "civilians", "checkpoint",
    "post", "base", "camp", "bridge", "road", "highway", "line", "front",
    "area", "region", "district", "province", "state", "country",
    "city", "town", "village", "border",
    "today", "yesterday", "tonight", "morning", "evening", "afternoon", "night",
}


def extract_location_like_tokens(text: str) -> set[str]:
    """
    Very rough heuristic: extract "location-like" tokens from the cleaned text.

    - Extract alphabetic words.
    - Lowercase.
    - Keep words with length >= 5 that are not in the GENERIC_WORDS set.

    This tends to keep items like: 'pulwama', 'peshawar', 'kulgam', 'bannu', 'gaza'.
    """
    words = [w.lower() for w in WORD_RE.findall(text)]
    tokens = {w for w in words if len(w) >= 5 and w not in GENERIC_WORDS}
    return tokens


def infer_event_type(text: str) -> str:
    """
    Very rough event-type heuristic from keywords in text_clean.
    This is only used to avoid comparing obviously different incident types.
    """
    t = text.lower()

    if any(k in t for k in ["ied", "bomb blast", "car bomb", "suicide attack"]):
        return "explosion"
    if any(k in t for k in ["explosion", "blast", "detonation"]):
        return "explosion"
    if any(k in t for k in ["shelling", "mortar", "artillery", "rocket fire"]):
        return "shelling"
    if any(k in t for k in ["drone strike", "drone attack"]):
        return "drone_strike"
    if any(k in t for k in ["airstrike", "air strike", "air raid", "air strike"]):
        return "air_strike"
    if any(k in t for k in ["gunfire", "firing", "firefight", "exchange of fire"]):
        return "firefight"
    if any(k in t for k in ["raid", "search operation", "cordon and search"]):
        return "raid_search"
    if any(k in t for k in ["arrested", "arrest", "detained", "detention"]):
        return "arrest"
    if any(k in t for k in ["seized", "seizure", "recovered weapons", "contraband"]):
        return "seizure"
    if any(k in t for k in ["killed", "shot dead", "martyred", "dead body"]):
        return "casualty"
    if any(k in t for k in ["injured", "wounded"]):
        return "injury"

    return "unknown"


def parse_iso_datetime(ts: str) -> Optional[datetime]:
    """Safely parse ISO timestamp to datetime, or return None on failure."""
    if not ts:
        return None
    try:
        return datetime.fromisoformat(ts.replace("Z", "+00:00"))  # tolerate 'Z'
    except Exception:
        return None


def hours_diff(dt1: Optional[datetime], dt2: Optional[datetime]) -> Optional[float]:
    """Return abs time difference in hours, or None if either dt is None."""
    if dt1 is None or dt2 is None:
        return None
    return abs((dt1 - dt2).total_seconds()) / 3600.0


# ----------------- PROMPT BUILDER -----------------

def build_dedup_prompt(
    text_a: str,
    text_b: str,
    ts_a: str,
    ts_b: str,
    day_str: str,
) -> str:
    """
    Build the user prompt that will be sent to the dedup agent.

    We pass both timestamps explicitly so the model can reason about
    follow-ups vs same-moment reports.
    """
    user_prompt = f"""
You are comparing two OSINT messages from the SAME calendar day: {day_str}.

You are given:
- CLEANED_MESSAGE_A
- TIMESTAMP_A: {ts_a}
- CLEANED_MESSAGE_B
- TIMESTAMP_B: {ts_b}

Using your deduplication rules, decide whether they describe the SAME incident
or DIFFERENT incidents.

Respond with ONLY ONE WORD: SAME or DIFFERENT.

CLEANED_MESSAGE_A:
{text_a}

---

CLEANED_MESSAGE_B:
{text_b}
""".strip()
    return user_prompt


# ----------------- ADK AGENT SETUP -----------------

def create_dedup_agent() -> LlmAgent:
    """
    Create and return the LlmAgent dedicated to contextual deduplication.
    """
    agent = LlmAgent(
        name="Agent3_Deduplicator",
        model=Gemini(
            model="gemini-2.5-flash-lite",
            retry_options=retry_config,
        ),
        description="Groups OSINT messages that describe the same incident on a given day.",
        instruction=DEDUP_SYSTEM_INSTRUCTIONS,
        tools=[],  # no external tools needed
    )
    return agent


# ----------------- LLM CALL WRAPPER -----------------

class DedupLLM:
    """
    Wrapper around an InMemoryRunner for the dedup agent.

    Provides an async call(...) -> bool that returns True if SAME, False otherwise.
    """

    def __init__(self, runner: InMemoryRunner):
        self.runner = runner

    async def call(
        self,
        text_a: str,
        text_b: str,
        ts_a: str,
        ts_b: str,
        day_str: str,
    ) -> bool:
        prompt = build_dedup_prompt(text_a, text_b, ts_a, ts_b, day_str)
        events = await self.runner.run_debug(prompt)

        # Find the last non-user event with content
        assistant_event = None
        for e in reversed(events):
            if getattr(e, "author", "") == "user":
                continue
            if getattr(e, "content", None) is None:
                continue
            assistant_event = e
            break

        if assistant_event is None:
            # Be conservative -> treat as DIFFERENT
            return False

        parts = getattr(assistant_event.content, "parts", [])
        texts = []
        for p in parts:
            if hasattr(p, "text") and p.text:
                texts.append(p.text)

        raw_text = "\n".join(texts).strip().upper()

        # Interpret output: SAME or DIFFERENT
        if "SAME" in raw_text and "DIFFERENT" not in raw_text:
            return True
        if "DIFFERENT" in raw_text and "SAME" not in raw_text:
            return False

        # If the model misbehaves, default to DIFFERENT (do not over-merge)
        return False


# ----------------- DEDUP LOGIC (ASYNC, WITH HEURISTICS) -----------------

async def dedup_for_day(
    conn: sqlite3.Connection,
    llm: DedupLLM,
    day_str: str,
) -> None:
    """
    Perform deduplication for a single calendar day (YYYY-MM-DD).

    Algorithm:
    - Fetch all checked=1, processed=0 rows for that day.
    - Maintain a list of canonical incidents with precomputed heuristics:
        id, text_clean, date_iso, dt, loc_tokens, event_type, length
    - For each message in order:
        - Build candidate canonicals based on:
            * time window (±TIME_WINDOW_HOURS)
            * overlapping location-like tokens
            * similar event type (if known)
            * length ratio <= LEN_RATIO_MAX
        - If no candidates -> mark as canonical (processed=1)
        - Else:
            - Compare against up to MAX_CANDIDATES_PER_MSG via LLM
            - If ANY returns SAME -> mark as duplicate (processed=-1)
            - Else mark as canonical (processed=1)
    """
    rows = fetch_incident_rows_for_day(conn, day_str)
    if not rows:
        print(f"[Dedup] No rows to process for day {day_str}.")
        return

    print(f"[Dedup] Processing day {day_str} with {len(rows)} incident-like messages.")

    canonical_incidents: List[Dict[str, Any]] = []

    for row_id, text_clean, date_iso, chat_id, message_id, chat_title in rows:
        if not text_clean or not text_clean.strip():
            update_processed(conn, row_id, -1)
            continue

        text_clean = text_clean.strip()
        dt = parse_iso_datetime(date_iso)
        loc_tokens = extract_location_like_tokens(text_clean)
        event_type = infer_event_type(text_clean)
        length = len(text_clean)

        # If there are no canonicals yet, this becomes the first canonical
        if not canonical_incidents:
            update_processed(conn, row_id, 1)
            canonical_incidents.append(
                {
                    "id": row_id,
                    "text_clean": text_clean,
                    "date_iso": date_iso,
                    "dt": dt,
                    "loc_tokens": loc_tokens,
                    "event_type": event_type,
                    "length": length,
                }
            )
            continue

        # ---- Candidate selection (heuristic pre-filter) ----
        candidates: List[Dict[str, Any]] = []

        for canon in canonical_incidents:
            # Time window filter
            dt_c = canon["dt"]
            diff_hours = hours_diff(dt, dt_c)
            if diff_hours is not None and diff_hours > TIME_WINDOW_HOURS:
                continue

            # Event type filter (if both known and different -> skip)
            et_c = canon["event_type"]
            if et_c != "unknown" and event_type != "unknown" and et_c != event_type:
                continue

            # Length ratio filter
            len_c = canon["length"]
            if len_c == 0 or length == 0:
                len_ratio = 1.0
            else:
                bigger = max(len_c, length)
                smaller = min(len_c, length)
                len_ratio = bigger / smaller
            if len_ratio > LEN_RATIO_MAX:
                continue

            # Location-like tokens overlap
            lt_c = canon["loc_tokens"]
            if loc_tokens and lt_c:
                common = loc_tokens.intersection(lt_c)
                if len(common) < LOCATION_MIN_COMMON:
                    continue

            # If all checks passed, accept as candidate
            candidates.append(canon)

            # Limit number of candidates to keep LLM calls bounded
            if len(candidates) >= MAX_CANDIDATES_PER_MSG:
                break

        # If no candidates, treat as new canonical
        if not candidates:
            update_processed(conn, row_id, 1)
            canonical_incidents.append(
                {
                    "id": row_id,
                    "text_clean": text_clean,
                    "date_iso": date_iso,
                    "dt": dt,
                    "loc_tokens": loc_tokens,
                    "event_type": event_type,
                    "length": length,
                }
            )
            continue

        # ---- LLM comparison with candidates ----
        is_duplicate = False
        for canon in candidates:
            same = await llm.call(
                text_a=text_clean,
                text_b=canon["text_clean"],
                ts_a=date_iso,
                ts_b=canon["date_iso"],
                day_str=day_str,
            )
            if same:
                update_processed(conn, row_id, -1)
                is_duplicate = True
                break

        if not is_duplicate:
            # New canonical incident
            update_processed(conn, row_id, 1)
            canonical_incidents.append(
                {
                    "id": row_id,
                    "text_clean": text_clean,
                    "date_iso": date_iso,
                    "dt": dt,
                    "loc_tokens": loc_tokens,
                    "event_type": event_type,
                    "length": length,
                }
            )

    conn.commit()
    print(
        f"[Dedup] Finished day {day_str}. "
        f"Canonical count: {len(canonical_incidents)}, "
        f"Duplicates: {len(rows) - len(canonical_incidents)}"
    )


async def run_dedup_all_days(
    llm: DedupLLM,
    db_path: str = DB_PATH,
) -> None:
    """
    Run deduplication for all calendar days that have checked=1 and processed=0.
    """
    conn = get_connection(db_path)
    try:
        days = get_distinct_calendar_days_with_incidents(conn)
        if not days:
            print("[Dedup] No days with pending incidents (checked=1, processed=0).")
            return

        print(f"[Dedup] Found {len(days)} day(s) to process: {days}")

        for day_str in days:
            await dedup_for_day(conn, llm, day_str)

    finally:
        conn.close()
        print("[Dedup] All days processed.")


# ----------------- NOTEBOOK ENTRYPOINT -----------------

async def run_agent3_dedup_fast():

    dedup_agent = create_dedup_agent()
    print("[Dedup] Agent created.")

    dedup_runner = InMemoryRunner(agent=dedup_agent)
    print("[Dedup] Runner created.")

    llm = DedupLLM(runner=dedup_runner)
    await run_dedup_all_days(llm=llm, db_path=DB_PATH)

    print("[Dedup] Completed.")

# %%
await run_agent3_dedup_fast()
# Out:
# App name mismatch detected. The runner is configured with app name "InMemoryRunner", but the root agent was loaded from "C:\Users\Lenovo\Desktop\AgentAICourse\agentai_venv\Lib\site-packages\google\adk\agents", which implies app name "agents".
# [Dedup] Agent created.
# [Dedup] Runner created.
# [Dedup] Found 2 day(s) to process: ['2025-11-27', '2025-11-28']
# [Dedup] Processing day 2025-11-27 with 30 incident-like messages.
#
#  ### Created new session: debug_session_id
#
# User > You are comparing two OSINT messages from the SAME calendar day: 2025-11-27.
#
# You are given:
# - CLEANED_MESSAGE_A
# - TIMESTAMP_A: 2025-11-27T05:25:05
# - CLEANED_MESSAGE_B
# - TIMESTAMP_B: 2025-11-27T04:22:29
#
# Using your deduplication rules, decide whether they describe the SAME incident
# or DIFFERENT incidents.
#
# Respond with ONLY ONE WORD: SAME or DIFFERENT.
#
# CLEANED_MESSAGE_A:
# Kash Patel, FBI Director:
#
# Guardsmen are alive but critical. They have been taken for treatment.
#
# The suspect was taken into custody.
#
# Investigation and interrogation to follow.
#
# DC Mayor and Metro PD chief were among the other top officials present there.
#
# ---
#
# CLEANED_MESSAGE_B:
# Washington, DC:
#
# An unidentified individual, shot two US Army National Guards near the WH.
#
# Guardsmen are critically wounded and being treated.
#
# Suspect in custody.
#
# FBI, Metro PD, etc were rushed to the spot.
# Agent3_Deduplicator > SAME
#
#  ### Continue session: debug_session_id
#
# User > You are comparing two OSINT messages from the SAME calendar day: 2025-11-27.
#
# You are given:
# - CLEANED_MESSAGE_A
# - TIMESTAMP_A: 2025-11-27T07:28:01
# - CLEANED_MESSAGE_B
# - TIMESTAMP_B: 2025-11-27T04:22:29
#
# Using your deduplication rules, decide whether they describe the SAME incident
# or DIFFERENT incidents.
#
# Respond with ONLY ONE WORD: SAME or DIFFERENT.
#
# CLEANED_MESSAGE_A:
# The suspect in the DC National Guard shooting has been identified as 29-year-old Afghan National Rahmanullah Lakanwal.
#
# ---
#
# CLEANED_MESSAGE_B:
# Washington, DC:
#
# An unidentified individual, shot two US Army National Guards near the WH.
#
# Guardsmen are critically wounded and being treated.
#
# Suspect in custody.
#
# FBI, Metro PD, etc were rushed to the spot.
# Agent3_Deduplicator > SAME
#
#  ### Continue session: debug_session_id
#
# User > You are comparing two OSINT messages from the SAME calendar day: 2025-11-27.
#
# You are given:
# - CLEANED_MESSAGE_A
# - TIMESTAMP_A: 2025-11-27T10:50:55
# - CLEANED_MESSAGE_B
# - TIMESTAMP_B: 2025-11-27T09:46:16
#
# Using your deduplication rules, decide whether they describe the SAME incident
# or DIFFERENT incidents.
#
# Respond with ONLY ONE WORD: SAME or DIFFERENT.
#
# CLEANED_MESSAGE_A:
# 24 years old Pakistani intruder arrested from Barmer Rajasthan.
#
# ---
#
# CLEANED_MESSAGE_B:
# BLA says Four Pakistani Army Personnel Eliminated in Panjgur Attack .
# Agent3_Deduplicator > DIFFERENT
#
#  ### Continue session: debug_session_id
#
# User > You are comparing two OSINT messages from the SAME calendar day: 2025-11-27.
#
# You are given:
# - CLEANED_MESSAGE_A
# - TIMESTAMP_A: 2025-11-27T11:00:25
# - CLEANED_MESSAGE_B
# - TIMESTAMP_B: 2025-11-27T09:55:48
#
# Using your deduplication rules, decide whether they describe the SAME incident
# or DIFFERENT incidents.
#
# Respond with ONLY ONE WORD: SAME or DIFFERENT.
#
# CLEANED_MESSAGE_A:
# Yesterday two national guards were shot dead by an Afghan national near White house.
#
# ---
#
# CLEANED_MESSAGE_B:
# Two US National Guard members were shot near the White House in an apparent ambush.
# Agent3_Deduplicator > SAME
#
#  ### Continue session: debug_session_id
#
# User > You are comparing two OSINT messages from the SAME calendar day: 2025-11-27.
#
# You are given:
# - CLEANED_MESSAGE_A
# - TIMESTAMP_A: 2025-11-27T12:15:02
# - CLEANED_MESSAGE_B
# - TIMESTAMP_B: 2025-11-27T09:58:01
#
# Using your deduplication rules, decide whether they describe the SAME incident
# or DIFFERENT incidents.
#
# Respond with ONLY ONE WORD: SAME or DIFFERENT.
#
# CLEANED_MESSAGE_A:
# Death toll in Hong Kong fire rises to 44 with 279 still missing
#
# At least 44 people have been killed in a major fire engulfing public housing apartments in Hong Kong's Tai Po district - more than 270 people are still not accounted for
#
# Three construction company executives have been arrested on suspicion of manslaughter connected to flammable materials that may have allowed the fire to spread quickly
#
# After 18 hours, officials said the fire was under control - it has been classified a level five blaze, the most serious level in Hong Kong
#
# @ResonantNews
#
# ---
#
# CLEANED_MESSAGE_B:
# US Special Forces launched a ground operation against the Islamic State of the Somalia Province (ISSP), in the Baalade Valley, Puntland, Somalia.
#
# Violent clashes erupted between the US troops and ISSP in the Cal-Miskaad mountain range.
#
# At least 100 US SF personnel were carrying out the ground operation.
# Agent3_Deduplicator > DIFFERENT
#
#  ### Continue session: debug_session_id
#
# User > You are comparing two OSINT messages from the SAME calendar day: 2025-11-27.
#
# You are given:
# - CLEANED_MESSAGE_A
# - TIMESTAMP_A: 2025-11-27T13:30:44
# - CLEANED_MESSAGE_B
# - TIMESTAMP_B: 2025-11-27T09:58:01
#
# Using your deduplication rules, decide whether they describe the SAME incident
# or DIFFERENT incidents.
#
# Respond with ONLY ONE WORD: SAME or DIFFERENT.
#
# CLEANED_MESSAGE_A:
# BREAKING: DC ATTACK SUSPECT ENTERED US AS A MIGRANT IN 2021, FBI PROBES TERROR ANGLE
#
# Authorities identified 29-year-old Rahmanullah Lakanwal, an Afghan national, as the gunman who shot two National Guard soldiers near the White House.
#
# The FBI and local security agencies have launched terrorism investigations, while the US government reviews Afghan migration records amid fresh security concerns.
#
# #DCshooting #NationalGuard #AfghanSuspect #Security #Breaking #USA
#
# 📍 @ResonantNews
#
# ---
#
# CLEANED_MESSAGE_B:
# US Special Forces launched a ground operation against the Islamic State of the Somalia Province (ISSP), in the Baalade Valley, Puntland, Somalia.
#
# Violent clashes erupted between the US troops and ISSP in the Cal-Miskaad mountain range.
#
# At least 100 US SF personnel were carrying out the ground operation.
# Agent3_Deduplicator > DIFFERENT
#
#  ### Continue session: debug_session_id
#
# User > You are comparing two OSINT messages from the SAME calendar day: 2025-11-27.
#
# You are given:
# - CLEANED_MESSAGE_A
# - TIMESTAMP_A: 2025-11-27T13:30:44
# - CLEANED_MESSAGE_B
# - TIMESTAMP_B: 2025-11-27T12:15:02
#
# Using your deduplication rules, decide whether they describe the SAME incident
# or DIFFERENT incidents.
#
# Respond with ONLY ONE WORD: SAME or DIFFERENT.
#
# CLEANED_MESSAGE_A:
# BREAKING: DC ATTACK SUSPECT ENTERED US AS A MIGRANT IN 2021, FBI PROBES TERROR ANGLE
#
# Authorities identified 29-year-old Rahmanullah Lakanwal, an Afghan national, as the gunman who shot two National Guard soldiers near the White House.
#
# The FBI and local security agencies have launched terrorism investigations, while the US government reviews Afghan migration records amid fresh security concerns.
#
# #DCshooting #NationalGuard #AfghanSuspect #Security #Breaking #USA
#
# 📍 @ResonantNews
#
# ---
#
# CLEANED_MESSAGE_B:
# Death toll in Hong Kong fire rises to 44 with 279 still missing
#
# At least 44 people have been killed in a major fire engulfing public housing apartments in Hong Kong's Tai Po district - more than 270 people are still not accounted for
#
# Three construction company executives have been arrested on suspicion of manslaughter connected to flammable materials that may have allowed the fire to spread quickly
#
# After 18 hours, officials said the fire was under control - it has been classified a level five blaze, the most serious level in Hong Kong
#
# @ResonantNews
# Agent3_Deduplicator > DIFFERENT
#
#  ### Continue session: debug_session_id
#
# User > You are comparing two OSINT messages from the SAME calendar day: 2025-11-27.
#
# You are given:
# - CLEANED_MESSAGE_A
# - TIMESTAMP_A: 2025-11-27T14:33:14
# - CLEANED_MESSAGE_B
# - TIMESTAMP_B: 2025-11-27T12:15:02
#
# Using your deduplication rules, decide whether they describe the SAME incident
# or DIFFERENT incidents.
#
# Respond with ONLY ONE WORD: SAME or DIFFERENT.
#
# CLEANED_MESSAGE_A:
# BREAKING: BLAZE DEVASTATES OVER 1,500 KORAIL SHANTIES, FAMILIES FLEE DHAKA SETTLEMENT OVERNIGHT
#
# A massive fire ripped through Dhaka’s crowded Korail slum, destroying more than 1,500 makeshift homes and leaving thousands of people with nowhere to sleep but the open streets.
#
# Rescue workers scrambled to assist and government officials are assessing damage as one of the worst urban blazes in years exposes harsh realities for Bangladesh’s poorest residents.
#
# #DhakaFire #Bangladesh #SlumFire #Korail #Disaster #UrbanPoverty #BreakingNews
#
# 📍 @ResonantNews
#
# ---
#
# CLEANED_MESSAGE_B:
# Death toll in Hong Kong fire rises to 44 with 279 still missing
#
# At least 44 people have been killed in a major fire engulfing public housing apartments in Hong Kong's Tai Po district - more than 270 people are still not accounted for
#
# Three construction company executives have been arrested on suspicion of manslaughter connected to flammable materials that may have allowed the fire to spread quickly
#
# After 18 hours, officials said the fire was under control - it has been classified a level five blaze, the most serious level in Hong Kong
#
# @ResonantNews
# Agent3_Deduplicator > DIFFERENT
#
#  ### Continue session: debug_session_id
#
# User > You are comparing two OSINT messages from the SAME calendar day: 2025-11-27.
#
# You are given:
# - CLEANED_MESSAGE_A
# - TIMESTAMP_A: 2025-11-27T14:33:14
# - CLEANED_MESSAGE_B
# - TIMESTAMP_B: 2025-11-27T13:30:44
#
# Using your deduplication rules, decide whether they describe the SAME incident
# or DIFFERENT incidents.
#
# Respond with ONLY ONE WORD: SAME or DIFFERENT.
#
# CLEANED_MESSAGE_A:
# BREAKING: BLAZE DEVASTATES OVER 1,500 KORAIL SHANTIES, FAMILIES FLEE DHAKA SETTLEMENT OVERNIGHT
#
# A massive fire ripped through Dhaka’s crowded Korail slum, destroying more than 1,500 makeshift homes and leaving thousands of people with nowhere to sleep but the open streets.
#
# Rescue workers scrambled to assist and government officials are assessing damage as one of the worst urban blazes in years exposes harsh realities for Bangladesh’s poorest residents.
#
# #DhakaFire #Bangladesh #SlumFire #Korail #Disaster #UrbanPoverty #BreakingNews
#
# 📍 @ResonantNews
#
# ---
#
# CLEANED_MESSAGE_B:
# BREAKING: DC ATTACK SUSPECT ENTERED US AS A MIGRANT IN 2021, FBI PROBES TERROR ANGLE
#
# Authorities identified 29-year-old Rahmanullah Lakanwal, an Afghan national, as the gunman who shot two National Guard soldiers near the White House.
#
# The FBI and local security agencies have launched terrorism investigations, while the US government reviews Afghan migration records amid fresh security concerns.
#
# #DCshooting #NationalGuard #AfghanSuspect #Security #Breaking #USA
#
# 📍 @ResonantNews
# Agent3_Deduplicator > DIFFERENT
#
#  ### Continue session: debug_session_id
#
# User > You are comparing two OSINT messages from the SAME calendar day: 2025-11-27.
#
# You are given:
# - CLEANED_MESSAGE_A
# - TIMESTAMP_A: 2025-11-27T18:30:16
# - CLEANED_MESSAGE_B
# - TIMESTAMP_B: 2025-11-27T17:55:13
#
# Using your deduplication rules, decide whether they describe the SAME incident
# or DIFFERENT incidents.
#
# Respond with ONLY ONE WORD: SAME or DIFFERENT.
#
# CLEANED_MESSAGE_A:
# Massive explosion in Wana South Waziristan
#
# ---
#
# CLEANED_MESSAGE_B:
# A loud explosion has been heard in Wana, South Waziristan
# Agent3_Deduplicator > SAME
#
#  ### Continue session: debug_session_id
#
# User > You are comparing two OSINT messages from the SAME calendar day: 2025-11-27.
#
# You are given:
# - CLEANED_MESSAGE_A
# - TIMESTAMP_A: 2025-11-27T21:02:13
# - CLEANED_MESSAGE_B
# - TIMESTAMP_B: 2025-11-27T20:11:16
#
# Using your deduplication rules, decide whether they describe the SAME incident
# or DIFFERENT incidents.
#
# Respond with ONLY ONE WORD: SAME or DIFFERENT.
#
# CLEANED_MESSAGE_A:
# According to TTP sources, reportedly rebels fired a homemade rocket at the Wali Noor PaK military camp in the Janikhel area of the Baka Khel subdivision.
#
# They shared a photo and said the video will be released soon.
#
# ---
#
# CLEANED_MESSAGE_B:
# A Pakistani spy identified as Farman son of Shah Jan, resident of Mohabbat Khel, who was involved in the killing of several rebels was executed by TTP rebels after he confessed to the crime.
# Agent3_Deduplicator > DIFFERENT
#
#  ### Continue session: debug_session_id
#
# User > You are comparing two OSINT messages from the SAME calendar day: 2025-11-27.
#
# You are given:
# - CLEANED_MESSAGE_A
# - TIMESTAMP_A: 2025-11-27T23:15:32
# - CLEANED_MESSAGE_B
# - TIMESTAMP_B: 2025-11-27T21:41:04
#
# Using your deduplication rules, decide whether they describe the SAME incident
# or DIFFERENT incidents.
#
# Respond with ONLY ONE WORD: SAME or DIFFERENT.
#
# CLEANED_MESSAGE_A:
# BREAKING: MILITARY SUSPENDS INSTITUTIONS, REOPENS BORDERS AFTER ELECTION TURMOIL
#
# General Horta Nta Na Man has assumed the role of "transitional president" after the High Military Command staged a coup in Guinea-Bissau, citing election instability and a plot by “drug lords” to alter the constitutional order.
#
# The military dissolved state institutions, shut media, closed borders (later reopened), and imposed a curfew in Bissau following disputed election results where both incumbent President Umaro Sissoco Embaló and challenger Fernando Dias claimed victory.
#
# International observers, the African Union, and ECOWAS have called for the return of constitutional governance as the West African nation faces yet another episode of political unrest and transitions led by its armed forces.
#
# #GuineaBissau #Coup #TransitionalPresident #MilitaryTakeover #PoliticalCrisis #AfricaNews #Democracy #BreakingNews
#
# 📍 @ResonantNews
#
# ---
#
# CLEANED_MESSAGE_B:
# WARNING WARNING WARNING
# Pakistan backed JeM Terrorist in Syria ‼️
#
# He statement and description of the incident confirms HTS grp (which is ruling Syria right now) is collaborating with JeM.
#
# So how do we know Syria's HTS and Pakistan's JeM are collaborating?
#
# The location and incident he mentioned took place when HTS took over the oldest mosque in Syria.
#
# You can read about it here https://resonantnews.com/2025/11/27/pakistan-backed-jem-in-syria-is-syrian-hts-collaborating-with-pakistans-jem-terror-group/
#
# Earlier in Aug we had posted that Syrian HTS men had visited #ISI HQ in Pakistan
#
# @ResonantNews
# Agent3_Deduplicator > DIFFERENT
# [Dedup] Finished day 2025-11-27. Canonical count: 26, Duplicates: 4
# [Dedup] Processing day 2025-11-28 with 24 incident-like messages.
#
#  ### Continue session: debug_session_id
#
# User > You are comparing two OSINT messages from the SAME calendar day: 2025-11-28.
#
# You are given:
# - CLEANED_MESSAGE_A
# - TIMESTAMP_A: 2025-11-28T10:16:36
# - CLEANED_MESSAGE_B
# - TIMESTAMP_B: 2025-11-28T10:10:09
#
# Using your deduplication rules, decide whether they describe the SAME incident
# or DIFFERENT incidents.
#
# Respond with ONLY ONE WORD: SAME or DIFFERENT.
#
# CLEANED_MESSAGE_A:
# Under Field Marshal Asim Munir’s , the Pakistani Taliban are now walking straight into military bases across Khyber Pakhtunkhwa like they own the place.
#
# The army isn’t fighting back. Posts are being abandoned overnight, soldiers pulling out without a shot fired, leaving basesand weapons behind. The militants move in, film videos and set up checkpoints.
#
# ---
#
# CLEANED_MESSAGE_B:
# As per pro rebel sources a massive attack was launched on the Police station in Bannu, KPK resulting in death of 7 police personals.
#
# Mean while pakistani side sources reported injuries to 5 police personals
# Agent3_Deduplicator > DIFFERENT
#
#  ### Continue session: debug_session_id
#
# User > You are comparing two OSINT messages from the SAME calendar day: 2025-11-28.
#
# You are given:
# - CLEANED_MESSAGE_A
# - TIMESTAMP_A: 2025-11-28T13:59:06
# - CLEANED_MESSAGE_B
# - TIMESTAMP_B: 2025-11-28T10:16:36
#
# Using your deduplication rules, decide whether they describe the SAME incident
# or DIFFERENT incidents.
#
# Respond with ONLY ONE WORD: SAME or DIFFERENT.
#
# CLEANED_MESSAGE_A:
# This is HILARIOUS 😄...and SERIOUS at the same time.
#
# 🔴An American plumber sues #FORD reseller after spotting his car being used by !SIS
# A $1,000,000 lawsuit‼️
#
# The ford reseller had promised the owner of the pickup that the LOGO will be removed before being resold.
# But they sold it as it is.
# Soon the owner spotted the pickup being used by !S!S terr01sts. 😅
#
# The billion dollar question is HOW did !s!s get this pickup❓❓❓ 🧐
#
# @ResonantNews
#
# ---
#
# CLEANED_MESSAGE_B:
# Under Field Marshal Asim Munir’s , the Pakistani Taliban are now walking straight into military bases across Khyber Pakhtunkhwa like they own the place.
#
# The army isn’t fighting back. Posts are being abandoned overnight, soldiers pulling out without a shot fired, leaving basesand weapons behind. The militants move in, film videos and set up checkpoints.
# Agent3_Deduplicator > DIFFERENT
#
#  ### Continue session: debug_session_id
#
# User > You are comparing two OSINT messages from the SAME calendar day: 2025-11-28.
#
# You are given:
# - CLEANED_MESSAGE_A
# - TIMESTAMP_A: 2025-11-28T14:02:11
# - CLEANED_MESSAGE_B
# - TIMESTAMP_B: 2025-11-28T10:10:09
#
# Using your deduplication rules, decide whether they describe the SAME incident
# or DIFFERENT incidents.
#
# Respond with ONLY ONE WORD: SAME or DIFFERENT.
#
# CLEANED_MESSAGE_A:
# Israeli forces carried out an incursion into the Syrian town of Beit Jinn in rural Damascus.
#
# Clashes reported between local residents and the troops, wherein IDF reportedly used artilleries and drones.
#
# ---
#
# CLEANED_MESSAGE_B:
# As per pro rebel sources a massive attack was launched on the Police station in Bannu, KPK resulting in death of 7 police personals.
#
# Mean while pakistani side sources reported injuries to 5 police personals
# Agent3_Deduplicator > DIFFERENT
#
#  ### Continue session: debug_session_id
#
# User > You are comparing two OSINT messages from the SAME calendar day: 2025-11-28.
#
# You are given:
# - CLEANED_MESSAGE_A
# - TIMESTAMP_A: 2025-11-28T15:32:52
# - CLEANED_MESSAGE_B
# - TIMESTAMP_B: 2025-11-28T13:07:51
#
# Using your deduplication rules, decide whether they describe the SAME incident
# or DIFFERENT incidents.
#
# Respond with ONLY ONE WORD: SAME or DIFFERENT.
#
# CLEANED_MESSAGE_A:
# BREAKING: MIGRANT ACCUSED OF DC ATTACK WAS PREVIOUSLY EVACUATED AFTER AIDING AMERICAN MISSIONS IN KABUL
#
# The Afghan migrant charged with shooting two National Guard soldiers near the White House had worked with the US military, CIA and special forces before being evacuated in 2021 as the Taliban took over Afghanistan.
#
# US media reports highlight the challenges of refugee vetting after his arrival on emergency flights, adding new focus to crime and security debates around former foreign partners.
#
# #NationalGuard #DCshooting #AfghanRefugee #USMilitary #Security #BreakingNews
#
# 📍 @ResonantNews
#
# ---
#
# CLEANED_MESSAGE_B:
# On Friday, November 28, at midnight, the Mujahideen of the Pakistan Revolution Movement and the Burr and Jamaat jointly launched a counterattack on the Domail Ahmadzai police station. With the grace of Allah, the Mujahideen displayed great courage and captured the police station. During this time, more police and army troops also arrived from Bannu, with whom a fierce battle ensued. Alhamdulillah, according to reliable reports, several anti-Sharia police officers were killed and injured in this battle.
#
# Maulvi Ismail Khan, spokesman for the Pakistan Revolution
# Agent3_Deduplicator > DIFFERENT
#
#  ### Continue session: debug_session_id
#
# User > You are comparing two OSINT messages from the SAME calendar day: 2025-11-28.
#
# You are given:
# - CLEANED_MESSAGE_A
# - TIMESTAMP_A: 2025-11-28T15:32:52
# - CLEANED_MESSAGE_B
# - TIMESTAMP_B: 2025-11-28T13:59:06
#
# Using your deduplication rules, decide whether they describe the SAME incident
# or DIFFERENT incidents.
#
# Respond with ONLY ONE WORD: SAME or DIFFERENT.
#
# CLEANED_MESSAGE_A:
# BREAKING: MIGRANT ACCUSED OF DC ATTACK WAS PREVIOUSLY EVACUATED AFTER AIDING AMERICAN MISSIONS IN KABUL
#
# The Afghan migrant charged with shooting two National Guard soldiers near the White House had worked with the US military, CIA and special forces before being evacuated in 2021 as the Taliban took over Afghanistan.
#
# US media reports highlight the challenges of refugee vetting after his arrival on emergency flights, adding new focus to crime and security debates around former foreign partners.
#
# #NationalGuard #DCshooting #AfghanRefugee #USMilitary #Security #BreakingNews
#
# 📍 @ResonantNews
#
# ---
#
# CLEANED_MESSAGE_B:
# This is HILARIOUS 😄...and SERIOUS at the same time.
#
# 🔴An American plumber sues #FORD reseller after spotting his car being used by !SIS
# A $1,000,000 lawsuit‼️
#
# The ford reseller had promised the owner of the pickup that the LOGO will be removed before being resold.
# But they sold it as it is.
# Soon the owner spotted the pickup being used by !S!S terr01sts. 😅
#
# The billion dollar question is HOW did !s!s get this pickup❓❓❓ 🧐
#
# @ResonantNews
# Agent3_Deduplicator > DIFFERENT
#
#  ### Continue session: debug_session_id
#
# User > You are comparing two OSINT messages from the SAME calendar day: 2025-11-28.
#
# You are given:
# - CLEANED_MESSAGE_A
# - TIMESTAMP_A: 2025-11-28T15:37:32
# - CLEANED_MESSAGE_B
# - TIMESTAMP_B: 2025-11-28T13:59:06
#
# Using your deduplication rules, decide whether they describe the SAME incident
# or DIFFERENT incidents.
#
# Respond with ONLY ONE WORD: SAME or DIFFERENT.
#
# CLEANED_MESSAGE_A:
# Statement from officials -A patrolling party of Assam Rifles was fired upon by terrorists in Tengnoupal district of Manipur, along the India-Myanmar Border in the early morning hours today. Operations are currently underway, with additional troops being deployed into the area.
#
# ---
#
# CLEANED_MESSAGE_B:
# This is HILARIOUS 😄...and SERIOUS at the same time.
#
# 🔴An American plumber sues #FORD reseller after spotting his car being used by !SIS
# A $1,000,000 lawsuit‼️
#
# The ford reseller had promised the owner of the pickup that the LOGO will be removed before being resold.
# But they sold it as it is.
# Soon the owner spotted the pickup being used by !S!S terr01sts. 😅
#
# The billion dollar question is HOW did !s!s get this pickup❓❓❓ 🧐
#
# @ResonantNews
# Agent3_Deduplicator > DIFFERENT
#
#  ### Continue session: debug_session_id
#
# User > You are comparing two OSINT messages from the SAME calendar day: 2025-11-28.
#
# You are given:
# - CLEANED_MESSAGE_A
# - TIMESTAMP_A: 2025-11-28T15:56:11
# - CLEANED_MESSAGE_B
# - TIMESTAMP_B: 2025-11-28T15:34:03
#
# Using your deduplication rules, decide whether they describe the SAME incident
# or DIFFERENT incidents.
#
# Respond with ONLY ONE WORD: SAME or DIFFERENT.
#
# CLEANED_MESSAGE_A:
# Khyber PakhtunKhwa
#
# The injured soldier of Frontier constabulary succumbed to his injuries in hospital.
#
# ---
#
# CLEANED_MESSAGE_B:
# Manipur: Reportedly PLA Terrorists attacked post BP-87
# in Tengnoupal (Manipur) around 4:30 am. 4 jawans are said to be injured.
# Agent3_Deduplicator > DIFFERENT
#
#  ### Continue session: debug_session_id
#
# User > You are comparing two OSINT messages from the SAME calendar day: 2025-11-28.
#
# You are given:
# - CLEANED_MESSAGE_A
# - TIMESTAMP_A: 2025-11-28T15:58:30
# - CLEANED_MESSAGE_B
# - TIMESTAMP_B: 2025-11-28T13:59:06
#
# Using your deduplication rules, decide whether they describe the SAME incident
# or DIFFERENT incidents.
#
# Respond with ONLY ONE WORD: SAME or DIFFERENT.
#
# CLEANED_MESSAGE_A:
# WATCH
#
# 3 Chinese men killed in a drone strike from Afghanistan inside Tajikistan
#
# 2nd such incident in last one year‼️
#
# The Chinese and Pakistanis are slowly losing hope of dominating in CENTRAL ASIA.
#
# You can also read about BOTH the incidents on ResonantNews website
#
# ---
#
# CLEANED_MESSAGE_B:
# This is HILARIOUS 😄...and SERIOUS at the same time.
#
# 🔴An American plumber sues #FORD reseller after spotting his car being used by !SIS
# A $1,000,000 lawsuit‼️
#
# The ford reseller had promised the owner of the pickup that the LOGO will be removed before being resold.
# But they sold it as it is.
# Soon the owner spotted the pickup being used by !S!S terr01sts. 😅
#
# The billion dollar question is HOW did !s!s get this pickup❓❓❓ 🧐
#
# @ResonantNews
# Agent3_Deduplicator > DIFFERENT
#
#  ### Continue session: debug_session_id
#
# User > You are comparing two OSINT messages from the SAME calendar day: 2025-11-28.
#
# You are given:
# - CLEANED_MESSAGE_A
# - TIMESTAMP_A: 2025-11-28T16:03:35
# - CLEANED_MESSAGE_B
# - TIMESTAMP_B: 2025-11-28T13:07:51
#
# Using your deduplication rules, decide whether they describe the SAME incident
# or DIFFERENT incidents.
#
# Respond with ONLY ONE WORD: SAME or DIFFERENT.
#
# CLEANED_MESSAGE_A:
# 1. Cyclone Ditwah has hit Sri Lanka, causing major loss of life and destruction.
#
# 2. India launched Operation Sagar Bandhu to provide urgent HADR support to its closest maritime neighbour.
#
# 3. INS Vikrant and INS Udaigiri delivered the first relief supplies to Colombo.
#
# 4. The mission reflects India’s Neighbourhood First and SAGAR vision, with PM Modi and EAM Dr. S. Jaishankar assuring full support to Sri Lanka.
#
# ---
#
# CLEANED_MESSAGE_B:
# On Friday, November 28, at midnight, the Mujahideen of the Pakistan Revolution Movement and the Burr and Jamaat jointly launched a counterattack on the Domail Ahmadzai police station. With the grace of Allah, the Mujahideen displayed great courage and captured the police station. During this time, more police and army troops also arrived from Bannu, with whom a fierce battle ensued. Alhamdulillah, according to reliable reports, several anti-Sharia police officers were killed and injured in this battle.
#
# Maulvi Ismail Khan, spokesman for the Pakistan Revolution
# Agent3_Deduplicator > DIFFERENT
#
#  ### Continue session: debug_session_id
#
# User > You are comparing two OSINT messages from the SAME calendar day: 2025-11-28.
#
# You are given:
# - CLEANED_MESSAGE_A
# - TIMESTAMP_A: 2025-11-28T16:09:11
# - CLEANED_MESSAGE_B
# - TIMESTAMP_B: 2025-11-28T14:02:11
#
# Using your deduplication rules, decide whether they describe the SAME incident
# or DIFFERENT incidents.
#
# Respond with ONLY ONE WORD: SAME or DIFFERENT.
#
# CLEANED_MESSAGE_A:
# Pakistan: Maulana Qari Izzatullah was shot dead near University Town a short while ago, according to local sources.
#
# The attackers have not yet been identified, and police have launched an investigation into the incident.
#
# ---
#
# CLEANED_MESSAGE_B:
# Israeli forces carried out an incursion into the Syrian town of Beit Jinn in rural Damascus.
#
# Clashes reported between local residents and the troops, wherein IDF reportedly used artilleries and drones.
# Agent3_Deduplicator > DIFFERENT
#
#  ### Continue session: debug_session_id
#
# User > You are comparing two OSINT messages from the SAME calendar day: 2025-11-28.
#
# You are given:
# - CLEANED_MESSAGE_A
# - TIMESTAMP_A: 2025-11-28T16:09:11
# - CLEANED_MESSAGE_B
# - TIMESTAMP_B: 2025-11-28T16:03:35
#
# Using your deduplication rules, decide whether they describe the SAME incident
# or DIFFERENT incidents.
#
# Respond with ONLY ONE WORD: SAME or DIFFERENT.
#
# CLEANED_MESSAGE_A:
# Pakistan: Maulana Qari Izzatullah was shot dead near University Town a short while ago, according to local sources.
#
# The attackers have not yet been identified, and police have launched an investigation into the incident.
#
# ---
#
# CLEANED_MESSAGE_B:
# 1. Cyclone Ditwah has hit Sri Lanka, causing major loss of life and destruction.
#
# 2. India launched Operation Sagar Bandhu to provide urgent HADR support to its closest maritime neighbour.
#
# 3. INS Vikrant and INS Udaigiri delivered the first relief supplies to Colombo.
#
# 4. The mission reflects India’s Neighbourhood First and SAGAR vision, with PM Modi and EAM Dr. S. Jaishankar assuring full support to Sri Lanka.
# Agent3_Deduplicator > DIFFERENT
#
#  ### Continue session: debug_session_id
#
# User > You are comparing two OSINT messages from the SAME calendar day: 2025-11-28.
#
# You are given:
# - CLEANED_MESSAGE_A
# - TIMESTAMP_A: 2025-11-28T16:33:51
# - CLEANED_MESSAGE_B
# - TIMESTAMP_B: 2025-11-28T13:07:51
#
# Using your deduplication rules, decide whether they describe the SAME incident
# or DIFFERENT incidents.
#
# Respond with ONLY ONE WORD: SAME or DIFFERENT.
#
# CLEANED_MESSAGE_A:
# Just in :
#
# Unknown gunmen shot and killed Maulvi Izzatullah and his son in Tajabad, Pushtakhra area, Peshawar- KP - Pakistan.
#
# Police says the killers escaped. The bodies were sent for postmortem.
#
# The motive is not clear. The eliminated Salafist Maulvi is presumed to be linked to Lashkar e Taiba.
#
# ---
#
# CLEANED_MESSAGE_B:
# On Friday, November 28, at midnight, the Mujahideen of the Pakistan Revolution Movement and the Burr and Jamaat jointly launched a counterattack on the Domail Ahmadzai police station. With the grace of Allah, the Mujahideen displayed great courage and captured the police station. During this time, more police and army troops also arrived from Bannu, with whom a fierce battle ensued. Alhamdulillah, according to reliable reports, several anti-Sharia police officers were killed and injured in this battle.
#
# Maulvi Ismail Khan, spokesman for the Pakistan Revolution
# Agent3_Deduplicator > DIFFERENT
#
#  ### Continue session: debug_session_id
#
# User > You are comparing two OSINT messages from the SAME calendar day: 2025-11-28.
#
# You are given:
# - CLEANED_MESSAGE_A
# - TIMESTAMP_A: 2025-11-28T17:00:20
# - CLEANED_MESSAGE_B
# - TIMESTAMP_B: 2025-11-28T16:33:51
#
# Using your deduplication rules, decide whether they describe the SAME incident
# or DIFFERENT incidents.
#
# Respond with ONLY ONE WORD: SAME or DIFFERENT.
#
# CLEANED_MESSAGE_A:
# A 33 minute long documentary has been released by rebel linked media on the attackers who killed Major Adnan from the SSG and other personnel in the attack on the Bannu FC lines.
#
# ---
#
# CLEANED_MESSAGE_B:
# Just in :
#
# Unknown gunmen shot and killed Maulvi Izzatullah and his son in Tajabad, Pushtakhra area, Peshawar- KP - Pakistan.
#
# Police says the killers escaped. The bodies were sent for postmortem.
#
# The motive is not clear. The eliminated Salafist Maulvi is presumed to be linked to Lashkar e Taiba.
# Agent3_Deduplicator > DIFFERENT
#
#  ### Continue session: debug_session_id
#
# User > You are comparing two OSINT messages from the SAME calendar day: 2025-11-28.
#
# You are given:
# - CLEANED_MESSAGE_A
# - TIMESTAMP_A: 2025-11-28T19:10:38
# - CLEANED_MESSAGE_B
# - TIMESTAMP_B: 2025-11-28T15:32:52
#
# Using your deduplication rules, decide whether they describe the SAME incident
# or DIFFERENT incidents.
#
# Respond with ONLY ONE WORD: SAME or DIFFERENT.
#
# CLEANED_MESSAGE_A:
# BREAKING: KABUL SEEKS IMPARTIAL PROBE AS AFGHAN LINK TO US NATIONAL GUARD ATTACK SPARKS TENSION
#
# Taliban spokesperson Suhail Shaheen has alleged that Pakistan’s ISI may be trying to damage Afghanistan’s reputation by linking it to the recent shooting of US National Guard soldiers near the White House, insisting Kabul does not allow its soil to be used for foreign attacks.
#
# Calling for a professional, unbiased investigation, the Taliban said all “possibilities” must be examined, including external intelligence networks, as Washington tightens Afghan immigration checks after the incident.
#
# #Afghanistan #ISI #DCshooting #Taliban #Pakistan #USSecurity
#
# 📍 @ResonantNews
#
# ---
#
# CLEANED_MESSAGE_B:
# BREAKING: MIGRANT ACCUSED OF DC ATTACK WAS PREVIOUSLY EVACUATED AFTER AIDING AMERICAN MISSIONS IN KABUL
#
# The Afghan migrant charged with shooting two National Guard soldiers near the White House had worked with the US military, CIA and special forces before being evacuated in 2021 as the Taliban took over Afghanistan.
#
# US media reports highlight the challenges of refugee vetting after his arrival on emergency flights, adding new focus to crime and security debates around former foreign partners.
#
# #NationalGuard #DCshooting #AfghanRefugee #USMilitary #Security #BreakingNews
#
# 📍 @ResonantNews
# Agent3_Deduplicator > SAME
#
#  ### Continue session: debug_session_id
#
# User > You are comparing two OSINT messages from the SAME calendar day: 2025-11-28.
#
# You are given:
# - CLEANED_MESSAGE_A
# - TIMESTAMP_A: 2025-11-28T22:20:32
# - CLEANED_MESSAGE_B
# - TIMESTAMP_B: 2025-11-28T19:02:34
#
# Using your deduplication rules, decide whether they describe the SAME incident
# or DIFFERENT incidents.
#
# Respond with ONLY ONE WORD: SAME or DIFFERENT.
#
# CLEANED_MESSAGE_A:
# Maoists responsible for the IED blast in Jharkhand.
#
# ---
#
# CLEANED_MESSAGE_B:
# Woman killed, two others injured in IED blast in Jharkhand''s Chaibasa: Police
#
# ~ PTI
# Agent3_Deduplicator > SAME
# [Dedup] Finished day 2025-11-28. Canonical count: 22, Duplicates: 2
# [Dedup] All days processed.
# [Dedup] Completed.

# %%
conn = sqlite3.connect(DB_PATH)
df = pd.read_sql_query(
    "SELECT id, text_clean FROM events WHERE checked=1 AND processed=1;",
    conn
)
print(len(df))
df.head()
# Out:
# 48
#    id                                         text_clean
# 0   4  A 33 minute long documentary has been released...
# 1   7  Just in :\n\nUnknown gunmen shot and killed Ma...
# 2  11  Under Field Marshal Asim Munir’s , the Pakista...
# 3  12  As per pro rebel sources a massive attack was ...
# 4  20  According to TTP sources, reportedly rebels fi...

# %% [markdown]
# Duplicates caught

# %%
df_dups = pd.read_sql_query("""
    SELECT id, date, chat_title, text_clean
    FROM events
    WHERE processed = -1
    ORDER BY date, id;
""", conn)

df_dups
# Out:
#     id                 date       chat_title  \
# 0  100  2025-11-27T05:25:05   ElitePredators
# 1   98  2025-11-27T07:28:01   ElitePredators
# 2   46  2025-11-27T11:00:25       War & Gore
# 3   35  2025-11-27T18:30:16       War & Gore
# 4  109  2025-11-28T19:10:38  Resonant News 📰
# 5   54  2025-11-28T22:20:32   ElitePredators
#
#                                           text_clean
# 0  Kash Patel, FBI Director:\n\nGuardsmen are ali...
# 1  The suspect in the DC National Guard shooting ...
# 2  Yesterday two national guards were shot dead b...
# 3         Massive explosion in Wana South Waziristan
# 4  BREAKING: KABUL SEEKS IMPARTIAL PROBE AS AFGHA...
# 5  Maoists responsible for the IED blast in Jhark...

# %% [markdown]
# ---
#
# # 🏷️ Agent 4 — Category & Location Extractor
# ### *Assigning semantic meaning and extracting geocodable places*
#
# Once we know an event is real and unique, we must interpret it.
#
# Agent 4 uses an LLM to extract two key intelligence fields:
#
# - **Category:** One label from a closed, 16-class taxonomy  (with multiple text/clause linkages)
# - **Location Text:** A clean, geocodable place string
#
# This step enriches events with structure, enabling downstream geocoding, visualization, and analysis.
#
# Below is the implementation of Agent 4.

# %%
"""
Agent 4 — Category + Location Extractor 

Role in pipeline:
- Input: rows in `events` table where:
    checked   = 1  (incident-like, from Agent 2)
    processed = 1  (canonical after Agent 3 dedup)
- For each such row, extract:
    - category       (short incident type label)
    - location_text  (geocodable string)

Schema (must match existing):
    CREATE TABLE IF NOT EXISTS events (
        id INTEGER PRIMARY KEY AUTOINCREMENT,
        chat_id INTEGER,
        message_id INTEGER,
        chat_title TEXT,
        date TEXT,
        text_raw TEXT,
        text_clean TEXT,
        checked INTEGER DEFAULT 0,
        processed INTEGER DEFAULT 0,
        category TEXT,
        location_text TEXT,
        lat REAL,
        lon REAL,
        UNIQUE(chat_id, message_id)
    );
"""

import sqlite3
import asyncio
import json
from typing import List, Tuple, Optional

import os
from dotenv import load_dotenv

from google.adk.agents import LlmAgent
from google.adk.models import Gemini
from google.adk.runners import InMemoryRunner
from google.genai import types

# ----------------- CONFIG -----------------

load_dotenv()
GOOGLE_API_KEY = os.getenv("GOOGLE_API_KEY")
if not GOOGLE_API_KEY:
    raise RuntimeError("GOOGLE_API_KEY not set in environment / .env")

DB_PATH = "incidents.db"   
BATCH_SIZE = 32            # how many canonical incidents to process per batch

retry_config = types.HttpRetryOptions(
    attempts=5,
    exp_base=7,
    initial_delay=1,
    http_status_codes=[429, 500, 503, 504],
)

CATLOC_SYSTEM_INSTRUCTIONS = """
You are an OSINT incident classification and location extraction assistant
for a geospatial mapping pipeline.

Your job:
Given a CLEANED OSINT message that is already known to describe a concrete,
localized incident, you must:

YOUR JOB (STRICT):
1. Identify ONE incident category.
2. Extract ONE geocodable location string if present.

CATEGORY SEMANTIC EXAMPLES (FOR INTERPRETATION ONLY):
These examples illustrate the meaning of categories. They are NEVER valid outputs.
- "attack": armed attack, shooting, skirmish, clash, firefight
- "explosion": bomb blast, IED, grenade explosion, rocket impact
- "shelling": artillery fire, mortar fire, rocket shelling
- "drone_strike": drone-delivered munition, drone strike
- "air_strike": jet or aircraft bombing, air raid
- "air_activity": military jet/helicopter overflight, unusual air activity
- "raid_search": raid, cordon & search operation
- "arrest_detention": arrest, capture, detention, chargesheets
- "weapons_seizure": seizure of weapons, explosives, contraband
- "casualty_death": confirmed death of soldier/civilian caused by an incident
- "injury": injuries reported without confirmed death
- "protest_riot": violent protest, riot, unrest
- "disaster": fire, flood, landslide, accident, building collapse, infrastructure damage
- "movement": troop/convoy movement, mobilization, infiltration attempt
- "kidnapping": abduction or kidnapping
- "smuggling": smuggling interdiction, trafficking crackdown

ALLOWED OUTPUT CATEGORIES (CLOSED LIST — USE EXACTLY ONE):
["attack", "explosion", "shelling", "drone_strike", "air_strike",
 "air_activity", "raid_search", "arrest_detention", "weapons_seizure",
 "casualty_death", "injury", "protest_riot",
 "movement", "disaster", "kidnapping", "smuggling"]

CATEGORY RULES:
- Choose EXACTLY ONE label from the CLOSED LIST above.
- NEVER output any example phrases or synonyms.
- The category value MUST be exactly one of the allowed labels.
- If uncertain, choose the closest valid category.
- Do NOT invent new categories.

DEATH VS INJURY RULES:
- "injury" is for cases where injuries are mentioned and NO death is confirmed.
- "casualty_death" is for messages whose PRIMARY focus is that someone has died
  as a result of an incident (for example, an injured person later
  "succumbed to injuries", "was martyred", or "was found dead").
- If the message mainly describes an action-type incident (attack, explosion,
  shelling, drone_strike, air_strike, etc.) and mentions that people were
  "killed" or "died" as part of that event, you should choose the ACTION
  category (e.g., "attack", "explosion", "shelling", "drone_strike",
  "air_strike") rather than "casualty_death".
- Only choose "casualty_death" when the death itself is the main subject of
  the message (for example, a follow-up report about a specific person dying).

LOCATION EXTRACTION RULES:
- Extract ONE location string that a geocoding service (e.g., Google Maps) can interpret.
- Use a comma-separated hierarchy when possible, for example:
  "Bannu, Khyber Pakhtunkhwa, Pakistan"
  "Kupwara, Jammu and Kashmir, India"
  "Peshawar, Khyber Pakhtunkhwa, Pakistan"
- Prefer the most specific place mentioned (town > district > region > country).
- Include the country when it is explicitly mentioned or clearly implied.
- Do NOT guess or invent a country if it is not clearly indicated.
- When multiple locations or countries are mentioned, choose the location
  where the incident physically occurred or where casualties/damage happened,
  NOT the origin of an attack or drone. For example, if a drone is launched
  from Country A and kills people in Country B, choose Country B.
- If the message mentions MULTIPLE locations, choose ONE based on where the MAIN incident occurs.
- NEVER return lists, arrays, multiple places, or separators like ";", "/", " and ".
- Do NOT add descriptive words such as "near", "around", "border area of".
  Use only the place names, e.g. "Bannu, Khyber Pakhtunkhwa, Pakistan".
- If only a country is given, return just that country, e.g. "Pakistan".
- If no concrete location exists, return "" (empty string).

OUTPUT FORMAT (STRICT):
Return a SINGLE JSON object with EXACTLY two keys:
{
  "category": "<one_of_the_allowed_labels>",
  "location_text": "<string_or_empty>"
}

Do NOT include any extra keys.
Do NOT include comments or explanations.
No explanations. No additional fields. Must be valid JSON.
""".strip()


# ----------------- DB HELPERS -----------------

def get_connection(db_path: str = DB_PATH) -> sqlite3.Connection:
    """Return a sqlite3 connection to the DB file."""
    return sqlite3.connect(db_path)


def fetch_rows_for_catloc(
    conn: sqlite3.Connection,
    limit: int = BATCH_SIZE,
) -> List[Tuple[int, str, Optional[str], Optional[str]]]:
    """
    Fetch a batch of canonical incidents that need category/location extraction.

    Conditions:
    - checked = 1              (incident-like)
    - processed = 1            (canonical, not duplicate)
    - text_clean not NULL/empty
    - category is NULL/empty   (we only run once per row)

    Returns:
        (id, text_clean, date, chat_title)
    """
    cur = conn.cursor()
    cur.execute(
        """
        SELECT id, text_clean, date, chat_title
        FROM events
        WHERE checked = 1
          AND processed = 1
          AND text_clean IS NOT NULL
          AND TRIM(text_clean) <> ''
          AND (category IS NULL OR TRIM(category) = '')
        ORDER BY id
        LIMIT ?
        """,
        (limit,),
    )
    return cur.fetchall()


def update_catloc(
    conn: sqlite3.Connection,
    row_id: int,
    category: str,
    location_text: str,
) -> None:
    """Update the category and location_text for a single row."""
    cur = conn.cursor()
    cur.execute(
        """
        UPDATE events
        SET category = ?, location_text = ?
        WHERE id = ?
        """,
        (category, location_text, row_id),
    )


# ----------------- PROMPT BUILDER -----------------

def build_catloc_prompt(
    text_clean: str,
    date_str: Optional[str],
    chat_title: Optional[str],
) -> str:
    """
    Build the user prompt that will be sent to the category+location agent.

    We provide some extra context (date, chat_title) but text_clean
    is the primary source of truth.
    """
    context_lines = []
    if date_str:
        context_lines.append(f"Date: {date_str}")
    if chat_title:
        context_lines.append(f"Channel: {chat_title}")
    context_block = "\n".join(context_lines) if context_lines else "Date/Channel: (not specified)"

    user_prompt = f"""
You are given a CLEANED OSINT incident message and some optional context.

CONTEXT:
{context_block}

CLEANED MESSAGE:
{text_clean}

Using your incident classification and location extraction rules,
return a JSON object with two keys: "category" and "location_text".

Remember:
- "category" is a short incident type label.
- "location_text" is the most specific geocodable place, or "" if none.

Output ONLY the JSON object.
""".strip()
    return user_prompt


# ----------------- ADK AGENT SETUP -----------------

def create_catloc_agent() -> LlmAgent:
    """
    Create and return the LlmAgent dedicated to category + location extraction.
    """
    agent = LlmAgent(
        name="Agent4_CategoryLocation",
        model=Gemini(
            model="gemini-2.5-flash-lite",
            api_key=GOOGLE_API_KEY,
            retry_options=retry_config,
        ),
        description="Extracts incident category and geocodable location_text from cleaned OSINT messages.",
        instruction=CATLOC_SYSTEM_INSTRUCTIONS,
        tools=[],  # no external tools needed
    )
    return agent


# ----------------- LLM CALL WRAPPER -----------------

class CatLocLLM:
    """
    Wrapper around an InMemoryRunner for the category+location agent.

    Provides:
        async call(...) -> (category: str, location_text: str)
    """

    def __init__(self, runner: InMemoryRunner):
        self.runner = runner

    async def call(
        self,
        text_clean: str,
        date_str: Optional[str],
        chat_title: Optional[str],
    ) -> Tuple[str, str]:
        prompt = build_catloc_prompt(text_clean, date_str, chat_title)
        events = await self.runner.run_debug(prompt)

        # Find the last non-user event with content
        assistant_event = None
        for e in reversed(events):
            if getattr(e, "author", "") == "user":
                continue
            if getattr(e, "content", None) is None:
                continue
            assistant_event = e
            break

        if assistant_event is None:
            # Fallback: choose a valid default category with no location
            return "attack", ""

        parts = getattr(assistant_event.content, "parts", [])
        texts = []
        for p in parts:
            if hasattr(p, "text") and p.text:
                texts.append(p.text)

        raw_text = "\n".join(texts).strip()

        # Strip Markdown code fences if present (```json ... ```)
        cleaned = raw_text
        if cleaned.startswith("```"):
            lines = cleaned.splitlines()
            # Drop leading ``` or ```json line
            if lines:
                lines = lines[1:]
            # Drop trailing ``` line if present
            if lines and lines[-1].strip().startswith("```"):
                lines = lines[:-1]
            cleaned = "\n".join(lines).strip()

        category = ""
        location_text = ""

        try:
            obj = json.loads(cleaned)
            if isinstance(obj, dict):
                cat_val = obj.get("category", "")
                loc_val = obj.get("location_text", "")
                if isinstance(cat_val, str) and cat_val.strip():
                    category = cat_val.strip()
                if isinstance(loc_val, str):
                    location_text = loc_val.strip()
        except Exception as e:
            print(f"[CatLoc] JSON parse error: {e}")

        # Basic cleanup
        category = category[:100] if category else ""
        location_text = location_text[:255] if location_text else ""

        # Final safety: ensure category is one of the allowed labels
        ALLOWED = {
            "attack", "explosion", "shelling", "drone_strike", "air_strike",
            "air_activity", "raid_search", "arrest_detention", "weapons_seizure",
            "casualty_death", "injury", "protest_riot",
            "movement", "disaster", "kidnapping", "smuggling",
        }
        if category not in ALLOWED:
            category = "attack"

        return category, location_text


# ----------------- BATCH LOGIC (ASYNC) -----------------

async def run_catloc_batch(
    llm: CatLocLLM,
    db_path: str = DB_PATH,
    batch_size: int = BATCH_SIZE,
) -> int:
    """
    Process a single batch of canonical incidents that need category/location.

    Returns:
        Number of rows updated in this batch.
    """
    conn = get_connection(db_path)
    try:
        rows = fetch_rows_for_catloc(conn, limit=batch_size)
        if not rows:
            return 0

        for row_id, text_clean, date_str, chat_title in rows:
            if not text_clean or not text_clean.strip():
                # Shouldn't happen, but be defensive
                update_catloc(conn, row_id, "attack", "")
                continue

            try:
                category, location_text = await llm.call(
                    text_clean=text_clean,
                    date_str=date_str,
                    chat_title=chat_title,
                )
            except Exception as e:
                print(f"[CatLoc] LLM error for id={row_id}: {e}")
                category, location_text = "attack", ""

            update_catloc(conn, row_id, category, location_text)

        conn.commit()
        return len(rows)

    finally:
        conn.close()


async def run_catloc_until_done(
    llm: CatLocLLM,
    db_path: str = DB_PATH,
    batch_size: int = BATCH_SIZE,
) -> None:
    """
    Keep running batches until there are no more canonical incidents
    needing category/location extraction.
    """
    total = 0
    while True:
        processed = await run_catloc_batch(
            llm=llm,
            db_path=db_path,
            batch_size=batch_size,
        )
        if processed == 0:
            break
        total += processed
        print(f"[CatLoc] Processed batch of {processed} rows (total={total}).")

    print(f"[CatLoc] Done. Total rows updated with category/location_text: {total}")


# ----------------- NOTEBOOK ENTRYPOINT -----------------

async def run_agent4_catloc():

    catloc_agent = create_catloc_agent()
    print("[CatLoc] Agent created.")

    catloc_runner = InMemoryRunner(agent=catloc_agent)
    print("[CatLoc] Runner created.")

    llm = CatLocLLM(runner=catloc_runner)
    await run_catloc_until_done(llm=llm, db_path=DB_PATH, batch_size=BATCH_SIZE)

    print("[CatLoc] Completed.")

# %%
await run_agent4_catloc()
# Out:
# App name mismatch detected. The runner is configured with app name "InMemoryRunner", but the root agent was loaded from "C:\Users\Lenovo\Desktop\AgentAICourse\agentai_venv\Lib\site-packages\google\adk\agents", which implies app name "agents".
# [CatLoc] Agent created.
# [CatLoc] Runner created.
#
#  ### Created new session: debug_session_id
#
# User > You are given a CLEANED OSINT incident message and some optional context.
#
# CONTEXT:
# Date: 2025-11-28T17:00:20
# Channel: OsintTV 📺️
#
# CLEANED MESSAGE:
# A 33 minute long documentary has been released by rebel linked media on the attackers who killed Major Adnan from the SSG and other personnel in the attack on the Bannu FC lines.
#
# Using your incident classification and location extraction rules,
# return a JSON object with two keys: "category" and "location_text".
#
# Remember:
# - "category" is a short incident type label.
# - "location_text" is the most specific geocodable place, or "" if none.
#
# Output ONLY the JSON object.
# Agent4_CategoryLocation > ```json
# {
#   "category": "attack",
#   "location_text": "Bannu"
# }
# ```
#
#  ### Continue session: debug_session_id
#
# User > You are given a CLEANED OSINT incident message and some optional context.
#
# CONTEXT:
# Date: 2025-11-28T16:33:51
# Channel: OsintTV 📺️
#
# CLEANED MESSAGE:
# Just in :
#
# Unknown gunmen shot and killed Maulvi Izzatullah and his son in Tajabad, Pushtakhra area, Peshawar- KP - Pakistan.
#
# Police says the killers escaped. The bodies were sent for postmortem.
#
# The motive is not clear. The eliminated Salafist Maulvi is presumed to be linked to Lashkar e Taiba.
#
# Using your incident classification and location extraction rules,
# return a JSON object with two keys: "category" and "location_text".
#
# Remember:
# - "category" is a short incident type label.
# - "location_text" is the most specific geocodable place, or "" if none.
#
# Output ONLY the JSON object.
# Agent4_CategoryLocation > ```json
# {
#   "category": "attack",
#   "location_text": "Peshawar, Khyber Pakhtunkhwa, Pakistan"
# }
# ```
#
#  ### Continue session: debug_session_id
#
# User > You are given a CLEANED OSINT incident message and some optional context.
#
# CONTEXT:
# Date: 2025-11-28T10:16:36
# Channel: OsintTV 📺️
#
# CLEANED MESSAGE:
# Under Field Marshal Asim Munir’s , the Pakistani Taliban are now walking straight into military bases across Khyber Pakhtunkhwa like they own the place.
#
# The army isn’t fighting back. Posts are being abandoned overnight, soldiers pulling out without a shot fired, leaving basesand weapons behind. The militants move in, film videos and set up checkpoints.
#
# Using your incident classification and location extraction rules,
# return a JSON object with two keys: "category" and "location_text".
#
# Remember:
# - "category" is a short incident type label.
# - "location_text" is the most specific geocodable place, or "" if none.
#
# Output ONLY the JSON object.
# Agent4_CategoryLocation > ```json
# {
#   "category": "movement",
#   "location_text": "Khyber Pakhtunkhwa, Pakistan"
# }
# ```
#
#  ### Continue session: debug_session_id
#
# User > You are given a CLEANED OSINT incident message and some optional context.
#
# CONTEXT:
# Date: 2025-11-28T10:10:09
# Channel: OsintTV 📺️
#
# CLEANED MESSAGE:
# As per pro rebel sources a massive attack was launched on the Police station in Bannu, KPK resulting in death of 7 police personals.
#
# Mean while pakistani side sources reported injuries to 5 police personals
#
# Using your incident classification and location extraction rules,
# return a JSON object with two keys: "category" and "location_text".
#
# Remember:
# - "category" is a short incident type label.
# - "location_text" is the most specific geocodable place, or "" if none.
#
# Output ONLY the JSON object.
# Agent4_CategoryLocation > ```json
# {
#   "category": "attack",
#   "location_text": "Bannu, Khyber Pakhtunkhwa"
# }
# ```
#
#  ### Continue session: debug_session_id
#
# User > You are given a CLEANED OSINT incident message and some optional context.
#
# CONTEXT:
# Date: 2025-11-27T21:02:13
# Channel: OsintTV 📺️
#
# CLEANED MESSAGE:
# According to TTP sources, reportedly rebels fired a homemade rocket at the Wali Noor PaK military camp in the Janikhel area of the Baka Khel subdivision.
#
# They shared a photo and said the video will be released soon.
#
# Using your incident classification and location extraction rules,
# return a JSON object with two keys: "category" and "location_text".
#
# Remember:
# - "category" is a short incident type label.
# - "location_text" is the most specific geocodable place, or "" if none.
#
# Output ONLY the JSON object.
# Agent4_CategoryLocation > ```json
# {
#   "category": "shelling",
#   "location_text": "Janikhel, Baka Khel subdivision"
# }
# ```
#
#  ### Continue session: debug_session_id
#
# User > You are given a CLEANED OSINT incident message and some optional context.
#
# CONTEXT:
# Date: 2025-11-27T09:46:16
# Channel: OsintTV 📺️
#
# CLEANED MESSAGE:
# BLA says Four Pakistani Army Personnel Eliminated in Panjgur Attack .
#
# Using your incident classification and location extraction rules,
# return a JSON object with two keys: "category" and "location_text".
#
# Remember:
# - "category" is a short incident type label.
# - "location_text" is the most specific geocodable place, or "" if none.
#
# Output ONLY the JSON object.
# Agent4_CategoryLocation > ```json
# {
#   "category": "attack",
#   "location_text": "Panjgur"
# }
# ```
#
#  ### Continue session: debug_session_id
#
# User > You are given a CLEANED OSINT incident message and some optional context.
#
# CONTEXT:
# Date: 2025-11-28T15:59:06
# Channel: War & Gore
#
# CLEANED MESSAGE:
# Hong Kong Fire incident:
#
# Death toll reaches 128.
#
# Using your incident classification and location extraction rules,
# return a JSON object with two keys: "category" and "location_text".
#
# Remember:
# - "category" is a short incident type label.
# - "location_text" is the most specific geocodable place, or "" if none.
#
# Output ONLY the JSON object.
# Agent4_CategoryLocation > ```json
# {
#   "category": "disaster",
#   "location_text": "Hong Kong"
# }
# ```
#
#  ### Continue session: debug_session_id
#
# User > You are given a CLEANED OSINT incident message and some optional context.
#
# CONTEXT:
# Date: 2025-11-28T15:37:32
# Channel: War & Gore
#
# CLEANED MESSAGE:
# Statement from officials -A patrolling party of Assam Rifles was fired upon by terrorists in Tengnoupal district of Manipur, along the India-Myanmar Border in the early morning hours today. Operations are currently underway, with additional troops being deployed into the area.
#
# Using your incident classification and location extraction rules,
# return a JSON object with two keys: "category" and "location_text".
#
# Remember:
# - "category" is a short incident type label.
# - "location_text" is the most specific geocodable place, or "" if none.
#
# Output ONLY the JSON object.
# Agent4_CategoryLocation > ```json
# {
#   "category": "attack",
#   "location_text": "Tengnoupal district, Manipur, India"
# }
# ```
#
#  ### Continue session: debug_session_id
#
# User > You are given a CLEANED OSINT incident message and some optional context.
#
# CONTEXT:
# Date: 2025-11-28T15:35:33
# Channel: War & Gore
#
# CLEANED MESSAGE:
# Udhampur:Security forces have launched a major search operation in Basantgarh after movement of three suspected terrorists.
#
# Using your incident classification and location extraction rules,
# return a JSON object with two keys: "category" and "location_text".
#
# Remember:
# - "category" is a short incident type label.
# - "location_text" is the most specific geocodable place, or "" if none.
#
# Output ONLY the JSON object.
# Agent4_CategoryLocation > ```json
# {
#   "category": "raid_search",
#   "location_text": "Basantgarh, Udhampur"
# }
# ```
#
#  ### Continue session: debug_session_id
#
# User > You are given a CLEANED OSINT incident message and some optional context.
#
# CONTEXT:
# Date: 2025-11-28T15:34:03
# Channel: War & Gore
#
# CLEANED MESSAGE:
# Manipur: Reportedly PLA Terrorists attacked post BP-87
# in Tengnoupal (Manipur) around 4:30 am. 4 jawans are said to be injured.
#
# Using your incident classification and location extraction rules,
# return a JSON object with two keys: "category" and "location_text".
#
# Remember:
# - "category" is a short incident type label.
# - "location_text" is the most specific geocodable place, or "" if none.
#
# Output ONLY the JSON object.
# Agent4_CategoryLocation > ```json
# {
#   "category": "attack",
#   "location_text": "Tengnoupal, Manipur"
# }
# ```
#
#  ### Continue session: debug_session_id
#
# User > You are given a CLEANED OSINT incident message and some optional context.
#
# CONTEXT:
# Date: 2025-11-27T19:37:26
# Channel: War & Gore
#
# CLEANED MESSAGE:
# Reportedly RPG attack on a FC post
#
# Using your incident classification and location extraction rules,
# return a JSON object with two keys: "category" and "location_text".
#
# Remember:
# - "category" is a short incident type label.
# - "location_text" is the most specific geocodable place, or "" if none.
#
# Output ONLY the JSON object.
# Agent4_CategoryLocation > ```json
# {
#   "category": "attack",
#   "location_text": ""
# }
# ```
#
#  ### Continue session: debug_session_id
#
# User > You are given a CLEANED OSINT incident message and some optional context.
#
# CONTEXT:
# Date: 2025-11-27T16:47:31
# Channel: War & Gore
#
# CLEANED MESSAGE:
# A quadcopter drone attack on a police post in Bannu district, Khyber Pakhtunkhwa province has injured two policemen: Police
#
# Using your incident classification and location extraction rules,
# return a JSON object with two keys: "category" and "location_text".
#
# Remember:
# - "category" is a short incident type label.
# - "location_text" is the most specific geocodable place, or "" if none.
#
# Output ONLY the JSON object.
# Agent4_CategoryLocation > ```json
# {
#   "category": "drone_strike",
#   "location_text": "Bannu district, Khyber Pakhtunkhwa province"
# }
# ```
#
#  ### Continue session: debug_session_id
#
# User > You are given a CLEANED OSINT incident message and some optional context.
#
# CONTEXT:
# Date: 2025-11-27T10:50:55
# Channel: War & Gore
#
# CLEANED MESSAGE:
# 24 years old Pakistani intruder arrested from Barmer Rajasthan.
#
# Using your incident classification and location extraction rules,
# return a JSON object with two keys: "category" and "location_text".
#
# Remember:
# - "category" is a short incident type label.
# - "location_text" is the most specific geocodable place, or "" if none.
#
# Output ONLY the JSON object.
# Agent4_CategoryLocation > ```json
# {
#   "category": "arrest_detention",
#   "location_text": "Barmer, Rajasthan"
# }
# ```
#
#  ### Continue session: debug_session_id
#
# User > You are given a CLEANED OSINT incident message and some optional context.
#
# CONTEXT:
# Date: 2025-11-27T10:42:12
# Channel: War & Gore
#
# CLEANED MESSAGE:
# 11 killed as train hits railway workers in southwest China.
#
# Using your incident classification and location extraction rules,
# return a JSON object with two keys: "category" and "location_text".
#
# Remember:
# - "category" is a short incident type label.
# - "location_text" is the most specific geocodable place, or "" if none.
#
# Output ONLY the JSON object.
# Agent4_CategoryLocation > ```json
# {
#   "category": "disaster",
#   "location_text": "southwest China"
# }
# ```
#
#  ### Continue session: debug_session_id
#
# User > You are given a CLEANED OSINT incident message and some optional context.
#
# CONTEXT:
# Date: 2025-11-27T10:38:37
# Channel: War & Gore
#
# CLEANED MESSAGE:
# Hong Kong Fire incident:
#
# 42 people died & 280+ are said to be Injured/missing.
#
# Using your incident classification and location extraction rules,
# return a JSON object with two keys: "category" and "location_text".
#
# Remember:
# - "category" is a short incident type label.
# - "location_text" is the most specific geocodable place, or "" if none.
#
# Output ONLY the JSON object.
# Agent4_CategoryLocation > ```json
# {
#   "category": "disaster",
#   "location_text": "Hong Kong"
# }
# ```
#
#  ### Continue session: debug_session_id
#
# User > You are given a CLEANED OSINT incident message and some optional context.
#
# CONTEXT:
# Date: 2025-11-28T19:02:34
# Channel: ElitePredators
#
# CLEANED MESSAGE:
# Woman killed, two others injured in IED blast in Jharkhand''s Chaibasa: Police
#
# ~ PTI
#
# Using your incident classification and location extraction rules,
# return a JSON object with two keys: "category" and "location_text".
#
# Remember:
# - "category" is a short incident type label.
# - "location_text" is the most specific geocodable place, or "" if none.
#
# Output ONLY the JSON object.
# Agent4_CategoryLocation > ```json
# {
#   "category": "explosion",
#   "location_text": "Chaibasa, Jharkhand"
# }
# ```
#
#  ### Continue session: debug_session_id
#
# User > You are given a CLEANED OSINT incident message and some optional context.
#
# CONTEXT:
# Date: 2025-11-28T16:09:11
# Channel: ElitePredators
#
# CLEANED MESSAGE:
# Pakistan: Maulana Qari Izzatullah was shot dead near University Town a short while ago, according to local sources.
#
# The attackers have not yet been identified, and police have launched an investigation into the incident.
#
# Using your incident classification and location extraction rules,
# return a JSON object with two keys: "category" and "location_text".
#
# Remember:
# - "category" is a short incident type label.
# - "location_text" is the most specific geocodable place, or "" if none.
#
# Output ONLY the JSON object.
# Agent4_CategoryLocation > ```json
# {
#   "category": "attack",
#   "location_text": "University Town, Pakistan"
# }
# ```
#
#  ### Continue session: debug_session_id
#
# User > You are given a CLEANED OSINT incident message and some optional context.
#
# CONTEXT:
# Date: 2025-11-28T16:03:35
# Channel: ElitePredators
#
# CLEANED MESSAGE:
# 1. Cyclone Ditwah has hit Sri Lanka, causing major loss of life and destruction.
#
# 2. India launched Operation Sagar Bandhu to provide urgent HADR support to its closest maritime neighbour.
#
# 3. INS Vikrant and INS Udaigiri delivered the first relief supplies to Colombo.
#
# 4. The mission reflects India’s Neighbourhood First and SAGAR vision, with PM Modi and EAM Dr. S. Jaishankar assuring full support to Sri Lanka.
#
# Using your incident classification and location extraction rules,
# return a JSON object with two keys: "category" and "location_text".
#
# Remember:
# - "category" is a short incident type label.
# - "location_text" is the most specific geocodable place, or "" if none.
#
# Output ONLY the JSON object.
# Agent4_CategoryLocation > ```json
# {
#   "category": "disaster",
#   "location_text": "Sri Lanka"
# }
# ```
#
#  ### Continue session: debug_session_id
#
# User > You are given a CLEANED OSINT incident message and some optional context.
#
# CONTEXT:
# Date: 2025-11-28T15:56:11
# Channel: ElitePredators
#
# CLEANED MESSAGE:
# Khyber PakhtunKhwa
#
# The injured soldier of Frontier constabulary succumbed to his injuries in hospital.
#
# Using your incident classification and location extraction rules,
# return a JSON object with two keys: "category" and "location_text".
#
# Remember:
# - "category" is a short incident type label.
# - "location_text" is the most specific geocodable place, or "" if none.
#
# Output ONLY the JSON object.
# Agent4_CategoryLocation > ```json
# {
#   "category": "casualty_death",
#   "location_text": "Khyber Pakhtunkhwa"
# }
# ```
#
#  ### Continue session: debug_session_id
#
# User > You are given a CLEANED OSINT incident message and some optional context.
#
# CONTEXT:
# Date: 2025-11-28T14:02:11
# Channel: ElitePredators
#
# CLEANED MESSAGE:
# Israeli forces carried out an incursion into the Syrian town of Beit Jinn in rural Damascus.
#
# Clashes reported between local residents and the troops, wherein IDF reportedly used artilleries and drones.
#
# Using your incident classification and location extraction rules,
# return a JSON object with two keys: "category" and "location_text".
#
# Remember:
# - "category" is a short incident type label.
# - "location_text" is the most specific geocodable place, or "" if none.
#
# Output ONLY the JSON object.
# Agent4_CategoryLocation > ```json
# {
#   "category": "attack",
#   "location_text": "Beit Jinn, rural Damascus, Syria"
# }
# ```
#
#  ### Continue session: debug_session_id
#
# User > You are given a CLEANED OSINT incident message and some optional context.
#
# CONTEXT:
# Date: 2025-11-28T13:07:51
# Channel: ElitePredators
#
# CLEANED MESSAGE:
# On Friday, November 28, at midnight, the Mujahideen of the Pakistan Revolution Movement and the Burr and Jamaat jointly launched a counterattack on the Domail Ahmadzai police station. With the grace of Allah, the Mujahideen displayed great courage and captured the police station. During this time, more police and army troops also arrived from Bannu, with whom a fierce battle ensued. Alhamdulillah, according to reliable reports, several anti-Sharia police officers were killed and injured in this battle.
#
# Maulvi Ismail Khan, spokesman for the Pakistan Revolution
#
# Using your incident classification and location extraction rules,
# return a JSON object with two keys: "category" and "location_text".
#
# Remember:
# - "category" is a short incident type label.
# - "location_text" is the most specific geocodable place, or "" if none.
#
# Output ONLY the JSON object.
# Agent4_CategoryLocation > ```json
# {
#   "category": "attack",
#   "location_text": "Domail Ahmadzai, Bannu"
# }
# ```
#
#  ### Continue session: debug_session_id
#
# User > You are given a CLEANED OSINT incident message and some optional context.
#
# CONTEXT:
# Date: 2025-11-27T22:19:22
# Channel: ElitePredators
#
# CLEANED MESSAGE:
# Tajikistan MFA: "Three Chinese workers were killed in a drone strike from Afghanistan."
#
# Using your incident classification and location extraction rules,
# return a JSON object with two keys: "category" and "location_text".
#
# Remember:
# - "category" is a short incident type label.
# - "location_text" is the most specific geocodable place, or "" if none.
#
# Output ONLY the JSON object.
# Agent4_CategoryLocation > ```json
# {
#   "category": "drone_strike",
#   "location_text": "Tajikistan"
# }
# ```
#
#  ### Continue session: debug_session_id
#
# User > You are given a CLEANED OSINT incident message and some optional context.
#
# CONTEXT:
# Date: 2025-11-27T20:11:16
# Channel: ElitePredators
#
# CLEANED MESSAGE:
# A Pakistani spy identified as Farman son of Shah Jan, resident of Mohabbat Khel, who was involved in the killing of several rebels was executed by TTP rebels after he confessed to the crime.
#
# Using your incident classification and location extraction rules,
# return a JSON object with two keys: "category" and "location_text".
#
# Remember:
# - "category" is a short incident type label.
# - "location_text" is the most specific geocodable place, or "" if none.
#
# Output ONLY the JSON object.
# Agent4_CategoryLocation > ```json
# {
#   "category": "casualty_death",
#   "location_text": "Mohabbat Khel"
# }
# ```
#
#  ### Continue session: debug_session_id
#
# User > You are given a CLEANED OSINT incident message and some optional context.
#
# CONTEXT:
# Date: 2025-11-27T17:55:13
# Channel: ElitePredators
#
# CLEANED MESSAGE:
# A loud explosion has been heard in Wana, South Waziristan
#
# Using your incident classification and location extraction rules,
# return a JSON object with two keys: "category" and "location_text".
#
# Remember:
# - "category" is a short incident type label.
# - "location_text" is the most specific geocodable place, or "" if none.
#
# Output ONLY the JSON object.
# Agent4_CategoryLocation > ```json
# {
#   "category": "explosion",
#   "location_text": "Wana, South Waziristan"
# }
# ```
#
#  ### Continue session: debug_session_id
#
# User > You are given a CLEANED OSINT incident message and some optional context.
#
# CONTEXT:
# Date: 2025-11-27T13:12:54
# Channel: ElitePredators
#
# CLEANED MESSAGE:
# Jammu Police arrested a 19-year-old Reasi native living in Bathindi, a key suspect in FIR 331/2025 u/s 113(3) BNS at PS Bahu Fort. He was allegedly radicalised online and in contact with foreign numbers. His digital devices were seized, and investigation continues.
#
# Using your incident classification and location extraction rules,
# return a JSON object with two keys: "category" and "location_text".
#
# Remember:
# - "category" is a short incident type label.
# - "location_text" is the most specific geocodable place, or "" if none.
#
# Output ONLY the JSON object.
# Agent4_CategoryLocation > ```json
# {
#   "category": "arrest_detention",
#   "location_text": "Bathindi, Jammu"
# }
# ```
#
#  ### Continue session: debug_session_id
#
# User > You are given a CLEANED OSINT incident message and some optional context.
#
# CONTEXT:
# Date: 2025-11-27T09:58:01
# Channel: ElitePredators
#
# CLEANED MESSAGE:
# US Special Forces launched a ground operation against the Islamic State of the Somalia Province (ISSP), in the Baalade Valley, Puntland, Somalia.
#
# Violent clashes erupted between the US troops and ISSP in the Cal-Miskaad mountain range.
#
# At least 100 US SF personnel were carrying out the ground operation.
#
# Using your incident classification and location extraction rules,
# return a JSON object with two keys: "category" and "location_text".
#
# Remember:
# - "category" is a short incident type label.
# - "location_text" is the most specific geocodable place, or "" if none.
#
# Output ONLY the JSON object.
# Agent4_CategoryLocation > ```json
# {
#   "category": "attack",
#   "location_text": "Baalade Valley, Puntland, Somalia"
# }
# ```
#
#  ### Continue session: debug_session_id
#
# User > You are given a CLEANED OSINT incident message and some optional context.
#
# CONTEXT:
# Date: 2025-11-27T09:55:48
# Channel: ElitePredators
#
# CLEANED MESSAGE:
# Two US National Guard members were shot near the White House in an apparent ambush.
#
# Using your incident classification and location extraction rules,
# return a JSON object with two keys: "category" and "location_text".
#
# Remember:
# - "category" is a short incident type label.
# - "location_text" is the most specific geocodable place, or "" if none.
#
# Output ONLY the JSON object.
# Agent4_CategoryLocation > ```json
# {
#   "category": "attack",
#   "location_text": "White House"
# }
# ```
#
#  ### Continue session: debug_session_id
#
# User > You are given a CLEANED OSINT incident message and some optional context.
#
# CONTEXT:
# Date: 2025-11-27T08:35:05
# Channel: ElitePredators
#
# CLEANED MESSAGE:
# 44 dead and 300+ missing after massive fire engulfed several high rise residential towers in Hong Kong!!
#
# Three senior staff from construction company have been arrested on suspicion of manslaughter
#
# Using your incident classification and location extraction rules,
# return a JSON object with two keys: "category" and "location_text".
#
# Remember:
# - "category" is a short incident type label.
# - "location_text" is the most specific geocodable place, or "" if none.
#
# Output ONLY the JSON object.
# Agent4_CategoryLocation > ```json
# {
#   "category": "disaster",
#   "location_text": "Hong Kong"
# }
# ```
#
#  ### Continue session: debug_session_id
#
# User > You are given a CLEANED OSINT incident message and some optional context.
#
# CONTEXT:
# Date: 2025-11-27T07:59:25
# Channel: ElitePredators
#
# CLEANED MESSAGE:
# Unknown drones reportedly carried out strikes on ISIS-linked locations in the Jabar Mela area of Khyber District, Khyber Pakhtunkhwa, according to Al-Mersad.
# The area hosts key ISIS-K figures, including Gul Nazim, Sadiqyar, and Hudhaifa. Nazim, who leads ISIS-K’s eastern zone, has been active in Jabar Mela since 2024.
#
# Using your incident classification and location extraction rules,
# return a JSON object with two keys: "category" and "location_text".
#
# Remember:
# - "category" is a short incident type label.
# - "location_text" is the most specific geocodable place, or "" if none.
#
# Output ONLY the JSON object.
# Agent4_CategoryLocation > ```json
# {
#   "category": "drone_strike",
#   "location_text": "Jabar Mela, Khyber District, Khyber Pakhtunkhwa"
# }
# ```
#
#  ### Continue session: debug_session_id
#
# User > You are given a CLEANED OSINT incident message and some optional context.
#
# CONTEXT:
# Date: 2025-11-27T04:22:29
# Channel: ElitePredators
#
# CLEANED MESSAGE:
# Washington, DC:
#
# An unidentified individual, shot two US Army National Guards near the WH.
#
# Guardsmen are critically wounded and being treated.
#
# Suspect in custody.
#
# FBI, Metro PD, etc were rushed to the spot.
#
# Using your incident classification and location extraction rules,
# return a JSON object with two keys: "category" and "location_text".
#
# Remember:
# - "category" is a short incident type label.
# - "location_text" is the most specific geocodable place, or "" if none.
#
# Output ONLY the JSON object.
# Agent4_CategoryLocation > ```json
# {
#   "category": "attack",
#   "location_text": "Washington, DC"
# }
# ```
#
#  ### Continue session: debug_session_id
#
# User > You are given a CLEANED OSINT incident message and some optional context.
#
# CONTEXT:
# Date: 2025-11-27T00:24:01
# Channel: ElitePredators
#
# CLEANED MESSAGE:
# Nigeria declares Nationwide State of Emergency amid escalating insurgency And kidnapping crisis.
#
# Using your incident classification and location extraction rules,
# return a JSON object with two keys: "category" and "location_text".
#
# Remember:
# - "category" is a short incident type label.
# - "location_text" is the most specific geocodable place, or "" if none.
#
# Output ONLY the JSON object.
# Agent4_CategoryLocation > ```json
# {
#   "category": "kidnapping",
#   "location_text": "Nigeria"
# }
# ```
#
#  ### Continue session: debug_session_id
#
# User > You are given a CLEANED OSINT incident message and some optional context.
#
# CONTEXT:
# Date: 2025-11-27T00:06:30
# Channel: ElitePredators
#
# CLEANED MESSAGE:
# Two lawyers from Nuh, Haryana were arrested for spying for ISI.
#
# -- Rizwan Khan and his associate Musharraf aka Parvez.
#
# Using your incident classification and location extraction rules,
# return a JSON object with two keys: "category" and "location_text".
#
# Remember:
# - "category" is a short incident type label.
# - "location_text" is the most specific geocodable place, or "" if none.
#
# Output ONLY the JSON object.
# Agent4_CategoryLocation > ```json
# {
#   "category": "arrest_detention",
#   "location_text": "Nuh, Haryana"
# }
# ```
# [CatLoc] Processed batch of 32 rows (total=32).
#
#  ### Continue session: debug_session_id
#
# User > You are given a CLEANED OSINT incident message and some optional context.
#
# CONTEXT:
# Date: 2025-11-28T22:55:53
# Channel: Resonant News 📰
#
# CLEANED MESSAGE:
# India's most successful counterinsurgency operation in #kashmir | Indian Army
# | Assam Rifles
#
# — when 72 terrorists were KILLED in one day🇮🇳🇮🇳🇮🇳
#
# Using your incident classification and location extraction rules,
# return a JSON object with two keys: "category" and "location_text".
#
# Remember:
# - "category" is a short incident type label.
# - "location_text" is the most specific geocodable place, or "" if none.
#
# Output ONLY the JSON object.
# Agent4_CategoryLocation > ```json
# {
#   "category": "attack",
#   "location_text": "Kashmir"
# }
# ```
#
#  ### Continue session: debug_session_id
#
# User > You are given a CLEANED OSINT incident message and some optional context.
#
# CONTEXT:
# Date: 2025-11-28T22:33:36
# Channel: Resonant News 📰
#
# CLEANED MESSAGE:
# Assam rifles/AR patrolling party ambushed in Saibol (Manipur);
# 4 soldiers injured
#
# Today, four Assam Rifles soldiers were injured when terrorists opened fire on their patrol in Manipur’s Tengnoupal district near the India 🇮🇳Myanmar🇲🇲- border.
#
# The incident took place close to border pillar No. 87 near Saibol village.
#
# In an official statement, the Defence Ministry confirmed that terrorists along the India-Myanmar border targeted the Assam Rifles patrol this morning. The troops responded with controlled and cautious retaliation to ensure civilian safety.
#
# The attack occurred in a porous border area of Tengnoupal district known for frequent militant activity.
#
# As of now, no insurgent group has claimed responsibility for the ambush.
#
# @ResonantNews
#
# Using your incident classification and location extraction rules,
# return a JSON object with two keys: "category" and "location_text".
#
# Remember:
# - "category" is a short incident type label.
# - "location_text" is the most specific geocodable place, or "" if none.
#
# Output ONLY the JSON object.
# Agent4_CategoryLocation > ```json
# {
#   "category": "attack",
#   "location_text": "Saibol, Tengnoupal district, Manipur, India"
# }
# ```
#
#  ### Continue session: debug_session_id
#
# User > You are given a CLEANED OSINT incident message and some optional context.
#
# CONTEXT:
# Date: 2025-11-28T21:10:06
# Channel: Resonant News 📰
#
# CLEANED MESSAGE:
# Part-1️⃣🚨BIG!
#
# 👉Awantipora Police, along with 42 #RashtriyaRifles and 180 Battalion #CRPF, busted a Jaish-e-Mohammad (JeM)-linked hideout in south #Kashmir.
#
# 👉Operation was launched on Friday based on specific intelligence about terrorist presence in Naner Midoora area of Tral.
# A joint cordon-and-search operation was conducted in the area.
# 👉Forces apprehended a key terror associate identified as Nazir Ahmed Ganai, son of Abdul Aziz Ganai, resident of Ganai Mohalla Nanar.
#
# The arrested individual has known links with proscribed terrorist outfit Jaish-e-Mohammad (JeM).
# During sustained questioning, Nazir Ahmed Ganai disclosed the location of a concealed hideout in his own orchards.
# 👉Security forces unearthed the hideout and recovered:Two hand grenades
# One detonator
# Explosive-like material
#
# Join Kashmir Conflict stories
#
# Using your incident classification and location extraction rules,
# return a JSON object with two keys: "category" and "location_text".
#
# Remember:
# - "category" is a short incident type label.
# - "location_text" is the most specific geocodable place, or "" if none.
#
# Output ONLY the JSON object.
# Agent4_CategoryLocation > ```json
# {
#   "category": "weapons_seizure",
#   "location_text": "Naner Midoora, Tral, Kashmir"
# }
# ```
#
#  ### Continue session: debug_session_id
#
# User > You are given a CLEANED OSINT incident message and some optional context.
#
# CONTEXT:
# Date: 2025-11-28T15:58:30
# Channel: Resonant News 📰
#
# CLEANED MESSAGE:
# WATCH
#
# 3 Chinese men killed in a drone strike from Afghanistan inside Tajikistan
#
# 2nd such incident in last one year‼️
#
# The Chinese and Pakistanis are slowly losing hope of dominating in CENTRAL ASIA.
#
# You can also read about BOTH the incidents on ResonantNews website
#
# Using your incident classification and location extraction rules,
# return a JSON object with two keys: "category" and "location_text".
#
# Remember:
# - "category" is a short incident type label.
# - "location_text" is the most specific geocodable place, or "" if none.
#
# Output ONLY the JSON object.
# Agent4_CategoryLocation > ```json
# {
#   "category": "drone_strike",
#   "location_text": "Tajikistan"
# }
# ```
#
#  ### Continue session: debug_session_id
#
# User > You are given a CLEANED OSINT incident message and some optional context.
#
# CONTEXT:
# Date: 2025-11-28T15:32:52
# Channel: Resonant News 📰
#
# CLEANED MESSAGE:
# BREAKING: MIGRANT ACCUSED OF DC ATTACK WAS PREVIOUSLY EVACUATED AFTER AIDING AMERICAN MISSIONS IN KABUL
#
# The Afghan migrant charged with shooting two National Guard soldiers near the White House had worked with the US military, CIA and special forces before being evacuated in 2021 as the Taliban took over Afghanistan.
#
# US media reports highlight the challenges of refugee vetting after his arrival on emergency flights, adding new focus to crime and security debates around former foreign partners.
#
# #NationalGuard #DCshooting #AfghanRefugee #USMilitary #Security #BreakingNews
#
# 📍 @ResonantNews
#
# Using your incident classification and location extraction rules,
# return a JSON object with two keys: "category" and "location_text".
#
# Remember:
# - "category" is a short incident type label.
# - "location_text" is the most specific geocodable place, or "" if none.
#
# Output ONLY the JSON object.
# Agent4_CategoryLocation > ```json
# {
#   "category": "attack",
#   "location_text": "DC"
# }
# ```
#
#  ### Continue session: debug_session_id
#
# User > You are given a CLEANED OSINT incident message and some optional context.
#
# CONTEXT:
# Date: 2025-11-28T13:59:06
# Channel: Resonant News 📰
#
# CLEANED MESSAGE:
# This is HILARIOUS 😄...and SERIOUS at the same time.
#
# 🔴An American plumber sues #FORD reseller after spotting his car being used by !SIS
# A $1,000,000 lawsuit‼️
#
# The ford reseller had promised the owner of the pickup that the LOGO will be removed before being resold.
# But they sold it as it is.
# Soon the owner spotted the pickup being used by !S!S terr01sts. 😅
#
# The billion dollar question is HOW did !s!s get this pickup❓❓❓ 🧐
#
# @ResonantNews
#
# Using your incident classification and location extraction rules,
# return a JSON object with two keys: "category" and "location_text".
#
# Remember:
# - "category" is a short incident type label.
# - "location_text" is the most specific geocodable place, or "" if none.
#
# Output ONLY the JSON object.
# Agent4_CategoryLocation > ```json
# {
#   "category": "smuggling",
#   "location_text": ""
# }
# ```
#
#  ### Continue session: debug_session_id
#
# User > You are given a CLEANED OSINT incident message and some optional context.
#
# CONTEXT:
# Date: 2025-11-28T07:43:56
# Channel: Resonant News 📰
#
# CLEANED MESSAGE:
# HEADLINE
#
# 27/28 - NOVEMBER - 2025
#
# 📍India Rebukes Pakistan Over Ayodhya Remarks
# Diplomatic S**t Heats Up Amid Bigotry
# Read more....
#
# 📍India’s $5 Trillion Economy Goal Delayed by IMF Projections
# Read more....
#
# 📍Amdavad, India Confirmed as Host of 2030 Centenary Games
# Read more....
#
# 📍Australia to Enforce Social Media Ban for Children Under 16
# Read more....
#
# 📍US National Guard Shooting: Afghan Suspect Identified
# Read more....
#
# 📍Taiwan Unveils $40 Billion Defence Budget to Deter China
# Read more....
#
# 📍Bangladesh Slum Fire Leaves Thousands Homeless
# Read more....
#
# 📍India–Nepal Joint Military Exercise ‘Suryakiran-XIX’ Begins in Uttarakhand
# Read more....
#
# 🎥 7 Pakistani Soldiers Killed In 2 Different Attacks
# Video.....
#
# 📍Guinea-Bissau Army Chief Takes Transitional Presidency Amid Coup
# Read more....
#
# 🎥 Pakistan backed JeM Terrorist In Syria
# Video.....
#
# RESONANT NEWS
#
# Using your incident classification and location extraction rules,
# return a JSON object with two keys: "category" and "location_text".
#
# Remember:
# - "category" is a short incident type label.
# - "location_text" is the most specific geocodable place, or "" if none.
#
# Output ONLY the JSON object.
# Agent4_CategoryLocation > ```json
# {
#   "category": "attack",
#   "location_text": ""
# }
# ```
#
#  ### Continue session: debug_session_id
#
# User > You are given a CLEANED OSINT incident message and some optional context.
#
# CONTEXT:
# Date: 2025-11-28T01:28:58
# Channel: Resonant News 📰
#
# CLEANED MESSAGE:
# WARNING WARNING WARNING
# Pakistan backed JeM Terrorist in Syria ‼️
#
# He statement and description of the incident confirms HTS grp (which is ruling Syria right now) is collaborating with JeM.
#
# So how do we know Syria's HTS and Pakistan's JeM are collaborating?
#
# The location and incident he mentioned took place when HTS took over the oldest mosque in Syria.
#
# You can read about it here https://resonantnews.com/2025/11/27/pakistan-backed-jem-in-syria-is-syrian-hts-collaborating-with-pakistans-jem-terror-group/
#
# Earlier in Aug we had posted that Syrian HTS men had visited #ISI HQ in Pakistan
#
# @ResonantNews
#
# Using your incident classification and location extraction rules,
# return a JSON object with two keys: "category" and "location_text".
#
# Remember:
# - "category" is a short incident type label.
# - "location_text" is the most specific geocodable place, or "" if none.
#
# Output ONLY the JSON object.
# Agent4_CategoryLocation > ```json
# {
#   "category": "attack",
#   "location_text": "Syria"
# }
# ```
#
#  ### Continue session: debug_session_id
#
# User > You are given a CLEANED OSINT incident message and some optional context.
#
# CONTEXT:
# Date: 2025-11-27T23:15:32
# Channel: Resonant News 📰
#
# CLEANED MESSAGE:
# BREAKING: MILITARY SUSPENDS INSTITUTIONS, REOPENS BORDERS AFTER ELECTION TURMOIL
#
# General Horta Nta Na Man has assumed the role of "transitional president" after the High Military Command staged a coup in Guinea-Bissau, citing election instability and a plot by “drug lords” to alter the constitutional order.
#
# The military dissolved state institutions, shut media, closed borders (later reopened), and imposed a curfew in Bissau following disputed election results where both incumbent President Umaro Sissoco Embaló and challenger Fernando Dias claimed victory.
#
# International observers, the African Union, and ECOWAS have called for the return of constitutional governance as the West African nation faces yet another episode of political unrest and transitions led by its armed forces.
#
# #GuineaBissau #Coup #TransitionalPresident #MilitaryTakeover #PoliticalCrisis #AfricaNews #Democracy #BreakingNews
#
# 📍 @ResonantNews
#
# Using your incident classification and location extraction rules,
# return a JSON object with two keys: "category" and "location_text".
#
# Remember:
# - "category" is a short incident type label.
# - "location_text" is the most specific geocodable place, or "" if none.
#
# Output ONLY the JSON object.
# Agent4_CategoryLocation > ```json
# {
#   "category": "movement",
#   "location_text": "Guinea-Bissau"
# }
# ```
#
#  ### Continue session: debug_session_id
#
# User > You are given a CLEANED OSINT incident message and some optional context.
#
# CONTEXT:
# Date: 2025-11-27T21:41:04
# Channel: Resonant News 📰
#
# CLEANED MESSAGE:
# WARNING WARNING WARNING
# Pakistan backed JeM Terrorist in Syria ‼️
#
# He statement and description of the incident confirms HTS grp (which is ruling Syria right now) is collaborating with JeM.
#
# So how do we know Syria's HTS and Pakistan's JeM are collaborating?
#
# The location and incident he mentioned took place when HTS took over the oldest mosque in Syria.
#
# You can read about it here https://resonantnews.com/2025/11/27/pakistan-backed-jem-in-syria-is-syrian-hts-collaborating-with-pakistans-jem-terror-group/
#
# Earlier in Aug we had posted that Syrian HTS men had visited #ISI HQ in Pakistan
#
# @ResonantNews
#
# Using your incident classification and location extraction rules,
# return a JSON object with two keys: "category" and "location_text".
#
# Remember:
# - "category" is a short incident type label.
# - "location_text" is the most specific geocodable place, or "" if none.
#
# Output ONLY the JSON object.
# Agent4_CategoryLocation > ```json
# {
#   "category": "attack",
#   "location_text": "Syria"
# }
# ```
#
#  ### Continue session: debug_session_id
#
# User > You are given a CLEANED OSINT incident message and some optional context.
#
# CONTEXT:
# Date: 2025-11-27T20:40:00
# Channel: Resonant News 📰
#
# CLEANED MESSAGE:
# 7 Pakistani soldiers killed in 2 diff attacks by BLA
#
# After reducing intensity of attacks in November, Baloch group BLA hits Pakistani forces again.
#
# Loc: Panjgur and Mastung (map)
#
# @ResonantNews
#
# Using your incident classification and location extraction rules,
# return a JSON object with two keys: "category" and "location_text".
#
# Remember:
# - "category" is a short incident type label.
# - "location_text" is the most specific geocodable place, or "" if none.
#
# Output ONLY the JSON object.
# Agent4_CategoryLocation > ```json
# {
#   "category": "attack",
#   "location_text": "Panjgur, Mastung"
# }
# ```
#
#  ### Continue session: debug_session_id
#
# User > You are given a CLEANED OSINT incident message and some optional context.
#
# CONTEXT:
# Date: 2025-11-27T19:48:09
# Channel: Resonant News 📰
#
# CLEANED MESSAGE:
# WARNING WARNING WARNINGSaudi authorities crack a whip on Pakistani drug network in Medinah
#
# Few Pakistani men involved in ice (meth) trade arrested in a massive op by Saudi authorities. 👇👇👇
#
# https://youtube.com/shorts/RYnioaOBQr0?si=MYs1L8Kab9stk2cV
#
# Using your incident classification and location extraction rules,
# return a JSON object with two keys: "category" and "location_text".
#
# Remember:
# - "category" is a short incident type label.
# - "location_text" is the most specific geocodable place, or "" if none.
#
# Output ONLY the JSON object.
# Agent4_CategoryLocation > ```json
# {
#   "category": "smuggling",
#   "location_text": "Medinah, Saudi Arabia"
# }
# ```
#
#  ### Continue session: debug_session_id
#
# User > You are given a CLEANED OSINT incident message and some optional context.
#
# CONTEXT:
# Date: 2025-11-27T19:09:43
# Channel: Resonant News 📰
#
# CLEANED MESSAGE:
# Kulgam Police Launch Major Raids on Banned JeI Network
#
# Kulgam Police executed swift, coordinated raids across the district targeting the banned Jamaat-e-Islami (JeI), recovering electronic gadgets and incriminating documents.
#
# This operation underscores ongoing efforts to dismantle terror-linked networks in Jammu & Kashmir.
#
# No arrests reported yet, but investigations continue.
#
# #KulgamRaids #JeI #JammuKashmirSecurity #IndiaSecurity
#
# Join Kashmir conflict stories
#
# Using your incident classification and location extraction rules,
# return a JSON object with two keys: "category" and "location_text".
#
# Remember:
# - "category" is a short incident type label.
# - "location_text" is the most specific geocodable place, or "" if none.
#
# Output ONLY the JSON object.
# Agent4_CategoryLocation > ```json
# {
#   "category": "raid_search",
#   "location_text": "Kulgam"
# }
# ```
#
#  ### Continue session: debug_session_id
#
# User > You are given a CLEANED OSINT incident message and some optional context.
#
# CONTEXT:
# Date: 2025-11-27T14:33:14
# Channel: Resonant News 📰
#
# CLEANED MESSAGE:
# BREAKING: BLAZE DEVASTATES OVER 1,500 KORAIL SHANTIES, FAMILIES FLEE DHAKA SETTLEMENT OVERNIGHT
#
# A massive fire ripped through Dhaka’s crowded Korail slum, destroying more than 1,500 makeshift homes and leaving thousands of people with nowhere to sleep but the open streets.
#
# Rescue workers scrambled to assist and government officials are assessing damage as one of the worst urban blazes in years exposes harsh realities for Bangladesh’s poorest residents.
#
# #DhakaFire #Bangladesh #SlumFire #Korail #Disaster #UrbanPoverty #BreakingNews
#
# 📍 @ResonantNews
#
# Using your incident classification and location extraction rules,
# return a JSON object with two keys: "category" and "location_text".
#
# Remember:
# - "category" is a short incident type label.
# - "location_text" is the most specific geocodable place, or "" if none.
#
# Output ONLY the JSON object.
# Agent4_CategoryLocation > ```json
# {
#   "category": "disaster",
#   "location_text": "Korail slum, Dhaka, Bangladesh"
# }
# ```
#
#  ### Continue session: debug_session_id
#
# User > You are given a CLEANED OSINT incident message and some optional context.
#
# CONTEXT:
# Date: 2025-11-27T13:30:44
# Channel: Resonant News 📰
#
# CLEANED MESSAGE:
# BREAKING: DC ATTACK SUSPECT ENTERED US AS A MIGRANT IN 2021, FBI PROBES TERROR ANGLE
#
# Authorities identified 29-year-old Rahmanullah Lakanwal, an Afghan national, as the gunman who shot two National Guard soldiers near the White House.
#
# The FBI and local security agencies have launched terrorism investigations, while the US government reviews Afghan migration records amid fresh security concerns.
#
# #DCshooting #NationalGuard #AfghanSuspect #Security #Breaking #USA
#
# 📍 @ResonantNews
#
# Using your incident classification and location extraction rules,
# return a JSON object with two keys: "category" and "location_text".
#
# Remember:
# - "category" is a short incident type label.
# - "location_text" is the most specific geocodable place, or "" if none.
#
# Output ONLY the JSON object.
# Agent4_CategoryLocation > ```json
# {
#   "category": "attack",
#   "location_text": "DC"
# }
# ```
#
#  ### Continue session: debug_session_id
#
# User > You are given a CLEANED OSINT incident message and some optional context.
#
# CONTEXT:
# Date: 2025-11-27T12:15:02
# Channel: Resonant News 📰
#
# CLEANED MESSAGE:
# Death toll in Hong Kong fire rises to 44 with 279 still missing
#
# At least 44 people have been killed in a major fire engulfing public housing apartments in Hong Kong's Tai Po district - more than 270 people are still not accounted for
#
# Three construction company executives have been arrested on suspicion of manslaughter connected to flammable materials that may have allowed the fire to spread quickly
#
# After 18 hours, officials said the fire was under control - it has been classified a level five blaze, the most serious level in Hong Kong
#
# @ResonantNews
#
# Using your incident classification and location extraction rules,
# return a JSON object with two keys: "category" and "location_text".
#
# Remember:
# - "category" is a short incident type label.
# - "location_text" is the most specific geocodable place, or "" if none.
#
# Output ONLY the JSON object.
# Agent4_CategoryLocation > ```json
# {
#   "category": "disaster",
#   "location_text": "Tai Po district, Hong Kong"
# }
# ```
# [CatLoc] Processed batch of 16 rows (total=48).
# [CatLoc] Done. Total rows updated with category/location_text: 48
# [CatLoc] Completed.

# %%
pd.read_sql_query(
    "SELECT category, location_text, COUNT(*) AS n "
    "FROM events WHERE checked = 1 AND processed = 1 "
    "GROUP BY category, location_text ORDER BY n DESC;",
    conn
)
# Out:
#             category                                    location_text  n
# 0           disaster                                        Hong Kong  3
# 1             attack                                                   2
# 2             attack                                               DC  2
# 3             attack                                            Syria  2
# 4       drone_strike                                       Tajikistan  2
# 5   arrest_detention                                Barmer, Rajasthan  1
# 6   arrest_detention                                  Bathindi, Jammu  1
# 7   arrest_detention                                     Nuh, Haryana  1
# 8             attack                Baalade Valley, Puntland, Somalia  1
# 9             attack                                            Bannu  1
# 10            attack                        Bannu, Khyber Pakhtunkhwa  1
# 11            attack                 Beit Jinn, rural Damascus, Syria  1
# 12            attack                           Domail Ahmadzai, Bannu  1
# 13            attack                                          Kashmir  1
# 14            attack                                          Panjgur  1
# 15            attack                                 Panjgur, Mastung  1
# 16            attack           Peshawar, Khyber Pakhtunkhwa, Pakistan  1
# 17            attack      Saibol, Tengnoupal district, Manipur, India  1
# 18            attack              Tengnoupal district, Manipur, India  1
# 19            attack                              Tengnoupal, Manipur  1
# 20            attack                        University Town, Pakistan  1
# 21            attack                                   Washington, DC  1
# 22            attack                                      White House  1
# 23    casualty_death                               Khyber Pakhtunkhwa  1
# 24    casualty_death                                    Mohabbat Khel  1
# 25          disaster                   Korail slum, Dhaka, Bangladesh  1
# 26          disaster                                        Sri Lanka  1
# 27          disaster                       Tai Po district, Hong Kong  1
# 28          disaster                                  southwest China  1
# 29      drone_strike      Bannu district, Khyber Pakhtunkhwa province  1
# 30      drone_strike  Jabar Mela, Khyber District, Khyber Pakhtunkhwa  1
# 31         explosion                              Chaibasa, Jharkhand  1
# 32         explosion                           Wana, South Waziristan  1
# 33        kidnapping                                          Nigeria  1
# 34          movement                                    Guinea-Bissau  1
# 35          movement                     Khyber Pakhtunkhwa, Pakistan  1
# 36       raid_search                             Basantgarh, Udhampur  1
# 37       raid_search                                           Kulgam  1
# 38          shelling                  Janikhel, Baka Khel subdivision  1
# 39         smuggling                                                   1
# 40         smuggling                            Medinah, Saudi Arabia  1
# 41   weapons_seizure                     Naner Midoora, Tral, Kashmir  1

# %% [markdown]
# ---
#
# # 📌 Agent 5 — LLM-Guided Geocoder
# ### *Converting ambiguous or partial locations into precise coordinates*
#
# Traditional geocoding APIs struggle with:
#
# - incomplete place names
# - ambiguous regional references
# - informal OSINT phrasing
#
# Agent 5 solves this using a hybrid approach:
#
# 1. **LLM-based reasoning** → interprets the location context, generates a refined, geocodable phrase
# 2. **Deterministic Google Maps lookup** → returns exact lat/lon
# 3. **Fallback handling** → marks ungeocodable events safely
#
# This results in **far more accurate geocoding**, especially for conflict-zone OSINT.
#
# Below is the implementation of Agent 5.

# %%
"""
Agent 5 — Geocoder (Google Maps + LlmAgent variants)

Role in pipeline:
- Input: rows in `events` table where:
    checked = 1         (incident-like)
    processed = 1       (canonical after dedup, NOT duplicate)
    location_text != '' (has some location from Agent 4)
    lat/lon are NULL    (not geocoded yet)

- For each such row:
    1) Use a small LlmAgent to generate 1–3 refined query variants
       for the location_text (e.g. add country, normalize, pick a
       more precise sub-region for broad phrases).
    2) Try Google Maps geocoding on those variants (with caching).
    3) On success → fill lat, lon.
       On total failure → set processed = -2 (ungood_geo).
"""

import sqlite3
from typing import Optional, Tuple, List, Dict

import time
import os
from dotenv import load_dotenv

import googlemaps

import json
import asyncio

from google.adk.agents import LlmAgent
from google.adk.models import Gemini
from google.adk.runners import InMemoryRunner
from google.genai import types

# ----------------- CONFIG -----------------

DB_PATH = "incidents.db"   
BATCH_SIZE = 32            # number of rows to geocode per batch
GEOCODE_SLEEP = 0.1        # small delay between API calls

load_dotenv()
GOOGLE_MAPS_API_KEY = os.getenv("GOOGLE_MAPS_API_KEY")
GOOGLE_API_KEY = os.getenv("GOOGLE_API_KEY")

if not GOOGLE_MAPS_API_KEY:
    raise RuntimeError("GOOGLE_MAPS_API_KEY is not set in environment / .env file.")
if not GOOGLE_API_KEY:
    raise RuntimeError("GOOGLE_API_KEY is not set in environment / .env file.")

# Google Maps client (deterministic)
gmaps = googlemaps.Client(key=GOOGLE_MAPS_API_KEY)

# Cache: query_string -> (lat, lon, formatted_address or None, status_str)
# status_str is "ok" or "fail"
GEOCODE_CACHE: Dict[str, Tuple[Optional[float], Optional[float], Optional[str], str]] = {}

retry_config = types.HttpRetryOptions(
    attempts=5,
    exp_base=7,
    initial_delay=1,
    http_status_codes=[429, 500, 503, 504],
)

# ----------------- LLM VARIANT GENERATOR (AGENT) -----------------

VARIANT_SYSTEM_INSTRUCTIONS = """
You are a location query refinement assistant for a geocoding service.

Your job:
- Take a single input location_text from an OSINT pipeline.
- Return a small list (1 to 3) of query strings that are suitable for geocoding.

Key distinction: BROAD REGION vs SPECIFIC PLACE
------------------------------------------------
1) SPECIFIC PLACE:
   - Examples (conceptually): named town, city, village, neighbourhood, checkpoint,
     base, bridge, road segment, or a clearly identified district name.
   - When the input is specific, you MUST preserve that specificity.
   - You may:
       - Normalize punctuation and spacing.
       - Expand abbreviations (& -> "and").
       - Add the country or state that is clearly implied by context.
   - You MUST NOT:
       - Drop or replace specific locality names with a broader area.
       - Replace a village/town/area with only its district, province, or country.
       - Generalize "X town in Y district" to just "Y district" or "Y country".

2) BROAD REGION:
   - Examples in structure (NOT specific names): phrases like "southwestern part of <country>",
     "northern region of <country>", or generic macro-regions without a single clear locality.
   - When the input is a broad region phrase:
       - You may choose a SINGLE best-guess sub-region (such as a state or province)
         that lies inside that broad region, based on your world knowledge and textual hints.
       - You may also include the original broad phrase as a fallback variant.
       - Do NOT invent an arbitrary city that is not clearly suggested by the phrase.
       - Your refined sub-region should still be realistic and geographically consistent
         with the described broad area.

General rules:
- All variants must refer to the SAME underlying general area described by the input.
- You may go from BROAD → more specific (e.g., macro-region to one constituent state/province).
- You must NOT go from SPECIFIC → broader.
- Never switch to a completely different region or country.
- Avoid purely generalized queries that lose important locality detail.

Output format (STRICT):
Return a SINGLE JSON object:
{
  "variants": ["<string1>", "<string2>", ...]
}

- The "variants" array must have between 1 and 3 strings.
- Do NOT include explanations or any other fields.
""".strip()


def create_variant_agent() -> LlmAgent:
    """
    Create the LlmAgent used only to refine location_text into
    a small list of geocoding query variants.
    """
    agent = LlmAgent(
        name="Agent5_LocationVariantGenerator",
        model=Gemini(
            model="gemini-2.5-flash-lite",
            api_key=GOOGLE_API_KEY,
            retry_options=retry_config,
        ),
        description="Generates refined geocoding query variants for a location_text.",
        instruction=VARIANT_SYSTEM_INSTRUCTIONS,
        tools=[],  # no tools needed
    )
    return agent


class VariantLLM:
    """
    Wrapper around InMemoryRunner for the variant generator agent.

    async get_variants(location_text: str) -> List[str]
    """

    def __init__(self, runner: InMemoryRunner):
        self.runner = runner

    async def get_variants(self, location_text: str) -> List[str]:
        """
        Ask the LLM for up to 3 refined variants.

        Fallback: if anything goes wrong, return [location_text.strip()].
        """
        loc = (location_text or "").strip()
        if not loc:
            return []

        user_prompt = f"""
Given the following location_text from an OSINT message:

"{loc}"

Return a JSON object of the form:
{{
  "variants": ["<string1>", "<string2>", ...]
}}

Follow your system instructions carefully:
- Distinguish between BROAD REGION and SPECIFIC PLACE.
- Preserve specificity when the place is already concrete.
- Only choose a more specific sub-region when the phrase is inherently broad.
Output ONLY the JSON.
""".strip()

        events = await self.runner.run_debug(user_prompt)

        # Find last assistant message with text
        assistant_event = None
        for e in reversed(events):
            if getattr(e, "author", "") == "user":
                continue
            if getattr(e, "content", None) is None:
                continue
            assistant_event = e
            break

        if assistant_event is None:
            return [loc]

        parts = getattr(assistant_event.content, "parts", [])
        texts: List[str] = []
        for p in parts:
            if hasattr(p, "text") and p.text:
                texts.append(p.text)

        raw_text = "\n".join(texts).strip()

        # Handle ```json ... ``` wrappers
        cleaned = raw_text
        if cleaned.startswith("```"):
            lines = cleaned.splitlines()
            # drop first line (``` or ```json)
            if lines:
                lines = lines[1:]
            # drop last ``` if present
            if lines and lines[-1].strip().startswith("```"):
                lines = lines[:-1]
            cleaned = "\n".join(lines).strip()

        variants: List[str] = [loc]
        try:
            obj = json.loads(cleaned)
            if isinstance(obj, dict) and "variants" in obj:
                arr = obj["variants"]
                if isinstance(arr, list):
                    extracted = []
                    for v in arr:
                        if isinstance(v, str) and v.strip():
                            extracted.append(v.strip())
                    if extracted:
                        variants = extracted
        except Exception as e:
            print(f"[VariantLLM] JSON parse error for '{loc}': {e}")

        # Remove duplicates, keep at most 3
        seen = set()
        uniq: List[str] = []
        for v in variants:
            if v not in seen:
                seen.add(v)
                uniq.append(v)
        if not uniq:
            uniq = [loc]

        return uniq[:3]


# ----------------- DB HELPERS -----------------

def get_connection(db_path: str = DB_PATH) -> sqlite3.Connection:
    """Return a sqlite3 connection to the incidents.db file."""
    return sqlite3.connect(db_path)


def fetch_rows_for_geocoding(
    conn: sqlite3.Connection,
    limit: int = BATCH_SIZE
) -> List[Tuple[int, str]]:
    """
    Fetch a batch of canonical incidents that need geocoding.

    Conditions:
    - checked = 1
    - processed = 1
    - location_text not NULL/empty
    - lat IS NULL OR lon IS NULL

    Returns:
        list of (id, location_text)
    """
    cur = conn.cursor()
    cur.execute(
        """
        SELECT id, location_text
        FROM events
        WHERE checked = 1
          AND processed = 1
          AND location_text IS NOT NULL
          AND TRIM(location_text) <> ''
          AND (lat IS NULL OR lon IS NULL)
        ORDER BY id
        LIMIT ?
        """,
        (limit,)
    )
    return cur.fetchall()


def update_geocode_success(
    conn: sqlite3.Connection,
    row_id: int,
    lat: float,
    lon: float
) -> None:
    """Update lat/lon for a successfully geocoded row."""
    cur = conn.cursor()
    cur.execute(
        """
        UPDATE events
        SET lat = ?, lon = ?
        WHERE id = ?
        """,
        (lat, lon, row_id)
    )


def update_geocode_failure(
    conn: sqlite3.Connection,
    row_id: int
) -> None:
    """
    Mark a row as ungeocodable.

    We do NOT change `checked`, but we set processed = -2 so that
    mapping and analysis can filter these out.
    """
    cur = conn.cursor()
    cur.execute(
        """
        UPDATE events
        SET processed = -2
        WHERE id = ?
        """,
        (row_id,)
    )


# ----------------- GEOCODING HELPERS -----------------

def geocode_once(query: str) -> Tuple[Optional[float], Optional[float], Optional[str]]:
    """
    Call Google Maps geocoding once for a given query string.

    Returns:
        (lat, lon, formatted_address) or (None, None, None) if no result.
    """
    try:
        results = gmaps.geocode(query)
    except Exception as e:
        print(f"[Geocode] Error for '{query}': {e}")
        return None, None, None

    if not results:
        return None, None, None

    loc = results[0].get("geometry", {}).get("location", {})
    lat = loc.get("lat")
    lon = loc.get("lng")
    formatted_address = results[0].get("formatted_address")

    if lat is None or lon is None:
        return None, None, None

    return float(lat), float(lon), formatted_address


def geocode_with_variants(variants: List[str]) -> Tuple[Optional[float], Optional[float], Optional[str], str]:
    """
    Try geocoding each variant in order, using cache.

    Returns:
        (lat, lon, formatted_address, status)  where status is "ok" or "fail".
    """
    lat = lon = None
    formatted = None

    for variant in variants:
        v = variant.strip()
        if not v:
            continue

        # Check cache first
        if v in GEOCODE_CACHE:
            lat, lon, formatted, status = GEOCODE_CACHE[v]
            if status == "ok" and lat is not None and lon is not None:
                print(f"[Geocode] (cached) '{v}' -> ({lat:.4f}, {lon:.4f})")
                return lat, lon, formatted, status
            else:
                # Cached failure → don't retry
                continue

        # Small delay
        time.sleep(GEOCODE_SLEEP)

        lat, lon, formatted = geocode_once(v)
        if lat is not None and lon is not None:
            print(f"[Geocode] '{v}' -> ({lat:.4f}, {lon:.4f})")
            status = "ok"
            GEOCODE_CACHE[v] = (lat, lon, formatted, status)
            return lat, lon, formatted, status
        else:
            print(f"[Geocode] No result for '{v}'")
            GEOCODE_CACHE[v] = (None, None, None, "fail")

    print(f"[Geocode] FAILED for variants: {variants}")
    return None, None, None, "fail"


# ----------------- BATCH GEOCODING (ASYNC) -----------------

async def geocode_batch_async(
    variant_llm: VariantLLM,
    db_path: str = DB_PATH,
    batch_size: int = BATCH_SIZE
) -> int:
    """
    Process a single batch of events that need geocoding.

    Returns:
        Number of rows processed in this batch.
    """
    conn = get_connection(db_path)
    try:
        rows = fetch_rows_for_geocoding(conn, limit=batch_size)
        if not rows:
            return 0

        for row_id, location_text in rows:
            loc = (location_text or "").strip()
            if not loc:
                update_geocode_failure(conn, row_id)
                continue

            # 1) Get LLM-generated variants (broad→specific or specific→normalized)
            try:
                variants = await variant_llm.get_variants(loc)
            except Exception as e:
                print(f"[Agent5] Variant LLM error for id={row_id}, loc='{loc}': {e}")
                variants = [loc]

            if not variants:
                variants = [loc]

            # 2) Geocode using those variants
            lat, lon, formatted, status = geocode_with_variants(variants)

            if status == "ok" and lat is not None and lon is not None:
                update_geocode_success(conn, row_id, lat, lon)
            else:
                update_geocode_failure(conn, row_id)

        conn.commit()
        return len(rows)

    finally:
        conn.close()


async def geocode_until_done_async(
    variant_llm: VariantLLM,
    db_path: str = DB_PATH,
    batch_size: int = BATCH_SIZE
) -> None:
    """
    Keep running geocoding batches until there are no more rows
    needing geocoding.
    """
    total = 0
    while True:
        processed = await geocode_batch_async(
            variant_llm=variant_llm,
            db_path=db_path,
            batch_size=batch_size,
        )
        if processed == 0:
            break
        total += processed
        print(f"[Agent5] Processed batch of {processed} rows (total={total}).")

    print(f"[Agent5] Done. Total rows geocoded or marked as ungeocodable: {total}")


# ----------------- NOTEBOOK ENTRYPOINT -----------------

async def run_agent5_geocoder():

    variant_agent = create_variant_agent()
    print("[Agent5] Variant LlmAgent created.")

    runner = InMemoryRunner(agent=variant_agent)
    print("[Agent5] Runner created.")

    variant_llm = VariantLLM(runner=runner)
    await geocode_until_done_async(
        variant_llm=variant_llm,
        db_path=DB_PATH,
        batch_size=BATCH_SIZE
    )

    print("[Agent5] Geocoding pipeline completed.")

# %%
await run_agent5_geocoder()
# Out:
# App name mismatch detected. The runner is configured with app name "InMemoryRunner", but the root agent was loaded from "C:\Users\Lenovo\Desktop\AgentAICourse\agentai_venv\Lib\site-packages\google\adk\agents", which implies app name "agents".
# [Agent5] Variant LlmAgent created.
# [Agent5] Runner created.
#
#  ### Created new session: debug_session_id
#
# User > Given the following location_text from an OSINT message:
#
# "Bannu"
#
# Return a JSON object of the form:
# {
#   "variants": ["<string1>", "<string2>", ...]
# }
#
# Follow your system instructions carefully:
# - Distinguish between BROAD REGION and SPECIFIC PLACE.
# - Preserve specificity when the place is already concrete.
# - Only choose a more specific sub-region when the phrase is inherently broad.
# Output ONLY the JSON.
# Agent5_LocationVariantGenerator > ```json
# {
#   "variants": [
#     "Bannu, Khyber Pakhtunkhwa, Pakistan",
#     "Bannu District, Pakistan"
#   ]
# }
# ```
# [Geocode] 'Bannu, Khyber Pakhtunkhwa, Pakistan' -> (32.9910, 70.6455)
#
#  ### Continue session: debug_session_id
#
# User > Given the following location_text from an OSINT message:
#
# "Peshawar, Khyber Pakhtunkhwa, Pakistan"
#
# Return a JSON object of the form:
# {
#   "variants": ["<string1>", "<string2>", ...]
# }
#
# Follow your system instructions carefully:
# - Distinguish between BROAD REGION and SPECIFIC PLACE.
# - Preserve specificity when the place is already concrete.
# - Only choose a more specific sub-region when the phrase is inherently broad.
# Output ONLY the JSON.
# Agent5_LocationVariantGenerator > ```json
# {
#   "variants": [
#     "Peshawar, Khyber Pakhtunkhwa, Pakistan"
#   ]
# }
# ```
# [Geocode] 'Peshawar, Khyber Pakhtunkhwa, Pakistan' -> (34.0083, 71.5189)
#
#  ### Continue session: debug_session_id
#
# User > Given the following location_text from an OSINT message:
#
# "Khyber Pakhtunkhwa, Pakistan"
#
# Return a JSON object of the form:
# {
#   "variants": ["<string1>", "<string2>", ...]
# }
#
# Follow your system instructions carefully:
# - Distinguish between BROAD REGION and SPECIFIC PLACE.
# - Preserve specificity when the place is already concrete.
# - Only choose a more specific sub-region when the phrase is inherently broad.
# Output ONLY the JSON.
# Agent5_LocationVariantGenerator > ```json
# {
#   "variants": [
#     "Khyber Pakhtunkhwa, Pakistan"
#   ]
# }
# ```
# [Geocode] 'Khyber Pakhtunkhwa, Pakistan' -> (34.1515, 71.5724)
#
#  ### Continue session: debug_session_id
#
# User > Given the following location_text from an OSINT message:
#
# "Bannu, Khyber Pakhtunkhwa"
#
# Return a JSON object of the form:
# {
#   "variants": ["<string1>", "<string2>", ...]
# }
#
# Follow your system instructions carefully:
# - Distinguish between BROAD REGION and SPECIFIC PLACE.
# - Preserve specificity when the place is already concrete.
# - Only choose a more specific sub-region when the phrase is inherently broad.
# Output ONLY the JSON.
# Agent5_LocationVariantGenerator > ```json
# {
#   "variants": [
#     "Bannu, Khyber Pakhtunkhwa, Pakistan"
#   ]
# }
# ```
# [Geocode] (cached) 'Bannu, Khyber Pakhtunkhwa, Pakistan' -> (32.9910, 70.6455)
#
#  ### Continue session: debug_session_id
#
# User > Given the following location_text from an OSINT message:
#
# "Janikhel, Baka Khel subdivision"
#
# Return a JSON object of the form:
# {
#   "variants": ["<string1>", "<string2>", ...]
# }
#
# Follow your system instructions carefully:
# - Distinguish between BROAD REGION and SPECIFIC PLACE.
# - Preserve specificity when the place is already concrete.
# - Only choose a more specific sub-region when the phrase is inherently broad.
# Output ONLY the JSON.
# Agent5_LocationVariantGenerator > ```json
# {
#   "variants": [
#     "Janikhel, Baka Khel subdivision, Bannu District, Khyber Pakhtunkhwa, Pakistan",
#     "Janikhel, Baka Khel, Bannu, Pakistan"
#   ]
# }
# ```
# [Geocode] 'Janikhel, Baka Khel subdivision, Bannu District, Khyber Pakhtunkhwa, Pakistan' -> (32.9566, 70.5324)
#
#  ### Continue session: debug_session_id
#
# User > Given the following location_text from an OSINT message:
#
# "Panjgur"
#
# Return a JSON object of the form:
# {
#   "variants": ["<string1>", "<string2>", ...]
# }
#
# Follow your system instructions carefully:
# - Distinguish between BROAD REGION and SPECIFIC PLACE.
# - Preserve specificity when the place is already concrete.
# - Only choose a more specific sub-region when the phrase is inherently broad.
# Output ONLY the JSON.
# Agent5_LocationVariantGenerator > ```json
# {
#   "variants": [
#     "Panjgur, Balochistan, Pakistan",
#     "Panjgur District, Pakistan"
#   ]
# }
# ```
# [Geocode] 'Panjgur, Balochistan, Pakistan' -> (26.9706, 64.0887)
#
#  ### Continue session: debug_session_id
#
# User > Given the following location_text from an OSINT message:
#
# "Hong Kong"
#
# Return a JSON object of the form:
# {
#   "variants": ["<string1>", "<string2>", ...]
# }
#
# Follow your system instructions carefully:
# - Distinguish between BROAD REGION and SPECIFIC PLACE.
# - Preserve specificity when the place is already concrete.
# - Only choose a more specific sub-region when the phrase is inherently broad.
# Output ONLY the JSON.
# Agent5_LocationVariantGenerator > ```json
# {
#   "variants": [
#     "Hong Kong"
#   ]
# }
# ```
# [Geocode] 'Hong Kong' -> (22.3193, 114.1694)
#
#  ### Continue session: debug_session_id
#
# User > Given the following location_text from an OSINT message:
#
# "Tengnoupal district, Manipur, India"
#
# Return a JSON object of the form:
# {
#   "variants": ["<string1>", "<string2>", ...]
# }
#
# Follow your system instructions carefully:
# - Distinguish between BROAD REGION and SPECIFIC PLACE.
# - Preserve specificity when the place is already concrete.
# - Only choose a more specific sub-region when the phrase is inherently broad.
# Output ONLY the JSON.
# Agent5_LocationVariantGenerator > ```json
# {
#   "variants": [
#     "Tengnoupal district, Manipur, India"
#   ]
# }
# ```
# [Geocode] 'Tengnoupal district, Manipur, India' -> (24.4189, 94.1923)
#
#  ### Continue session: debug_session_id
#
# User > Given the following location_text from an OSINT message:
#
# "Basantgarh, Udhampur"
#
# Return a JSON object of the form:
# {
#   "variants": ["<string1>", "<string2>", ...]
# }
#
# Follow your system instructions carefully:
# - Distinguish between BROAD REGION and SPECIFIC PLACE.
# - Preserve specificity when the place is already concrete.
# - Only choose a more specific sub-region when the phrase is inherently broad.
# Output ONLY the JSON.
# Agent5_LocationVariantGenerator > ```json
# {
#   "variants": [
#     "Basantgarh, Udhampur district, Jammu and Kashmir, India"
#   ]
# }
# ```
# [Geocode] 'Basantgarh, Udhampur district, Jammu and Kashmir, India' -> (32.8102, 75.5488)
#
#  ### Continue session: debug_session_id
#
# User > Given the following location_text from an OSINT message:
#
# "Tengnoupal, Manipur"
#
# Return a JSON object of the form:
# {
#   "variants": ["<string1>", "<string2>", ...]
# }
#
# Follow your system instructions carefully:
# - Distinguish between BROAD REGION and SPECIFIC PLACE.
# - Preserve specificity when the place is already concrete.
# - Only choose a more specific sub-region when the phrase is inherently broad.
# Output ONLY the JSON.
# Agent5_LocationVariantGenerator > ```json
# {
#   "variants": [
#     "Tengnoupal, Manipur, India"
#   ]
# }
# ```
# [Geocode] 'Tengnoupal, Manipur, India' -> (24.3869, 94.1476)
#
#  ### Continue session: debug_session_id
#
# User > Given the following location_text from an OSINT message:
#
# "Bannu district, Khyber Pakhtunkhwa province"
#
# Return a JSON object of the form:
# {
#   "variants": ["<string1>", "<string2>", ...]
# }
#
# Follow your system instructions carefully:
# - Distinguish between BROAD REGION and SPECIFIC PLACE.
# - Preserve specificity when the place is already concrete.
# - Only choose a more specific sub-region when the phrase is inherently broad.
# Output ONLY the JSON.
# Agent5_LocationVariantGenerator > ```json
# {
#   "variants": [
#     "Bannu District, Khyber Pakhtunkhwa, Pakistan"
#   ]
# }
# ```
# [Geocode] 'Bannu District, Khyber Pakhtunkhwa, Pakistan' -> (32.9298, 70.6693)
#
#  ### Continue session: debug_session_id
#
# User > Given the following location_text from an OSINT message:
#
# "Barmer, Rajasthan"
#
# Return a JSON object of the form:
# {
#   "variants": ["<string1>", "<string2>", ...]
# }
#
# Follow your system instructions carefully:
# - Distinguish between BROAD REGION and SPECIFIC PLACE.
# - Preserve specificity when the place is already concrete.
# - Only choose a more specific sub-region when the phrase is inherently broad.
# Output ONLY the JSON.
# Agent5_LocationVariantGenerator > ```json
# {
#   "variants": [
#     "Barmer, Rajasthan, India"
#   ]
# }
# ```
# [Geocode] 'Barmer, Rajasthan, India' -> (25.7521, 71.3967)
#
#  ### Continue session: debug_session_id
#
# User > Given the following location_text from an OSINT message:
#
# "southwest China"
#
# Return a JSON object of the form:
# {
#   "variants": ["<string1>", "<string2>", ...]
# }
#
# Follow your system instructions carefully:
# - Distinguish between BROAD REGION and SPECIFIC PLACE.
# - Preserve specificity when the place is already concrete.
# - Only choose a more specific sub-region when the phrase is inherently broad.
# Output ONLY the JSON.
# Agent5_LocationVariantGenerator > ```json
# {
#   "variants": [
#     "Southwest China",
#     "Yunnan Province, China",
#     "Sichuan Province, China"
#   ]
# }
# ```
# [Geocode] 'Southwest China' -> (35.8617, 104.1954)
#
#  ### Continue session: debug_session_id
#
# User > Given the following location_text from an OSINT message:
#
# "Hong Kong"
#
# Return a JSON object of the form:
# {
#   "variants": ["<string1>", "<string2>", ...]
# }
#
# Follow your system instructions carefully:
# - Distinguish between BROAD REGION and SPECIFIC PLACE.
# - Preserve specificity when the place is already concrete.
# - Only choose a more specific sub-region when the phrase is inherently broad.
# Output ONLY the JSON.
# Agent5_LocationVariantGenerator > ```json
# {
#   "variants": [
#     "Hong Kong"
#   ]
# }
# ```
# [Geocode] (cached) 'Hong Kong' -> (22.3193, 114.1694)
#
#  ### Continue session: debug_session_id
#
# User > Given the following location_text from an OSINT message:
#
# "Chaibasa, Jharkhand"
#
# Return a JSON object of the form:
# {
#   "variants": ["<string1>", "<string2>", ...]
# }
#
# Follow your system instructions carefully:
# - Distinguish between BROAD REGION and SPECIFIC PLACE.
# - Preserve specificity when the place is already concrete.
# - Only choose a more specific sub-region when the phrase is inherently broad.
# Output ONLY the JSON.
# Agent5_LocationVariantGenerator > ```json
# {
#   "variants": [
#     "Chaibasa, Jharkhand, India"
#   ]
# }
# ```
# [Geocode] 'Chaibasa, Jharkhand, India' -> (22.5474, 85.8025)
#
#  ### Continue session: debug_session_id
#
# User > Given the following location_text from an OSINT message:
#
# "University Town, Pakistan"
#
# Return a JSON object of the form:
# {
#   "variants": ["<string1>", "<string2>", ...]
# }
#
# Follow your system instructions carefully:
# - Distinguish between BROAD REGION and SPECIFIC PLACE.
# - Preserve specificity when the place is already concrete.
# - Only choose a more specific sub-region when the phrase is inherently broad.
# Output ONLY the JSON.
# Agent5_LocationVariantGenerator > ```json
# {
#   "variants": [
#     "University Town, Peshawar, Khyber Pakhtunkhwa, Pakistan"
#   ]
# }
# ```
# [Geocode] 'University Town, Peshawar, Khyber Pakhtunkhwa, Pakistan' -> (33.9922, 71.4982)
#
#  ### Continue session: debug_session_id
#
# User > Given the following location_text from an OSINT message:
#
# "Sri Lanka"
#
# Return a JSON object of the form:
# {
#   "variants": ["<string1>", "<string2>", ...]
# }
#
# Follow your system instructions carefully:
# - Distinguish between BROAD REGION and SPECIFIC PLACE.
# - Preserve specificity when the place is already concrete.
# - Only choose a more specific sub-region when the phrase is inherently broad.
# Output ONLY the JSON.
# Agent5_LocationVariantGenerator > ```json
# {
#   "variants": [
#     "Sri Lanka"
#   ]
# }
# ```
# [Geocode] 'Sri Lanka' -> (7.8731, 80.7718)
#
#  ### Continue session: debug_session_id
#
# User > Given the following location_text from an OSINT message:
#
# "Khyber Pakhtunkhwa"
#
# Return a JSON object of the form:
# {
#   "variants": ["<string1>", "<string2>", ...]
# }
#
# Follow your system instructions carefully:
# - Distinguish between BROAD REGION and SPECIFIC PLACE.
# - Preserve specificity when the place is already concrete.
# - Only choose a more specific sub-region when the phrase is inherently broad.
# Output ONLY the JSON.
# Agent5_LocationVariantGenerator > ```json
# {
#   "variants": [
#     "Khyber Pakhtunkhwa, Pakistan"
#   ]
# }
# ```
# [Geocode] (cached) 'Khyber Pakhtunkhwa, Pakistan' -> (34.1515, 71.5724)
#
#  ### Continue session: debug_session_id
#
# User > Given the following location_text from an OSINT message:
#
# "Beit Jinn, rural Damascus, Syria"
#
# Return a JSON object of the form:
# {
#   "variants": ["<string1>", "<string2>", ...]
# }
#
# Follow your system instructions carefully:
# - Distinguish between BROAD REGION and SPECIFIC PLACE.
# - Preserve specificity when the place is already concrete.
# - Only choose a more specific sub-region when the phrase is inherently broad.
# Output ONLY the JSON.
# Agent5_LocationVariantGenerator > ```json
# {
#   "variants": [
#     "Beit Jinn, Rural Damascus Governorate, Syria"
#   ]
# }
# ```
# [Geocode] 'Beit Jinn, Rural Damascus Governorate, Syria' -> (33.3101, 35.9182)
#
#  ### Continue session: debug_session_id
#
# User > Given the following location_text from an OSINT message:
#
# "Domail Ahmadzai, Bannu"
#
# Return a JSON object of the form:
# {
#   "variants": ["<string1>", "<string2>", ...]
# }
#
# Follow your system instructions carefully:
# - Distinguish between BROAD REGION and SPECIFIC PLACE.
# - Preserve specificity when the place is already concrete.
# - Only choose a more specific sub-region when the phrase is inherently broad.
# Output ONLY the JSON.
# Agent5_LocationVariantGenerator > ```json
# {
#   "variants": [
#     "Domail Ahmadzai, Bannu, Khyber Pakhtunkhwa, Pakistan"
#   ]
# }
# ```
# [Geocode] 'Domail Ahmadzai, Bannu, Khyber Pakhtunkhwa, Pakistan' -> (33.0216, 70.7528)
#
#  ### Continue session: debug_session_id
#
# User > Given the following location_text from an OSINT message:
#
# "Tajikistan"
#
# Return a JSON object of the form:
# {
#   "variants": ["<string1>", "<string2>", ...]
# }
#
# Follow your system instructions carefully:
# - Distinguish between BROAD REGION and SPECIFIC PLACE.
# - Preserve specificity when the place is already concrete.
# - Only choose a more specific sub-region when the phrase is inherently broad.
# Output ONLY the JSON.
# Agent5_LocationVariantGenerator > ```json
# {
#   "variants": [
#     "Tajikistan"
#   ]
# }
# ```
# [Geocode] 'Tajikistan' -> (38.8610, 71.2761)
#
#  ### Continue session: debug_session_id
#
# User > Given the following location_text from an OSINT message:
#
# "Mohabbat Khel"
#
# Return a JSON object of the form:
# {
#   "variants": ["<string1>", "<string2>", ...]
# }
#
# Follow your system instructions carefully:
# - Distinguish between BROAD REGION and SPECIFIC PLACE.
# - Preserve specificity when the place is already concrete.
# - Only choose a more specific sub-region when the phrase is inherently broad.
# Output ONLY the JSON.
# Agent5_LocationVariantGenerator > ```json
# {
#   "variants": [
#     "Mohabbat Khel, Bannu District, Khyber Pakhtunkhwa, Pakistan"
#   ]
# }
# ```
# [Geocode] 'Mohabbat Khel, Bannu District, Khyber Pakhtunkhwa, Pakistan' -> (32.9298, 70.6693)
#
#  ### Continue session: debug_session_id
#
# User > Given the following location_text from an OSINT message:
#
# "Wana, South Waziristan"
#
# Return a JSON object of the form:
# {
#   "variants": ["<string1>", "<string2>", ...]
# }
#
# Follow your system instructions carefully:
# - Distinguish between BROAD REGION and SPECIFIC PLACE.
# - Preserve specificity when the place is already concrete.
# - Only choose a more specific sub-region when the phrase is inherently broad.
# Output ONLY the JSON.
# Agent5_LocationVariantGenerator > ```json
# {
#   "variants": [
#     "Wana, South Waziristan District, Khyber Pakhtunkhwa, Pakistan"
#   ]
# }
# ```
# [Geocode] 'Wana, South Waziristan District, Khyber Pakhtunkhwa, Pakistan' -> (32.2982, 69.5976)
#
#  ### Continue session: debug_session_id
#
# User > Given the following location_text from an OSINT message:
#
# "Bathindi, Jammu"
#
# Return a JSON object of the form:
# {
#   "variants": ["<string1>", "<string2>", ...]
# }
#
# Follow your system instructions carefully:
# - Distinguish between BROAD REGION and SPECIFIC PLACE.
# - Preserve specificity when the place is already concrete.
# - Only choose a more specific sub-region when the phrase is inherently broad.
# Output ONLY the JSON.
# Agent5_LocationVariantGenerator > ```json
# {
#   "variants": [
#     "Bathindi, Jammu, Jammu and Kashmir, India"
#   ]
# }
# ```
# [Geocode] 'Bathindi, Jammu, Jammu and Kashmir, India' -> (32.7104, 74.9063)
#
#  ### Continue session: debug_session_id
#
# User > Given the following location_text from an OSINT message:
#
# "Baalade Valley, Puntland, Somalia"
#
# Return a JSON object of the form:
# {
#   "variants": ["<string1>", "<string2>", ...]
# }
#
# Follow your system instructions carefully:
# - Distinguish between BROAD REGION and SPECIFIC PLACE.
# - Preserve specificity when the place is already concrete.
# - Only choose a more specific sub-region when the phrase is inherently broad.
# Output ONLY the JSON.
# Agent5_LocationVariantGenerator > ```json
# {
#   "variants": [
#     "Baalade Valley, Puntland, Somalia"
#   ]
# }
# ```
# [Geocode] 'Baalade Valley, Puntland, Somalia' -> (8.9794, 49.6911)
#
#  ### Continue session: debug_session_id
#
# User > Given the following location_text from an OSINT message:
#
# "White House"
#
# Return a JSON object of the form:
# {
#   "variants": ["<string1>", "<string2>", ...]
# }
#
# Follow your system instructions carefully:
# - Distinguish between BROAD REGION and SPECIFIC PLACE.
# - Preserve specificity when the place is already concrete.
# - Only choose a more specific sub-region when the phrase is inherently broad.
# Output ONLY the JSON.
# Agent5_LocationVariantGenerator > ```json
# {
#   "variants": [
#     "The White House, Washington D.C., USA"
#   ]
# }
# ```
# [Geocode] 'The White House, Washington D.C., USA' -> (38.8977, -77.0365)
#
#  ### Continue session: debug_session_id
#
# User > Given the following location_text from an OSINT message:
#
# "Hong Kong"
#
# Return a JSON object of the form:
# {
#   "variants": ["<string1>", "<string2>", ...]
# }
#
# Follow your system instructions carefully:
# - Distinguish between BROAD REGION and SPECIFIC PLACE.
# - Preserve specificity when the place is already concrete.
# - Only choose a more specific sub-region when the phrase is inherently broad.
# Output ONLY the JSON.
# Agent5_LocationVariantGenerator > ```json
# {
#   "variants": [
#     "Hong Kong"
#   ]
# }
# ```
# [Geocode] (cached) 'Hong Kong' -> (22.3193, 114.1694)
#
#  ### Continue session: debug_session_id
#
# User > Given the following location_text from an OSINT message:
#
# "Jabar Mela, Khyber District, Khyber Pakhtunkhwa"
#
# Return a JSON object of the form:
# {
#   "variants": ["<string1>", "<string2>", ...]
# }
#
# Follow your system instructions carefully:
# - Distinguish between BROAD REGION and SPECIFIC PLACE.
# - Preserve specificity when the place is already concrete.
# - Only choose a more specific sub-region when the phrase is inherently broad.
# Output ONLY the JSON.
# Agent5_LocationVariantGenerator > ```json
# {
#   "variants": [
#     "Jabar Mela, Khyber District, Khyber Pakhtunkhwa, Pakistan"
#   ]
# }
# ```
# [Geocode] 'Jabar Mela, Khyber District, Khyber Pakhtunkhwa, Pakistan' -> (34.1054, 71.1552)
#
#  ### Continue session: debug_session_id
#
# User > Given the following location_text from an OSINT message:
#
# "Washington, DC"
#
# Return a JSON object of the form:
# {
#   "variants": ["<string1>", "<string2>", ...]
# }
#
# Follow your system instructions carefully:
# - Distinguish between BROAD REGION and SPECIFIC PLACE.
# - Preserve specificity when the place is already concrete.
# - Only choose a more specific sub-region when the phrase is inherently broad.
# Output ONLY the JSON.
# Agent5_LocationVariantGenerator > ```json
# {
#   "variants": [
#     "Washington, D.C., USA"
#   ]
# }
# ```
# [Geocode] 'Washington, D.C., USA' -> (38.9072, -77.0369)
#
#  ### Continue session: debug_session_id
#
# User > Given the following location_text from an OSINT message:
#
# "Nigeria"
#
# Return a JSON object of the form:
# {
#   "variants": ["<string1>", "<string2>", ...]
# }
#
# Follow your system instructions carefully:
# - Distinguish between BROAD REGION and SPECIFIC PLACE.
# - Preserve specificity when the place is already concrete.
# - Only choose a more specific sub-region when the phrase is inherently broad.
# Output ONLY the JSON.
# Agent5_LocationVariantGenerator > ```json
# {
#   "variants": [
#     "Nigeria"
#   ]
# }
# ```
# [Geocode] 'Nigeria' -> (9.0820, 8.6753)
#
#  ### Continue session: debug_session_id
#
# User > Given the following location_text from an OSINT message:
#
# "Nuh, Haryana"
#
# Return a JSON object of the form:
# {
#   "variants": ["<string1>", "<string2>", ...]
# }
#
# Follow your system instructions carefully:
# - Distinguish between BROAD REGION and SPECIFIC PLACE.
# - Preserve specificity when the place is already concrete.
# - Only choose a more specific sub-region when the phrase is inherently broad.
# Output ONLY the JSON.
# Agent5_LocationVariantGenerator > ```json
# {
#   "variants": [
#     "Nuh, Haryana, India"
#   ]
# }
# ```
# [Geocode] 'Nuh, Haryana, India' -> (28.1024, 76.9931)
#
#  ### Continue session: debug_session_id
#
# User > Given the following location_text from an OSINT message:
#
# "Kashmir"
#
# Return a JSON object of the form:
# {
#   "variants": ["<string1>", "<string2>", ...]
# }
#
# Follow your system instructions carefully:
# - Distinguish between BROAD REGION and SPECIFIC PLACE.
# - Preserve specificity when the place is already concrete.
# - Only choose a more specific sub-region when the phrase is inherently broad.
# Output ONLY the JSON.
# Agent5_LocationVariantGenerator > ```json
# {
#   "variants": [
#     "Kashmir Valley, Jammu and Kashmir, India",
#     "Azad Kashmir, Pakistan"
#   ]
# }
# ```
# [Geocode] 'Kashmir Valley, Jammu and Kashmir, India' -> (33.2778, 75.3412)
# [Agent5] Processed batch of 32 rows (total=32).
#
#  ### Continue session: debug_session_id
#
# User > Given the following location_text from an OSINT message:
#
# "Saibol, Tengnoupal district, Manipur, India"
#
# Return a JSON object of the form:
# {
#   "variants": ["<string1>", "<string2>", ...]
# }
#
# Follow your system instructions carefully:
# - Distinguish between BROAD REGION and SPECIFIC PLACE.
# - Preserve specificity when the place is already concrete.
# - Only choose a more specific sub-region when the phrase is inherently broad.
# Output ONLY the JSON.
# Agent5_LocationVariantGenerator > ```json
# {
#   "variants": [
#     "Saibol, Tengnoupal district, Manipur, India"
#   ]
# }
# ```
# [Geocode] 'Saibol, Tengnoupal district, Manipur, India' -> (24.4715, 94.3583)
#
#  ### Continue session: debug_session_id
#
# User > Given the following location_text from an OSINT message:
#
# "Naner Midoora, Tral, Kashmir"
#
# Return a JSON object of the form:
# {
#   "variants": ["<string1>", "<string2>", ...]
# }
#
# Follow your system instructions carefully:
# - Distinguish between BROAD REGION and SPECIFIC PLACE.
# - Preserve specificity when the place is already concrete.
# - Only choose a more specific sub-region when the phrase is inherently broad.
# Output ONLY the JSON.
# Agent5_LocationVariantGenerator > ```json
# {
#   "variants": [
#     "Naner Midoora, Tral, Pulwama district, Jammu and Kashmir, India"
#   ]
# }
# ```
# [Geocode] 'Naner Midoora, Tral, Pulwama district, Jammu and Kashmir, India' -> (33.9351, 75.0604)
#
#  ### Continue session: debug_session_id
#
# User > Given the following location_text from an OSINT message:
#
# "Tajikistan"
#
# Return a JSON object of the form:
# {
#   "variants": ["<string1>", "<string2>", ...]
# }
#
# Follow your system instructions carefully:
# - Distinguish between BROAD REGION and SPECIFIC PLACE.
# - Preserve specificity when the place is already concrete.
# - Only choose a more specific sub-region when the phrase is inherently broad.
# Output ONLY the JSON.
# Agent5_LocationVariantGenerator > ```json
# {
#   "variants": [
#     "Tajikistan"
#   ]
# }
# ```
# [Geocode] (cached) 'Tajikistan' -> (38.8610, 71.2761)
#
#  ### Continue session: debug_session_id
#
# User > Given the following location_text from an OSINT message:
#
# "DC"
#
# Return a JSON object of the form:
# {
#   "variants": ["<string1>", "<string2>", ...]
# }
#
# Follow your system instructions carefully:
# - Distinguish between BROAD REGION and SPECIFIC PLACE.
# - Preserve specificity when the place is already concrete.
# - Only choose a more specific sub-region when the phrase is inherently broad.
# Output ONLY the JSON.
# Agent5_LocationVariantGenerator > ```json
# {
#   "variants": [
#     "Washington D.C., USA"
#   ]
# }
# ```
# [Geocode] 'Washington D.C., USA' -> (38.9072, -77.0369)
#
#  ### Continue session: debug_session_id
#
# User > Given the following location_text from an OSINT message:
#
# "Syria"
#
# Return a JSON object of the form:
# {
#   "variants": ["<string1>", "<string2>", ...]
# }
#
# Follow your system instructions carefully:
# - Distinguish between BROAD REGION and SPECIFIC PLACE.
# - Preserve specificity when the place is already concrete.
# - Only choose a more specific sub-region when the phrase is inherently broad.
# Output ONLY the JSON.
# Agent5_LocationVariantGenerator > ```json
# {
#   "variants": [
#     "Syria"
#   ]
# }
# ```
# [Geocode] 'Syria' -> (34.8021, 38.9968)
#
#  ### Continue session: debug_session_id
#
# User > Given the following location_text from an OSINT message:
#
# "Guinea-Bissau"
#
# Return a JSON object of the form:
# {
#   "variants": ["<string1>", "<string2>", ...]
# }
#
# Follow your system instructions carefully:
# - Distinguish between BROAD REGION and SPECIFIC PLACE.
# - Preserve specificity when the place is already concrete.
# - Only choose a more specific sub-region when the phrase is inherently broad.
# Output ONLY the JSON.
# Agent5_LocationVariantGenerator > ```json
# {
#   "variants": [
#     "Guinea-Bissau"
#   ]
# }
# ```
# [Geocode] 'Guinea-Bissau' -> (11.8037, -15.1804)
#
#  ### Continue session: debug_session_id
#
# User > Given the following location_text from an OSINT message:
#
# "Syria"
#
# Return a JSON object of the form:
# {
#   "variants": ["<string1>", "<string2>", ...]
# }
#
# Follow your system instructions carefully:
# - Distinguish between BROAD REGION and SPECIFIC PLACE.
# - Preserve specificity when the place is already concrete.
# - Only choose a more specific sub-region when the phrase is inherently broad.
# Output ONLY the JSON.
# Agent5_LocationVariantGenerator > ```json
# {
#   "variants": [
#     "Syria"
#   ]
# }
# ```
# [Geocode] (cached) 'Syria' -> (34.8021, 38.9968)
#
#  ### Continue session: debug_session_id
#
# User > Given the following location_text from an OSINT message:
#
# "Panjgur, Mastung"
#
# Return a JSON object of the form:
# {
#   "variants": ["<string1>", "<string2>", ...]
# }
#
# Follow your system instructions carefully:
# - Distinguish between BROAD REGION and SPECIFIC PLACE.
# - Preserve specificity when the place is already concrete.
# - Only choose a more specific sub-region when the phrase is inherently broad.
# Output ONLY the JSON.
# Agent5_LocationVariantGenerator > ```json
# {
#   "variants": [
#     "Panjgur, Mastung District, Balochistan, Pakistan"
#   ]
# }
# ```
# [Geocode] 'Panjgur, Mastung District, Balochistan, Pakistan' -> (29.7952, 66.9035)
#
#  ### Continue session: debug_session_id
#
# User > Given the following location_text from an OSINT message:
#
# "Medinah, Saudi Arabia"
#
# Return a JSON object of the form:
# {
#   "variants": ["<string1>", "<string2>", ...]
# }
#
# Follow your system instructions carefully:
# - Distinguish between BROAD REGION and SPECIFIC PLACE.
# - Preserve specificity when the place is already concrete.
# - Only choose a more specific sub-region when the phrase is inherently broad.
# Output ONLY the JSON.
# Agent5_LocationVariantGenerator > ```json
# {
#   "variants": [
#     "Medina, Saudi Arabia"
#   ]
# }
# ```
# [Geocode] 'Medina, Saudi Arabia' -> (24.4672, 39.6024)
#
#  ### Continue session: debug_session_id
#
# User > Given the following location_text from an OSINT message:
#
# "Kulgam"
#
# Return a JSON object of the form:
# {
#   "variants": ["<string1>", "<string2>", ...]
# }
#
# Follow your system instructions carefully:
# - Distinguish between BROAD REGION and SPECIFIC PLACE.
# - Preserve specificity when the place is already concrete.
# - Only choose a more specific sub-region when the phrase is inherently broad.
# Output ONLY the JSON.
# Agent5_LocationVariantGenerator > ```json
# {
#   "variants": [
#     "Kulgam, Jammu and Kashmir, India",
#     "Kulgam District, India"
#   ]
# }
# ```
# [Geocode] 'Kulgam, Jammu and Kashmir, India' -> (33.6450, 75.0180)
#
#  ### Continue session: debug_session_id
#
# User > Given the following location_text from an OSINT message:
#
# "Korail slum, Dhaka, Bangladesh"
#
# Return a JSON object of the form:
# {
#   "variants": ["<string1>", "<string2>", ...]
# }
#
# Follow your system instructions carefully:
# - Distinguish between BROAD REGION and SPECIFIC PLACE.
# - Preserve specificity when the place is already concrete.
# - Only choose a more specific sub-region when the phrase is inherently broad.
# Output ONLY the JSON.
# Agent5_LocationVariantGenerator > ```json
# {
#   "variants": [
#     "Korail slum, Dhaka, Bangladesh"
#   ]
# }
# ```
# [Geocode] 'Korail slum, Dhaka, Bangladesh' -> (23.7845, 90.4044)
#
#  ### Continue session: debug_session_id
#
# User > Given the following location_text from an OSINT message:
#
# "DC"
#
# Return a JSON object of the form:
# {
#   "variants": ["<string1>", "<string2>", ...]
# }
#
# Follow your system instructions carefully:
# - Distinguish between BROAD REGION and SPECIFIC PLACE.
# - Preserve specificity when the place is already concrete.
# - Only choose a more specific sub-region when the phrase is inherently broad.
# Output ONLY the JSON.
# Agent5_LocationVariantGenerator > ```json
# {
#   "variants": [
#     "Washington D.C., USA"
#   ]
# }
# ```
# [Geocode] (cached) 'Washington D.C., USA' -> (38.9072, -77.0369)
#
#  ### Continue session: debug_session_id
#
# User > Given the following location_text from an OSINT message:
#
# "Tai Po district, Hong Kong"
#
# Return a JSON object of the form:
# {
#   "variants": ["<string1>", "<string2>", ...]
# }
#
# Follow your system instructions carefully:
# - Distinguish between BROAD REGION and SPECIFIC PLACE.
# - Preserve specificity when the place is already concrete.
# - Only choose a more specific sub-region when the phrase is inherently broad.
# Output ONLY the JSON.
# Agent5_LocationVariantGenerator > ```json
# {
#   "variants": [
#     "Tai Po District, Hong Kong"
#   ]
# }
# ```
# [Geocode] 'Tai Po District, Hong Kong' -> (22.4423, 114.1655)
# [Agent5] Processed batch of 13 rows (total=45).
# [Agent5] Done. Total rows geocoded or marked as ungeocodable: 45
# [Agent5] Geocoding pipeline completed.

# %%
df = pd.read_sql_query(
    "SELECT category, location_text, lat, lon FROM events WHERE checked=1 AND processed=1;",
    conn
)
df.head()
# Out:
#    category                           location_text        lat        lon
# 0    attack                                   Bannu  32.990994  70.645473
# 1    attack  Peshawar, Khyber Pakhtunkhwa, Pakistan  34.008337  71.518862
# 2  movement            Khyber Pakhtunkhwa, Pakistan  34.151517  71.572395
# 3    attack               Bannu, Khyber Pakhtunkhwa  32.990994  70.645473
# 4  shelling         Janikhel, Baka Khel subdivision  32.956558  70.532443

# %% [markdown]
# ---
#
# # 🗺️ Agent 6 — Reporter & Map Orchestrator
# ### *Generating the final interactive map + LLM intelligence summary*
#
# Agent 6 is the “presentation” layer of the pipeline.
#
# It performs two responsibilities:
#
# ### 1. Mapping
# Using a function tool, it renders a **global interactive incident map** incorporating:
# - category-based colors
# - shape-based families
# - toggleable category layers
# - dark-matter basemap
#
# ### 2. Narrative Intelligence Summary
# Using the full incident context, Agent 6 produces a **human-readable markdown report** explaining:
# - per-day activity
# - category distribution
# - spatial clusters
# - notable out-of-region events
#
# This is the final deliverable showing the pipeline’s analytical value.
#
# Below is the implementation of Agent 6.

# %%
# === Agent 6 — Reporter & Interactive Map Orchestrator ===
#
# Role:
# - Input: incidents.db / events table with:
#       checked = 1
#       processed = 1
#       category, location_text, lat, lon
# - Tool:
#       make_interactive_map(mode: str = "all") -> dict
#       → plots ALL incidents with lat/lon on a global interactive map
#         (GeoPandas .explore + Folium, DarkMatter tiles)
# - LlmAgent:
#       1) Calls make_interactive_map(mode="all") ONCE
#       2) Reads a textual context describing per-day / per-category stats
#       3) Produces a GRAND MARKDOWN SUMMARY for the two days

import os
import sqlite3
import asyncio
from collections import defaultdict
from typing import List, Dict, Tuple

from dotenv import load_dotenv

import pandas as pd
import geopandas as gpd
import matplotlib.pyplot as plt

import contextily as ctx  # not strictly needed for explore, but ok to keep
from shapely.geometry import Point
import folium
from folium.features import RegularPolygonMarker

from google.genai import types
from google.adk.agents import LlmAgent
from google.adk.models import Gemini
from google.adk.runners import InMemoryRunner
from google.adk.tools.function_tool import FunctionTool

# ----------------- CONFIG -----------------

DB_PATH = "incidents.db"   # <- notebook DB
DAY1 = "2025-11-27"
DAY2 = "2025-11-28"

load_dotenv()
GOOGLE_API_KEY = os.getenv("GOOGLE_API_KEY")
if not GOOGLE_API_KEY:
    raise RuntimeError("GOOGLE_API_KEY is not set in environment / .env file.")

retry_config = types.HttpRetryOptions(
    attempts=5,
    exp_base=7,
    initial_delay=1,
    http_status_codes=[429, 500, 503, 504],
)

# Optional: consistent category colors (used as palette in .explore)
CATEGORY_COLORS: Dict[str, str] = {
    "attack":           "#ff6b6b",
    "explosion":        "#ffd93b",
    "shelling":         "#ff9f1c",
    "drone_strike":     "#f15bb5",
    "air_strike":       "#d7263d",
    "air_activity":     "#4cc9f0",
    "raid_search":      "#7209b7",
    "arrest_detention": "#4361ee",
    "weapons_seizure":  "#4cd5b5",
    "casualty_death":   "#f72585",
    "injury":           "#ff8fab",
    "protest_riot":     "#80ed99",
    "movement":         "#8d99ae",
    "disaster":         "#b56576",
    "kidnapping":       "#ff7f51",
    "smuggling":        "#b08968",
}


# ----------------- DB → CONTEXT HELPERS -----------------

def fetch_incidents_for_context() -> pd.DataFrame:
    """
    Fetch all canonical, mappable incidents from incidents.db/events.

    Conditions:
        checked = 1
        processed = 1
        lat/lon not null
    """
    conn = sqlite3.connect(DB_PATH)
    try:
        df = pd.read_sql_query(
            """
            SELECT date, category, location_text, lat, lon
            FROM events
            WHERE checked = 1
              AND processed = 1
              AND lat IS NOT NULL
              AND lon IS NOT NULL
            """,
            conn,
        )
    finally:
        conn.close()
    return df


def build_context_for_agent6() -> str:
    """
    Build a compact textual context for Agent 6.

    Includes:
        - Overall count of incidents across both days
        - Per-day counts
        - Per-day category breakdown
        - A small sample list of incidents (date | category | location_text)
    """
    df = fetch_incidents_for_context()
    if df.empty:
        return "No incidents available."

    # Extract YYYY-MM-DD for convenience
    df = df.copy()
    df["day"] = df["date"].astype(str).str.slice(0, 10)

    # Overall stats
    total_incidents = len(df)
    days_present = sorted(df["day"].unique())

    # Per-day counts
    day_counts = df.groupby("day").size().to_dict()

    # Per-day category counts
    day_cat_counts: Dict[str, Dict[str, int]] = {}
    grouped = df.groupby(["day", "category"]).size()
    for (day, cat), cnt in grouped.items():
        day_cat_counts.setdefault(day, {})[cat] = int(cnt)

    # Sample incidents (cap to avoid giant prompt)
    samples = []
    for _, row in df.head(30).iterrows():
        samples.append(
            f"- {row['day']} | {row['category']} | {row['location_text']}"
        )

    lines: List[str] = []
    lines.append("INCIDENT CONTEXT FOR AGENT 6 (GLOBAL VIEW)")
    lines.append("")
    lines.append(f"Total incidents with coordinates: {total_incidents}")
    lines.append(f"Days covered: {', '.join(days_present)}")
    lines.append("")

    lines.append("PER-DAY INCIDENT COUNTS:")
    for day in sorted(day_counts.keys()):
        lines.append(f"- {day}: {day_counts[day]} incidents")

    lines.append("")
    lines.append("PER-DAY CATEGORY BREAKDOWN:")
    for day in sorted(day_cat_counts.keys()):
        lines.append(f"{day}:")
        cat_map = day_cat_counts[day]
        # Sort categories by frequency descending
        for cat, cnt in sorted(cat_map.items(), key=lambda x: -x[1]):
            lines.append(f"  - {cat}: {cnt}")

    lines.append("")
    lines.append("SAMPLE INCIDENTS (for qualitative flavor):")
    if samples:
        lines.extend(samples)
    else:
        lines.append("- (no samples)")

    return "\n".join(lines)


# ----------------- MAP TOOL (INTERACTIVE, GLOBAL) -----------------

import folium
from folium.features import RegularPolygonMarker
from IPython.display import display
from typing import Dict
from typing import Dict
from folium import FeatureGroup, LayerControl


# High-level families of incident types
KINETIC = {
    "attack", "explosion", "shelling",
    "drone_strike", "air_strike",
}

SECURITY = {
    "raid_search", "arrest_detention", "weapons_seizure",
    "movement", "smuggling", "kidnapping", "air_activity",
}

CIVILIAN_IMPACT = {
    "disaster", "protest_riot", "casualty_death", "injury",
}

FAMILY_COLORS = {
    "KINETIC": "#ff6b6b",        # red
    "SECURITY": "#4cc9f0",       # blue
    "CIVILIAN_IMPACT": "#ffd93b" # yellow
}

def classify_family(category: str) -> str:
    """Map a fine-grained category into one of the three visual families."""
    if category in KINETIC:
        return "KINETIC"
    if category in SECURITY:
        return "SECURITY"
    if category in CIVILIAN_IMPACT:
        return "CIVILIAN_IMPACT"
    return "CIVILIAN_IMPACT"  # safe fallback


def add_shape_family_legend(m: folium.Map) -> None:
    """Add a compact HTML legend explaining color + shape."""
    html = """
    <div style="
        position: fixed;
        bottom: 40px;
        right: 40px;
        z-index: 9999;
        background-color: rgba(0,0,0,0.7);
        padding: 8px 12px;
        border-radius: 6px;
        color: #ffffff;
        font-size: 12px;
        line-height: 1.4;
    ">
      <b>Map key</b><br>
      <div style="margin-top:4px;">
        <span style="color:#ff6b6b;">●</span> Kinetic violence<br>
        <span style="color:#4cc9f0;">■</span> Security / law enforcement<br>
        <span style="color:#ffd93b;">▲</span> Civilian impact / disasters<br>
      </div>
    </div>
    """
    m.get_root().html.add_child(folium.Element(html))


from typing import Dict
import folium
from folium import FeatureGroup, LayerControl
from folium.features import RegularPolygonMarker
from IPython.display import display

def make_interactive_map(mode: str = "all") -> Dict[str, str]:
    """
    Create an INTERACTIVE global map of incidents using folium.

    mode:
      - "all" (default): plot all incidents
      - "YYYY-MM-DD": filter to that day
    LayerControl:
      - one toggle per CATEGORY
    Legend:
      - only 3 families (kinetic / security / civilian) with shape + color.
    """
    df = fetch_incidents_for_context()
    if df.empty:
        print("[MapTool] No incidents with coordinates to plot.")
        return {"status": "no_data"}

    if mode != "all":
        df = df[df["date"].astype(str).str.startswith(mode)]
        if df.empty:
            print(f"[MapTool] No incidents for day={mode}.")
            return {"status": "no_data"}

    df = df.dropna(subset=["lat", "lon"])
    if df.empty:
        print("[MapTool] No incidents with valid coordinates after filtering.")
        return {"status": "no_data"}

    center_lat = df["lat"].mean()
    center_lon = df["lon"].mean()

    m = folium.Map(
        location=[center_lat, center_lon],
        tiles="CartoDB dark_matter",
        zoom_start=4,
        control_scale=True,
    )

    # --- one FeatureGroup per CATEGORY ---
    categories = sorted(df["category"].dropna().unique())
    fg_by_category: Dict[str, FeatureGroup] = {}
    for cat in categories:
        fg = FeatureGroup(name=cat, show=True)
        fg.add_to(m)
        fg_by_category[cat] = fg

    # --- drop rows with missing category (optional) ---
    df = df[df["category"].notna()].copy()

    for _, row in df.iterrows():
        cat = row["category"]
        loc_text = row.get("location_text") or "Unknown location"
        family = classify_family(cat)
        color = FAMILY_COLORS.get(family, "#ffd93b")
        popup_txt = f"{cat} — {loc_text}"

        fg = fg_by_category.get(cat)
        if fg is None:
            continue  # should not happen

        if family == "KINETIC":
            # circle = kinetic violence
            folium.CircleMarker(
                location=[row["lat"], row["lon"]],
                radius=6,
                color=None,
                fill=True,
                fill_opacity=0.9,
                fill_color=color,
                popup=popup_txt,
            ).add_to(fg)

        elif family == "SECURITY":
            # diamond (rotated square) = security / law enforcement
            RegularPolygonMarker(
                location=[row["lat"], row["lon"]],
                number_of_sides=4,
                radius=7,
                rotation=0,
                weight=1.5,
                color=color,
                fill=True,
                fill_opacity=0.9,
                popup=popup_txt,
            ).add_to(fg)

        else:
            # triangle = civilian impact / disasters
            RegularPolygonMarker(
                location=[row["lat"], row["lon"]],
                number_of_sides=3,
                radius=7,
                rotation=30,
                weight=1.5,
                color=color,
                fill=True,
                fill_opacity=0.9,
                popup=popup_txt,
            ).add_to(fg)

    # LayerControl now shows *all categories*
    LayerControl(collapsed=False).add_to(m)

    # Shape + color legend for the 3 families
    add_shape_family_legend(m)

    display(m)
    print(f"[MapTool] Interactive map rendered for mode='{mode}'.")
    return {"status": "ok"}





# ----------------- AGENT 6: REPORTER + MAP ORCHESTRATOR -----------------

AGENT6_SYSTEM_INSTRUCTIONS = """
You are Agent6_Reporter in a multi-agent OSINT pipeline.

You have two things:
1. A map-generation tool: make_interactive_map(mode: str = "all").
   - When you call it with mode="all", it renders an interactive global map
     of all incidents with coordinates in the notebook output.
2. A textual context describing counts and samples of incidents.

Your tasks (STRICT):

1. Call make_interactive_map once with mode="all"
   so that the notebook shows an interactive global incident map
   for the two days combined.

2. After the map tool has been called, write a GRAND MARKDOWN SUMMARY
   of the incident data based on the context you are given. The summary
   should be intended for a human analyst reading the notebook.

   The report MUST include:
   - A section "## Overview" that describes:
       * scale of activity across both days
       * which categories seem most common
       * any high-level spatial intuition (e.g., cluster in certain regions)
         based on the context (do not hallucinate exact coordinates).
   - A section "## 27 November 2025" summarizing:
       * key categories and notable patterns for that day
   - A section "## 28 November 2025" summarizing:
       * key categories and notable patterns for that day
   - A section "## Analyst Notes & Caveats" that briefly mentions:
       * potential biases in the source channels
       * limitations of geocoding and categorization
       * that this is a 2-day slice, not a full operational picture.

Important:
- ALWAYS call the map tool exactly once with mode="all" before finalizing the report.
- Do NOT attempt to describe the visual style of the map in great detail.
  It is enough to refer to it as an interactive incident map.
- Base all quantitative statements ONLY on the context text you receive.
- Stay under ~500 words total.
""".strip()


def create_agent6_reporter() -> LlmAgent:
    """
    Create Agent 6 (LlmAgent) with the interactive map function as a tool.
    This is the ONLY agent in the pipeline that uses a FunctionTool.
    """
    agent = LlmAgent(
        name="Agent6_Reporter",
        model=Gemini(
            model="gemini-2.5-flash-lite",
            api_key=GOOGLE_API_KEY,
            retry_options=retry_config,
        ),
        description="Final reporter agent that renders an interactive global map and writes a grand summary.",
        instruction=AGENT6_SYSTEM_INSTRUCTIONS,
        tools=[FunctionTool(func=make_interactive_map)],  # map tool
    )
    return agent


# ----------------- RUNNER FOR AGENT 6 (NOTEBOOK ENTRYPOINT) -----------------


async def run_agent6_once():
    """
    Build context, run Agent 6 with the interactive-map tool,
    and print the final markdown report.
    """
    context_text = build_context_for_agent6()  

    user_prompt = f"""
You are provided with the following incident context text:

{context_text}

Remember your tasks:
1. You MUST call the `make_interactive_map` tool exactly once with mode="all".
2. AFTER the tool has been called and you have seen its result,
   you MUST send a final assistant message that is a concise markdown report.

Output rules:
- Call the tool first.
- Then send ONE final assistant message containing ONLY the markdown report
  (no code, no tool calls, no extra commentary).
""".strip()

    agent = create_agent6_reporter()      # your Agent6_Reporter constructor
    runner = InMemoryRunner(agent=agent)
    print("[Agent6] Reporter agent created. Running with debug trace...\n")

    events = await runner.run_debug(user_prompt)

    # --- extract final assistant text, skipping pure tool-call events ---
    final_text = None

    for e in reversed(events):
        # we only care about assistant messages
        if getattr(e, "author", "") != "assistant":
            continue
        content = getattr(e, "content", None)
        if content is None:
            continue

        text_parts = []
        for p in getattr(content, "parts", []):
            # ignore function_call / tool stuff, keep only plain text
            if hasattr(p, "text") and p.text:
                text_parts.append(p.text)

        if text_parts:
            final_text = "\n".join(text_parts).strip()
            break

    if not final_text:
        print("[Agent6] No final text response found. Check that the system "
              "instructions tell the model to respond AFTER the tool call.")
        return

    print("\n===== Agent 6 Final Report =====\n")
    print(final_text)

# %%
await run_agent6_once()
# Out:
# App name mismatch detected. The runner is configured with app name "InMemoryRunner", but the root agent was loaded from "C:\Users\Lenovo\Desktop\AgentAICourse\agentai_venv\Lib\site-packages\google\adk\agents", which implies app name "agents".
# [Agent6] Reporter agent created. Running with debug trace...
#
#
#  ### Created new session: debug_session_id
#
# User > You are provided with the following incident context text:
#
# INCIDENT CONTEXT FOR AGENT 6 (GLOBAL VIEW)
#
# Total incidents with coordinates: 45
# Days covered: 2025-11-27, 2025-11-28
#
# PER-DAY INCIDENT COUNTS:
# - 2025-11-27: 25 incidents
# - 2025-11-28: 20 incidents
#
# PER-DAY CATEGORY BREAKDOWN:
# 2025-11-27:
#   - attack: 7
#   - disaster: 5
#   - arrest_detention: 3
#   - drone_strike: 3
#   - casualty_death: 1
#   - explosion: 1
#   - kidnapping: 1
#   - movement: 1
#   - raid_search: 1
#   - shelling: 1
#   - smuggling: 1
# 2025-11-28:
#   - attack: 12
#   - disaster: 2
#   - casualty_death: 1
#   - drone_strike: 1
#   - explosion: 1
#   - movement: 1
#   - raid_search: 1
#   - weapons_seizure: 1
#
# SAMPLE INCIDENTS (for qualitative flavor):
# - 2025-11-28 | attack | Bannu
# - 2025-11-28 | attack | Peshawar, Khyber Pakhtunkhwa, Pakistan
# - 2025-11-28 | movement | Khyber Pakhtunkhwa, Pakistan
# - 2025-11-28 | attack | Bannu, Khyber Pakhtunkhwa
# - 2025-11-27 | shelling | Janikhel, Baka Khel subdivision
# - 2025-11-27 | attack | Panjgur
# - 2025-11-28 | disaster | Hong Kong
# - 2025-11-28 | attack | Tengnoupal district, Manipur, India
# - 2025-11-28 | raid_search | Basantgarh, Udhampur
# - 2025-11-28 | attack | Tengnoupal, Manipur
# - 2025-11-27 | drone_strike | Bannu district, Khyber Pakhtunkhwa province
# - 2025-11-27 | arrest_detention | Barmer, Rajasthan
# - 2025-11-27 | disaster | southwest China
# - 2025-11-27 | disaster | Hong Kong
# - 2025-11-28 | explosion | Chaibasa, Jharkhand
# - 2025-11-28 | attack | University Town, Pakistan
# - 2025-11-28 | disaster | Sri Lanka
# - 2025-11-28 | casualty_death | Khyber Pakhtunkhwa
# - 2025-11-28 | attack | Beit Jinn, rural Damascus, Syria
# - 2025-11-28 | attack | Domail Ahmadzai, Bannu
# - 2025-11-27 | drone_strike | Tajikistan
# - 2025-11-27 | casualty_death | Mohabbat Khel
# - 2025-11-27 | explosion | Wana, South Waziristan
# - 2025-11-27 | arrest_detention | Bathindi, Jammu
# - 2025-11-27 | attack | Baalade Valley, Puntland, Somalia
# - 2025-11-27 | attack | White House
# - 2025-11-27 | disaster | Hong Kong
# - 2025-11-27 | drone_strike | Jabar Mela, Khyber District, Khyber Pakhtunkhwa
# - 2025-11-27 | attack | Washington, DC
# - 2025-11-27 | kidnapping | Nigeria
#
# Remember your tasks:
# 1. You MUST call the `make_interactive_map` tool exactly once with mode="all".
# 2. AFTER the tool has been called and you have seen its result,
#    you MUST send a final assistant message that is a concise markdown report.
#
# Output rules:
# - Call the tool first.
# - Then send ONE final assistant message containing ONLY the markdown report
#   (no code, no tool calls, no extra commentary).
# Warning: there are non-text parts in the response: ['function_call'], returning concatenated text result from text parts. Check the full candidates.content.parts accessor to get the full model response.
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_f85c1cf61b73270bbd67256f40fefb01 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet-dvf/0.3.0/leaflet-dvf.markers.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#     &lt;div style=&quot;
#         position: fixed;
#         bottom: 40px;
#         right: 40px;
#         z-index: 9999;
#         background-color: rgba(0,0,0,0.7);
#         padding: 8px 12px;
#         border-radius: 6px;
#         color: #ffffff;
#         font-size: 12px;
#         line-height: 1.4;
#     &quot;&gt;
#       &lt;b&gt;Map key&lt;/b&gt;&lt;br&gt;
#       &lt;div style=&quot;margin-top:4px;&quot;&gt;
#         &lt;span style=&quot;color:#ff6b6b;&quot;&gt;●&lt;/span&gt; Kinetic violence&lt;br&gt;
#         &lt;span style=&quot;color:#4cc9f0;&quot;&gt;■&lt;/span&gt; Security / law enforcement&lt;br&gt;
#         &lt;span style=&quot;color:#ffd93b;&quot;&gt;▲&lt;/span&gt; Civilian impact / disasters&lt;br&gt;
#       &lt;/div&gt;
#     &lt;/div&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_f85c1cf61b73270bbd67256f40fefb01&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_f85c1cf61b73270bbd67256f40fefb01 = L.map(
#                 &quot;map_f85c1cf61b73270bbd67256f40fefb01&quot;,
#                 {
#                     center: [29.35239220222222, 58.61638515777778],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 4,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#             L.control.scale().addTo(map_f85c1cf61b73270bbd67256f40fefb01);
#
#
#
#
#
#             var tile_layer_3809fe4d01f6691f8392cf41e5862779 = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/dark_all/{z}/{x}/{y}{r}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 20,
#   &quot;maxNativeZoom&quot;: 20,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;,
#   &quot;subdomains&quot;: &quot;abcd&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_3809fe4d01f6691f8392cf41e5862779.addTo(map_f85c1cf61b73270bbd67256f40fefb01);
#
#
#             var feature_group_68f59e7cf5d0bd35b6da16ea72be2a52 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var regular_polygon_marker_d2e873618fa5b22948001319be5c1c46 = new L.RegularPolygonMarker(
#                 [25.7521467, 71.3966865],
#                 {
#   &quot;stroke&quot;: true,
#   &quot;color&quot;: &quot;#4cc9f0&quot;,
#   &quot;weight&quot;: 1.5,
#   &quot;opacity&quot;: 1.0,
#   &quot;lineCap&quot;: &quot;round&quot;,
#   &quot;lineJoin&quot;: &quot;round&quot;,
#   &quot;dashArray&quot;: null,
#   &quot;dashOffset&quot;: null,
#   &quot;fill&quot;: true,
#   &quot;fillColor&quot;: &quot;#4cc9f0&quot;,
#   &quot;fillOpacity&quot;: 0.9,
#   &quot;fillRule&quot;: &quot;evenodd&quot;,
#   &quot;bubblingMouseEvents&quot;: true,
#   &quot;radius&quot;: 7,
#   &quot;numberOfSides&quot;: 4,
#   &quot;rotation&quot;: 0,
# }
#             ).addTo(feature_group_68f59e7cf5d0bd35b6da16ea72be2a52);
#
#
#         var popup_fecf4989faa3659d899e6505fcd9ac12 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_17416b2e42413e096d807c77de799523 = $(`&lt;div id=&quot;html_17416b2e42413e096d807c77de799523&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;arrest_detention — Barmer, Rajasthan&lt;/div&gt;`)[0];
#                 popup_fecf4989faa3659d899e6505fcd9ac12.setContent(html_17416b2e42413e096d807c77de799523);
#
#
#
#         regular_polygon_marker_d2e873618fa5b22948001319be5c1c46.bindPopup(popup_fecf4989faa3659d899e6505fcd9ac12)
#         ;
#
#
#
#
#             var regular_polygon_marker_f84d6bde6d9eb64efaa702b397728cdc = new L.RegularPolygonMarker(
#                 [32.7103768, 74.9062622],
#                 {
#   &quot;stroke&quot;: true,
#   &quot;color&quot;: &quot;#4cc9f0&quot;,
#   &quot;weight&quot;: 1.5,
#   &quot;opacity&quot;: 1.0,
#   &quot;lineCap&quot;: &quot;round&quot;,
#   &quot;lineJoin&quot;: &quot;round&quot;,
#   &quot;dashArray&quot;: null,
#   &quot;dashOffset&quot;: null,
#   &quot;fill&quot;: true,
#   &quot;fillColor&quot;: &quot;#4cc9f0&quot;,
#   &quot;fillOpacity&quot;: 0.9,
#   &quot;fillRule&quot;: &quot;evenodd&quot;,
#   &quot;bubblingMouseEvents&quot;: true,
#   &quot;radius&quot;: 7,
#   &quot;numberOfSides&quot;: 4,
#   &quot;rotation&quot;: 0,
# }
#             ).addTo(feature_group_68f59e7cf5d0bd35b6da16ea72be2a52);
#
#
#         var popup_0c120705d887e11565f97fb0c046493e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2982b579a6b8fefe9f061b840df9b20b = $(`&lt;div id=&quot;html_2982b579a6b8fefe9f061b840df9b20b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;arrest_detention — Bathindi, Jammu&lt;/div&gt;`)[0];
#                 popup_0c120705d887e11565f97fb0c046493e.setContent(html_2982b5
# [MapTool] Interactive map rendered for mode='all'.
# Agent6_Reporter > ## Grand Summary of Incidents (27-28 November 2025)
#
# ### Overview
#
# This report summarizes a total of 45 incidents recorded across two days, 27 and 28 November 2025. The activity shows a notable presence of "attack" incidents, which appear to be the most common category across the period. Geographically, incidents are distributed globally, with some indications of clusters in regions like Khyber Pakhtunkhwa, Pakistan, and Manipur, India, based on sample data.
#
# ### 27 November 2025
#
# On this day, 25 incidents were recorded. The most frequent categories were "attack" (7 incidents), followed by "disaster" (5 incidents). Other notable categories included "arrest_detention" and "drone_strike," each with 3 incidents. There was also isolated activity in categories such as "shelling," "explosion," "kidnapping," and "smuggling."
#
# ### 28 November 2025
#
# The second day saw 20 incidents. "Attack" incidents were significantly more prevalent, with 12 recorded events. "Disaster" incidents decreased to 2. Other categories present included "casualty_death," "drone_strike," "explosion," "movement," "raid_search," and "weapons_seizure," each with one or two occurrences.
#
# ### Analyst Notes & Caveats
#
# The provided incident data is based on available source channels, which may present certain biases. Geocoding and categorization processes can have inherent limitations, potentially affecting the precision and classification of incidents. This 2-day overview offers a snapshot of activity but does not represent a comprehensive operational picture.
# [Agent6] No final text response found. Check that the system instructions tell the model to respond AFTER the tool call.

# %% [markdown]
# ---
#
# # 🎯 Final Remarks
#
# This concludes the full OSINT incident pipeline:
#
# Raw Telegram messages →  Cleaned, structured events →  Filtered to real incidents → Deduped → Categorized → Geocoded →  Mapped + summarized automatically
#
# The entire workflow is reproducible, transparent, and modular, making it easy to improve or scale.
# It showcases how **agentic AI + geospatial intelligence** can transform unstructured data streams into actionable situational awareness.
#
# Feedback is welcome — the pipeline is designed to evolve.
#
# ---
